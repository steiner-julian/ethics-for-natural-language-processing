# %% [markdown]
# ## Task 1: Toy Bi-Gram LM

# %%
from collections import Counter, defaultdict
import random
import tqdm

# %%
# <BOS> is the beginning of sentence token
# <EOS> is the end of sentence token
def preprocess(s):
    s = "<BOS> " + s + " <EOS>"
    words = [w.replace(".", "") for w in s.lower().split(" ")]
    return words

# %%
# Mount your google drive
# Remove this code if you do not upload the file to your google drive
# Download it from: https://hessenbox.tu-darmstadt.de/getlink/fiCd4Ym2C61sGD2dVd1RqFNh/simple_wikipedia.zip
# from google.colab import drive
# drive.mount('/content/drive')

# %%
corpus = []
# Insert path to the text file
with open("data/simple_wikipedia.txt") as f:
    for line in f.readlines():
        line = line.replace("\n", "")
        if line:
            corpus += preprocess(line)

# %%
print(len(corpus))
# Out:
# 31756752

# %%
corpus[:10]
# Out:
# ['<bos>',
#  'april',
#  '<eos>',
#  '<bos>',
#  'april',
#  '(apr)',
#  'is',
#  'the',
#  'fourth',
#  'month']

# %%
# Counts the frequency of each word
c = Counter(corpus)

# %%
c
# Out:
# Counter({'the': 2019819,
#          '<bos>': 977830,
#          '<eos>': 977830,
#          'of': 959455,
#          'in': 943150,
#          'and': 760404,
#          'a': 684641,
#          'is': 568699,
#          'to': 502970,
#          'was': 452046,
#          'it': 268659,
#          'he': 263238,
#          'on': 235740,
#          'for': 230421,
#          'as': 198648,
#          'by': 183094,
#          'from': 167653,
#          'that': 158897,
#          'with': 153606,
#          'are': 147833,
#          'at': 140200,
#          'an': 130035,
#          'his': 127013,
#          'they': 104974,
#          'or': 92598,
#          'also': 91516,
#          'this': 88630,
#          'were': 87805,
#          'has': 87283,
#          'she': 84216,
#          '': 82948,
#          'be': 79419,
#          'people': 69889,
#          'which': 69247,
#          'first': 68312,
#          'not': 68291,
#          'have': 65044,
#          'one': 64075,
#          'their': 59631,
#          'there': 58565,
#          'had': 58248,
#          'after': 55698,
#          'her': 52567,
#          'new': 52158,
#          'but': 52135,
#          'united': 51956,
#          'other': 50375,
#          'many': 49080,
#          'who': 49013,
#          'its': 48641,
#          'can': 48599,
#          'when': 47039,
#          'known': 46551,
#          'about': 45974,
#          'city': 44066,
#          'american': 43152,
#          'called': 43131,
#          'used': 42748,
#          'two': 41936,
#          'made': 41717,
#          'states': 41421,
#          'most': 41048,
#          'some': 39908,
#          'born': 39186,
#          'may': 38635,
#          'been': 37109,
#          'more': 35844,
#          'all': 35609,
#          '–': 35247,
#          'died': 35107,
#          'into': 33914,
#          'world': 33257,
#          'during': 32823,
#          'became': 32455,
#          'national': 31108,
#          'part': 30102,
#          'because': 29949,
#          'movie': 29717,
#          'time': 29181,
#          'played': 28491,
#          'only': 28335,
#          'state': 28273,
#          'these': 28081,
#          '"the': 26799,
#          '(born': 26780,
#          'than': 26441,
#          'years': 26168,
#          'name': 26162,
#          'between': 26125,
#          'january': 24626,
#          'like': 24481,
#          'up': 24243,
#          'would': 24235,
#          'over': 24143,
#          'county': 23956,
#          'where': 23877,
#          'number': 23823,
#          'very': 23758,
#          'south': 23289,
#          'north': 23255,
#          'them': 23203,
#          'such': 23129,
#          'won': 23086,
#          'team': 22943,
#          'until': 22626,
#          'released': 22033,
#          'then': 21994,
#          'three': 21709,
#          'found': 21528,
#          'france': 21308,
#          'him': 20715,
#          'different': 20705,
#          'age': 20510,
#          'since': 20372,
#          'march': 20342,
#          'university': 20163,
#          'out': 19810,
#          'later': 19633,
#          'september': 19498,
#          'before': 19468,
#          'second': 19436,
#          'series': 19261,
#          'july': 19258,
#          'music': 19257,
#          'will': 19253,
#          'august': 19249,
#          'area': 19202,
#          'october': 19124,
#          'so': 19092,
#          'june': 19084,
#          'us': 19038,
#          'war': 18661,
#          'november': 18503,
#          'april': 18374,
#          'december': 18330,
#          'member': 18241,
#          'president': 18222,
#          'department': 18218,
#          'town': 18074,
#          'make': 17878,
#          'de': 17743,
#          'same': 17720,
#          'best': 17713,
#          'if': 17688,
#          'february': 17529,
#          'region': 17498,
#          'being': 17485,
#          'district': 17482,
#          'football': 17437,
#          'group': 17395,
#          'started': 17388,
#          'named': 17077,
#          'song': 16998,
#          'no': 16958,
#          'use': 16899,
#          'year': 16857,
#          'often': 16807,
#          'both': 16666,
#          'album': 16622,
#          'through': 16601,
#          'british': 16164,
#          'each': 16106,
#          'said': 15941,
#          '2020': 15899,
#          'did': 15897,
#          'while': 15789,
#          'against': 15671,
#          'commune': 15640,
#          'television': 15285,
#          'government': 15068,
#          'around': 15051,
#          'party': 15014,
#          'work': 14997,
#          'family': 14995,
#          'game': 14988,
#          'do': 14974,
#          'player': 14712,
#          'population': 14383,
#          'river': 14346,
#          'well': 14260,
#          'under': 14250,
#          'several': 14217,
#          'could': 14124,
#          'school': 14021,
#          'lived': 14000,
#          'place': 13928,
#          'main': 13889,
#          'former': 13823,
#          'west': 13742,
#          'however,': 13730,
#          'usually': 13630,
#          'including': 13610,
#          'municipality': 13447,
#          'four': 13373,
#          'county,': 13310,
#          'league': 13295,
#          'english': 13261,
#          'began': 13249,
#          'john': 13237,
#          '1': 13178,
#          'small': 13129,
#          'went': 12886,
#          'east': 12881,
#          'long': 12850,
#          'york': 12728,
#          'created': 12657,
#          'based': 12494,
#          'live': 12452,
#          'water': 12418,
#          'international': 12360,
#          'province': 12234,
#          'important': 12233,
#          'show': 12233,
#          'back': 12184,
#          'early': 12101,
#          'house': 11910,
#          'band': 11853,
#          'home': 11798,
#          'another': 11793,
#          'large': 11779,
#          'season': 11711,
#          'any': 11692,
#          'high': 11645,
#          'french': 11608,
#          'king': 11567,
#          'club': 11253,
#          'games': 11251,
#          'get': 11227,
#          'now': 11223,
#          'death': 11192,
#          '()': 11127,
#          'person': 11106,
#          '-': 11071,
#          'system': 11054,
#          'politician': 11009,
#          'country': 10947,
#          'end': 10880,
#          'old': 10810,
#          'much': 10753,
#          '2': 10745,
#          'last': 10736,
#          'company': 10733,
#          'what': 10721,
#          'means': 10539,
#          'famous': 10435,
#          'way': 10422,
#          'popular': 10410,
#          'century': 10345,
#          'life': 10335,
#          'written': 10325,
#          'million': 10314,
#          'single': 10295,
#          'near': 10291,
#          'germany': 10234,
#          'still': 10203,
#          'even': 10180,
#          'took': 10173,
#          'married': 10143,
#          'minister': 10099,
#          'left': 10019,
#          'moved': 9989,
#          'capital': 9973,
#          'how': 9857,
#          'language': 9856,
#          'list': 9777,
#          'award': 9768,
#          'day': 9719,
#          'general': 9694,
#          'england': 9693,
#          'largest': 9689,
#          'built': 9687,
#          'great': 9645,
#          'book': 9642,
#          'include': 9627,
#          'wrote': 9614,
#          'directed': 9555,
#          'play': 9530,
#          'came': 9516,
#          'german': 9497,
#          'sometimes': 9483,
#          'become': 9453,
#          'common': 9401,
#          'worked': 9364,
#          'japan': 9316,
#          'species': 9310,
#          'major': 9308,
#          'held': 9213,
#          'countries': 9181,
#          'third': 9155,
#          'children': 9132,
#          'island': 9030,
#          'own': 9021,
#          'following': 8963,
#          'living': 8944,
#          'given': 8944,
#          'members': 8867,
#          'central': 8816,
#          'i': 8763,
#          'five': 8738,
#          '3': 8679,
#          'served': 8641,
#          'form': 8617,
#          'cup': 8603,
#          'times': 8582,
#          'summer': 8561,
#          'western': 8526,
#          'using': 8446,
#          'good': 8380,
#          'aged': 8333,
#          'white': 8325,
#          'sea': 8317,
#          'army': 8311,
#          'northern': 8279,
#          'set': 8273,
#          'public': 8256,
#          'just': 8253,
#          'land': 8239,
#          'does': 8225,
#          'top': 8159,
#          'you': 8152,
#          '10': 8151,
#          'black': 8148,
#          'kingdom': 8143,
#          'role': 8122,
#          'founded': 8092,
#          '4': 8084,
#          'history': 8076,
#          'word': 8060,
#          'california': 8057,
#          'got': 8023,
#          'along': 8008,
#          'go': 7909,
#          'next': 7823,
#          'professional': 7802,
#          'power': 7788,
#          'film': 7787,
#          'down': 7763,
#          'published': 7749,
#          'together': 7737,
#          'every': 7735,
#          'church': 7728,
#          'air': 7682,
#          'again': 7681,
#          'video': 7664,
#          'things': 7662,
#          'actor': 7627,
#          'union': 7625,
#          'career': 7605,
#          'india': 7602,
#          'european': 7570,
#          'plays': 7547,
#          'parts': 7541,
#          'london': 7536,
#          'rock': 7518,
#          'political': 7516,
#          'center': 7502,
#          'order': 7495,
#          'seat': 7494,
#          'few': 7481,
#          'body': 7478,
#          'help': 7441,
#          'stars': 7439,
#          'located': 7425,
#          'station': 7423,
#          '2010': 7415,
#          'line': 7378,
#          'those': 7355,
#          'young': 7352,
#          '2019': 7321,
#          'making': 7303,
#          '2018': 7271,
#          'japanese': 7244,
#          'thought': 7234,
#          'southern': 7230,
#          '5': 7227,
#          'frog': 7219,
#          'human': 7209,
#          'father': 7206,
#          '2017': 7157,
#          'term': 7137,
#          'received': 7136,
#          'due': 7117,
#          'indian': 7116,
#          'take': 7109,
#          'village': 7106,
#          'killed': 7098,
#          'australia': 7081,
#          'women': 7049,
#          'seen': 7036,
#          'park': 7010,
#          'la': 7010,
#          'head': 7008,
#          'type': 6984,
#          'law': 6975,
#          '2011': 6970,
#          'works': 6946,
#          'red': 6946,
#          'championship': 6942,
#          'big': 6924,
#          'according': 6901,
#          'movies': 6893,
#          'studio': 6881,
#          'modern': 6840,
#          'st': 6833,
#          'led': 6778,
#          'college': 6754,
#          '2021': 6695,
#          'republic': 6672,
#          'son': 6663,
#          'without': 6661,
#          'military': 6656,
#          'election': 6640,
#          'joined': 6607,
#          'produced': 6602,
#          'six': 6580,
#          '2014': 6546,
#          'prime': 6502,
#          'ii': 6483,
#          'similar': 6482,
#          'special': 6457,
#          'james': 6449,
#          ',': 6447,
#          'italian': 6447,
#          'caused': 6428,
#          'announced': 6414,
#          'formed': 6406,
#          'man': 6400,
#          'lost': 6389,
#          'although': 6386,
#          '2008': 6384,
#          'put': 6339,
#          '12': 6330,
#          '20': 6320,
#          'original': 6306,
#          'off': 6305,
#          '2013': 6301,
#          'late': 6299,
#          'america': 6276,
#          'actress': 6262,
#          'lot': 6251,
#          'san': 6248,
#          'makes': 6232,
#          'songs': 6230,
#          'william': 6216,
#          'lives': 6193,
#          '2016': 6186,
#          'roman': 6179,
#          '15': 6151,
#          'playing': 6122,
#          'total': 6120,
#          '2007': 6108,
#          '2012': 6106,
#          'eastern': 6096,
#          'version': 6094,
#          'singer': 6092,
#          '6': 6086,
#          'elected': 6078,
#          'building': 6075,
#          'local': 6074,
#          'short': 6070,
#          'leader': 6068,
#          'story': 6066,
#          'changed': 6063,
#          'court': 6049,
#          "women's": 6038,
#          'george': 6035,
#          '2009': 6032,
#          'gave': 6030,
#          'appeared': 6021,
#          'mostly': 6016,
#          'time,': 6015,
#          'money': 5992,
#          'men': 5986,
#          'days': 5981,
#          '2006': 5962,
#          'side': 5945,
#          '2020,': 5941,
#          'italy': 5938,
#          'example,': 5919,
#          'away': 5897,
#          'director': 5894,
#          'we': 5893,
#          'royal': 5865,
#          'battle': 5865,
#          'others': 5857,
#          'office': 5848,
#          'title': 5845,
#          'australian': 5840,
#          'food': 5818,
#          'soviet': 5780,
#          'character': 5766,
#          'lake': 5766,
#          'record': 5758,
#          'social': 5745,
#          '&': 5732,
#          'governor': 5722,
#          '2015': 5715,
#          'among': 5697,
#          'right': 5673,
#          'little': 5672,
#          'less': 5672,
#          'wanted': 5664,
#          '8': 5662,
#          'census': 5644,
#          'olympics': 5638,
#          'art': 5631,
#          'included': 5622,
#          '7': 5618,
#          '2022': 5618,
#          'comes': 5614,
#          'change': 5605,
#          'light': 5590,
#          'see': 5578,
#          'within': 5556,
#          'academy': 5556,
#          'includes': 5553,
#          'service': 5553,
#          'should': 5548,
#          '100': 5513,
#          '(;': 5504,
#          'civil': 5497,
#          'control': 5470,
#          'having': 5469,
#          '11': 5468,
#          'robert': 5446,
#          'shows': 5440,
#          'final': 5433,
#          'current': 5407,
#          'awards': 5386,
#          'period': 5365,
#          'russian': 5361,
#          'must': 5360,
#          'studied': 5360,
#          'community': 5359,
#          'ancient': 5347,
#          'taken': 5343,
#          'almost': 5340,
#          'books': 5329,
#          'event': 5322,
#          'official': 5314,
#          'mother': 5308,
#          'europe': 5303,
#          'rights': 5303,
#          'los': 5265,
#          'attack': 5258,
#          'come': 5255,
#          '18': 5255,
#          'canada': 5254,
#          'middle': 5252,
#          'police': 5249,
#          'groups': 5245,
#          'female': 5241,
#          'considered': 5236,
#          '13': 5228,
#          'canadian': 5228,
#          'china': 5226,
#          '2005': 5215,
#          'match': 5215,
#          '30': 5196,
#          '14': 5188,
#          'places': 5178,
#          'level': 5170,
#          '(the': 5167,
#          'david': 5156,
#          '1,': 5153,
#          'though': 5152,
#          'drama': 5145,
#          'better': 5127,
#          'council': 5127,
#          'division': 5110,
#          'run': 5106,
#          '2001': 5102,
#          'democratic': 5100,
#          'says': 5097,
#          '16': 5096,
#          'areas': 5095,
#          '2004': 5087,
#          'switzerland': 5087,
#          'sold': 5061,
#          'hockey': 5055,
#          'heart': 5044,
#          'texas': 5031,
#          'grand': 5023,
#          'developed': 5019,
#          'players': 5008,
#          'once': 5000,
#          'able': 4967,
#          'point': 4959,
#          '25': 4948,
#          'empire': 4946,
#          '2000': 4946,
#          'never': 4945,
#          'spanish': 4933,
#          'working': 4930,
#          'force': 4910,
#          'tropical': 4888,
#          'charles': 4880,
#          'too': 4854,
#          '9': 4838,
#          'done': 4816,
#          'michael': 4803,
#          'free': 4802,
#          '17': 4788,
#          'chinese': 4786,
#          'association': 4764,
#          'animals': 4761,
#          'above': 4756,
#          'natural': 4732,
#          'parliament': 4724,
#          'uses': 4719,
#          'seven': 4714,
#          'cities': 4698,
#          'retired': 4695,
#          'sent': 4683,
#          'radio': 4675,
#          'race': 4666,
#          'instead': 4653,
#          'various': 4631,
#          'find': 4624,
#          'currently': 4617,
#          'support': 4614,
#          'teams': 4614,
#          'science': 4604,
#          'cancer': 4601,
#          'problems': 4575,
#          'mainly': 4555,
#          'islands': 4546,
#          'research': 4534,
#          'medal': 4528,
#          'greek': 4487,
#          '2020)': 4484,
#          'give': 4477,
#          '2003': 4465,
#          'movement': 4461,
#          'example': 4460,
#          'competed': 4460,
#          'star': 4459,
#          'gold': 4454,
#          'spain': 4452,
#          '24': 4448,
#          'languages': 4444,
#          'census,': 4431,
#          'federal': 4426,
#          'say': 4420,
#          'lead': 4417,
#          'across': 4416,
#          'ended': 4410,
#          'energy': 4410,
#          'space': 4383,
#          'records': 4383,
#          'study': 4376,
#          'love': 4371,
#          'woman': 4367,
#          'ice': 4364,
#          '2019,': 4362,
#          'start': 4360,
#          'helped': 4360,
#          'god': 4348,
#          'hit': 4345,
#          '2002': 4337,
#          'opened': 4325,
#          'tv': 4322,
#          'computer': 4317,
#          'comedy': 4316,
#          'wife': 4311,
#          'act': 4303,
#          'forces': 4303,
#          'types': 4287,
#          'highest': 4281,
#          'reached': 4277,
#          'average': 4271,
#          'native': 4270,
#          'coast': 4264,
#          'lower': 4262,
#          'paul': 4260,
#          'recorded': 4251,
#          'green': 4240,
#          'writer': 4237,
#          'states,': 4233,
#          '(or': 4222,
#          'storm': 4221,
#          'win': 4209,
#          'health': 4207,
#          'richard': 4201,
#          'open': 4193,
#          'scientists': 4191,
#          'fourth': 4187,
#          'think': 4186,
#          'earth': 4184,
#          'least': 4177,
#          'dutch': 4175,
#          'either': 4170,
#          'move': 4169,
#          'fire': 4165,
#          'originally': 4164,
#          '2,': 4164,
#          'canton': 4163,
#          '19': 4155,
#          'meaning': 4154,
#          'development': 4151,
#          'roles': 4150,
#          'program': 4147,
#          'road': 4136,
#          'africa': 4134,
#          'hall': 4131,
#          'decided': 4129,
#          'might': 4129,
#          'cause': 4124,
#          'later,': 4118,
#          'hot': 4117,
#          'tree': 4117,
#          'child': 4116,
#          '21': 4110,
#          'field': 4101,
#          'returned': 4093,
#          'performed': 4091,
#          'close': 4086,
#          'class': 4081,
#          'sports': 4079,
#          '22': 4052,
#          'words': 4038,
#          'network': 4034,
#          'today': 4025,
#          'strong': 4023,
#          'stage': 4021,
#          'replaced': 4015,
#          '1999': 4013,
#          'information': 4013,
#          'plants': 4010,
#          'always': 4005,
#          'daughter': 4000,
#          'museum': 4000,
#          'prize': 3999,
#          'chief': 3997,
#          'episode': 3995,
#          'certain': 3990,
#          'students': 3988,
#          'signed': 3986,
#          'peter': 3985,
#          'real': 3985,
#          'established': 3983,
#          'hurricane': 3982,
#          'car': 3974,
#          'christian': 3966,
#          'illinois': 3965,
#          'debut': 3964,
#          'idea': 3946,
#          'especially': 3941,
#          'mountain': 3937,
#          'writing': 3930,
#          'city,': 3920,
#          '23': 3913,
#          'business': 3910,
#          'african': 3906,
#          'shown': 3903,
#          'inside': 3899,
#          '3,': 3894,
#          '1996': 3888,
#          'henry': 3886,
#          'ten': 3876,
#          'himself': 3872,
#          'railway': 3864,
#          'names': 3861,
#          'channel': 3861,
#          'professor': 3858,
#          'thomas': 3852,
#          'pakistan': 3850,
#          'hospital': 3844,
#          '4,': 3843,
#          'catholic': 3840,
#          'disease': 3829,
#          'need': 3825,
#          'half': 3824,
#          'fc': 3814,
#          'nominated': 3813,
#          'outside': 3809,
#          'per': 3803,
#          'sweden': 3799,
#          'florida': 3799,
#          'going': 3796,
#          'position': 3795,
#          'chicago': 3787,
#          'stop': 3786,
#          'bad': 3784,
#          'goes': 3780,
#          'airport': 3779,
#          'sound': 3775,
#          '26': 3767,
#          'allowed': 3760,
#          'society': 3752,
#          'takes': 3739,
#          'paris': 3739,
#          'medical': 3720,
#          'republican': 3718,
#          '1998': 3715,
#          'color': 3701,
#          'successful': 3696,
#          '1992': 3696,
#          'night': 3694,
#          'months': 3693,
#          'mexico': 3679,
#          'independent': 3670,
#          'queen': 3655,
#          'look': 3643,
#          'characters': 3643,
#          'virginia': 3635,
#          'media': 3633,
#          'added': 3628,
#          'continued': 3615,
#          'russia': 3613,
#          'site': 3612,
#          'uk': 3607,
#          'divided': 3603,
#          'male': 3597,
#          'education': 3581,
#          'eight': 3568,
#          'related': 3564,
#          'want': 3564,
#          '1995': 3563,
#          '15,': 3563,
#          'believed': 3557,
#          'prince': 3554,
#          'changes': 3551,
#          '2016,': 3548,
#          'enough': 3547,
#          'blue': 3546,
#          'musical': 3538,
#          '2010,': 3534,
#          'ever': 3533,
#          'brother': 3533,
#          'winter': 3529,
#          'centre': 3522,
#          'secretary': 3516,
#          'finished': 3515,
#          'years,': 3514,
#          'latin': 3514,
#          'hard': 3513,
#          'soon': 3512,
#          'zealand': 3512,
#          '1994': 3500,
#          '2021,': 3493,
#          'events': 3491,
#          'owned': 3489,
#          '(also': 3484,
#          '28': 3480,
#          '7,': 3477,
#          'far': 3476,
#          '12,': 3475,
#          'cannot': 3474,
#          'full': 3473,
#          ')': 3473,
#          'kind': 3469,
#          '27': 3467,
#          'brown': 3466,
#          'know': 3464,
#          '10,': 3462,
#          'told': 3452,
#          'metal': 3443,
#          '5,': 3442,
#          'here': 3437,
#          'blood': 3436,
#          'something': 3432,
#          'production': 3431,
#          'front': 3431,
#          '6,': 3424,
#          'chemical': 3422,
#          '20th': 3422,
#          '11,': 3420,
#          '16,': 3406,
#          '1997': 3402,
#          'model': 3398,
#          'style': 3397,
#          'awarded': 3394,
#          'smaller': 3393,
#          'parents': 3392,
#          'senate': 3390,
#          'tried': 3382,
#          'voice': 3381,
#          'kansas': 3379,
#          'coach': 3377,
#          'longer': 3376,
#          'washington': 3375,
#          'possible': 3370,
#          '2018,': 3368,
#          '20,': 3363,
#          'range': 3361,
#          'plant': 3358,
#          'services': 3358,
#          '1993': 3355,
#          'case': 3351,
#          'designed': 3350,
#          'street': 3348,
#          '18,': 3348,
#          '""': 3348,
#          'presidential': 3339,
#          '8,': 3339,
#          'austrian': 3331,
#          'van': 3330,
#          '2017,': 3329,
#          'artist': 3328,
#          'keep': 3318,
#          'described': 3317,
#          'people,': 3312,
#          'oldest': 3310,
#          'valley': 3307,
#          '9,': 3306,
#          '13,': 3305,
#          'mayor': 3304,
#          'throughout': 3303,
#          'fight': 3294,
#          '(,': 3291,
#          'distributed': 3278,
#          'my': 3275,
#          'novel': 3271,
#          'festival': 3269,
#          'climate': 3267,
#          'ireland': 3267,
#          'northwest': 3239,
#          '17,': 3229,
#          '14,': 3225,
#          'discovered': 3209,
#          'border': 3206,
#          'happened': 3200,
#          'square': 3199,
#          'action': 3198,
#          'release': 3192,
#          'territory': 3190,
#          '29': 3190,
#          'low': 3188,
#          'traditional': 3188,
#          'ground': 3187,
#          'brought': 3186,
#          'fish': 3184,
#          'saw': 3182,
#          'data': 3176,
#          'news': 3173,
#          'commonly': 3173,
#          'numbers': 3169,
#          'ran': 3168,
#          'bank': 3168,
#          'assembly': 3166,
#          'culture': 3150,
#          '1991': 3147,
#          'round': 3141,
#          'gets': 3140,
#          'wrestling': 3139,
#          'stadium': 3133,
#          'amount': 3132,
#          'features': 3132,
#          '"a': 3125,
#          'believe': 3125,
#          'lee': 3120,
#          'leading': 3115,
#          'starring': 3112,
#          'soldiers': 3111,
#          '21,': 3109,
#          'beginning': 3107,
#          'upper': 3105,
#          'starting': 3102,
#          '1990': 3101,
#          'louis': 3099,
#          'grew': 3097,
#          '19,': 3092,
#          'congress': 3091,
#          'larger': 3089,
#          'process': 3080,
#          'mountains': 3079,
#          'this,': 3078,
#          'opera': 3077,
#          'organization': 3073,
#          'design': 3061,
#          '22,': 3056,
#          'create': 3055,
#          'matches': 3054,
#          'religious': 3052,
#          '23,': 3052,
#          '25,': 3051,
#          'pictures': 3049,
#          '27,': 3048,
#          '2007,': 3047,
#          'your': 3044,
#          '26,': 3043,
#          'higher': 3039,
#          'are:': 3027,
#          'foreign': 3025,
#          'ocean': 3023,
#          '24,': 3021,
#          'available': 3020,
#          'olympic': 3017,
#          'board': 3015,
#          'bridge': 3013,
#          '2022,': 3002,
#          'size': 2998,
#          'emperor': 2995,
#          'refer': 2993,
#          'edward': 2992,
#          'nations': 2988,
#          'followed': 2985,
#          'producer': 2983,
#          '28,': 2983,
#          ...})

# %%
unigram_counts = {k: v for k,v in c.items() if v>1} # also freq filter: each word should appear at least twice

# %%
# A set of words with unigram counts
vocab = set([k for k,v in c.items() if v>1])

# %%
bigram_counts = {v: defaultdict(int) for v in vocab} #takes few seconds

# %%
# Takes some time (a minute maybe)
for i in tqdm.tqdm(range(len(corpus)-1)):
    x1, x2 = corpus[i], corpus[i+1]
    # Check if x1 and x2 are in vocab and if they are increase bigram_couts[x1][x2] by 1
    # Your Code here
    if x1 in vocab and x2 in vocab:
        bigram_counts[x1][x2] += 1
# Out:
# 100%|██████████| 31756751/31756751 [00:27<00:00, 1137569.34it/s]

# %%
bigram_counts
# Out:
# {'': defaultdict(int,
#              {'<eos>': 74687,
#               'for': 22,
#               'around': 3,
#               '': 924,
#               'earth': 2,
#               'it': 813,
#               'we': 14,
#               'the': 1524,
#               '→': 1,
#               'people': 12,
#               '"': 9,
#               'increases': 1,
#               'this': 245,
#               '-': 13,
#               'mediawiki': 1,
#               'both': 13,
#               'mercury': 1,
#               'mariner': 1,
#               'several': 6,
#               'however,': 29,
#               'summers': 1,
#               'new': 5,
#               'honolulu,': 1,
#               'platonic': 1,
#               'because': 17,
#               'its': 164,
#               'seven': 2,
#               'in': 309,
#               'scientists': 4,
#               'they': 158,
#               '3': 5,
#               '0': 4,
#               'at': 66,
#               'herodotus': 1,
#               '/': 1,
#               'that': 26,
#               'he': 383,
#               'using': 3,
#               'more': 8,
#               'german': 1,
#               'vladimir': 1,
#               "moscow's": 2,
#               'moscow': 1,
#               'los': 2,
#               'tags': 1,
#               'during': 15,
#               'everton': 1,
#               'previous': 1,
#               '•': 1,
#               'lumps': 1,
#               'with': 29,
#               'mount': 2,
#               'an': 13,
#               'here': 5,
#               'cnn': 1,
#               'alberta': 1,
#               'most': 25,
#               'a': 52,
#               'electric': 1,
#               'today': 3,
#               'and': 28,
#               'former': 2,
#               'low': 1,
#               'medium-level': 1,
#               'vertical': 1,
#               'george': 3,
#               'tom,': 1,
#               'been': 2,
#               'her': 20,
#               'ph': 1,
#               'on': 43,
#               'january': 2,
#               'these': 38,
#               'eyes,': 1,
#               'she': 131,
#               'some': 26,
#               'since': 15,
#               'august': 1,
#               'is': 38,
#               'today,': 5,
#               'large': 2,
#               'females': 15,
#               'mature': 1,
#               'oxygen': 1,
#               'there': 131,
#               'sources': 1,
#               'means': 2,
#               'liberation': 1,
#               'louisiana': 2,
#               'cartier': 1,
#               'season': 58,
#               'of': 265,
#               'other': 16,
#               'gorbachev': 1,
#               'casting': 1,
#               'trying': 1,
#               'reformation': 1,
#               "jehovah's": 1,
#               'their': 31,
#               'belarus': 1,
#               '(which': 1,
#               'his': 33,
#               'sealand': 1,
#               "alabama's": 1,
#               'temperatures': 2,
#               'bremen': 1,
#               'about': 18,
#               "it's": 10,
#               'spring': 1,
#               'nesmith': 1,
#               'as': 63,
#               'others': 7,
#               'mineralogists': 1,
#               'mandate': 1,
#               '()': 4,
#               'thousands': 1,
#               "croatia's": 1,
#               "chad's": 1,
#               'freezers': 1,
#               'arctic': 1,
#               'humidity': 1,
#               'high': 1,
#               'saying': 2,
#               '"later': 1,
#               'to': 31,
#               'was': 23,
#               'iowa': 1,
#               'congress': 1,
#               'nations"': 1,
#               'rifles': 1,
#               'another': 3,
#               'older': 1,
#               'before': 13,
#               'theophrastus': 1,
#               'libya': 1,
#               'oklahoma': 1,
#               'winters': 4,
#               'until': 4,
#               'reason': 1,
#               '[and]': 3,
#               "franklin's": 1,
#               'newcastle': 1,
#               'summer': 2,
#               'foreign': 1,
#               'stood': 1,
#               'mongolia': 1,
#               'land': 1,
#               'tropical': 3,
#               '9': 1,
#               '6': 1,
#               'much': 2,
#               'measurable': 1,
#               'wichita': 1,
#               '(chorus)': 1,
#               'de': 2,
#               'burkina': 1,
#               'five': 2,
#               'longboard': 1,
#               '15': 1,
#               'emperor': 1,
#               'every': 6,
#               'snowfall': 1,
#               'averages': 1,
#               'wolverines': 1,
#               'after': 54,
#               '=': 1,
#               'print': 1,
#               'f1': 1,
#               'guillotin': 1,
#               'svalbard': 1,
#               'suppose': 1,
#               'eleven': 2,
#               'like': 9,
#               'each': 8,
#               'if': 21,
#               '[due': 1,
#               'highlights': 1,
#               'possibly': 1,
#               '(for': 1,
#               'two': 6,
#               'khartoum': 1,
#               'karma': 1,
#               'but': 18,
#               'scotty': 1,
#               'general': 4,
#               'get': 7,
#               'selene': 1,
#               'joe': 2,
#               'four': 2,
#               'toyota': 1,
#               'together,': 1,
#               'helena': 1,
#               'constantine': 2,
#               '(': 1,
#               'sometimes,': 3,
#               'snow': 1,
#               'railways': 1,
#               'lava': 1,
#               'pajamas': 1,
#               'did': 10,
#               'formula_7,': 1,
#               'next': 3,
#               'helplessness': 1,
#               '[that': 2,
#               'somewhere': 1,
#               'sexual': 1,
#               'first': 3,
#               'rachmaninoff': 1,
#               '"(let\'s': 1,
#               'males': 7,
#               'flowing': 2,
#               'now,': 1,
#               'thor': 1,
#               'referees': 1,
#               'dr': 2,
#               'one': 13,
#               'making': 1,
#               'borzois': 1,
#               'has': 4,
#               'taken': 1,
#               'whispered': 1,
#               "loki's": 1,
#               'many': 17,
#               'by': 9,
#               'then)': 1,
#               'instead': 1,
#               "there's": 2,
#               'apres': 1,
#               'so': 9,
#               'lenses': 1,
#               'annie': 1,
#               'excluded': 1,
#               'fossils': 1,
#               '"-"': 1,
#               'host': 1,
#               'everywhere': 1,
#               '[find': 2,
#               'who': 7,
#               'feces': 1,
#               'yet': 1,
#               'mal': 1,
#               'accounts': 1,
#               'nero': 1,
#               'sevan': 1,
#               'usually': 2,
#               'also': 7,
#               'officials': 1,
#               'capital': 1,
#               'there,': 3,
#               'no': 6,
#               'when': 37,
#               'well': 1,
#               'schubert': 1,
#               'historically,': 1,
#               'not': 4,
#               'concussions': 1,
#               "n'djamena": 1,
#               'according': 20,
#               'gazi': 1,
#               'čair': 1,
#               'butel': 1,
#               'gjorče': 1,
#               'college': 1,
#               'towns': 1,
#               'female': 2,
#               'music': 1,
#               'mozart': 1,
#               'thus': 2,
#               '"9"': 1,
#               'old': 2,
#               'instead,': 1,
#               'however': 4,
#               "moon's": 1,
#               'diocletian': 1,
#               'ü': 1,
#               'nautilus': 1,
#               'neither': 1,
#               'hirohito': 1,
#               'melkonian': 1,
#               'killed': 1,
#               'approximately': 1,
#               'have': 3,
#               'even': 6,
#               'team': 4,
#               'gerry': 1,
#               'cdf': 1,
#               'together': 4,
#               'volume': 1,
#               'i': 22,
#               'caprivi': 1,
#               'multiple': 1,
#               'lack': 1,
#               'population': 1,
#               'city': 2,
#               'use': 3,
#               '"2': 1,
#               'currently,': 1,
#               'zu': 1,
#               'almost': 5,
#               '2,000,000': 1,
#               'hurling': 1,
#               'lee': 1,
#               'although': 13,
#               'checkpoint': 1,
#               'between': 5,
#               'won': 5,
#               'aalborg': 1,
#               'driver': 4,
#               'which': 1,
#               'while': 9,
#               'fiction': 1,
#               'oceans,': 1,
#               '*': 7,
#               '"yellow': 2,
#               'meldorf': 1,
#               'public': 2,
#               'seyß-inquart': 1,
#               '92%': 1,
#               'eventually,': 1,
#               'gary': 1,
#               'getting': 1,
#               'three': 2,
#               'any': 3,
#               'port-au-prince,': 1,
#               'overall': 1,
#               'non-building': 1,
#               'hundreds': 1,
#               'having': 2,
#               'clio': 1,
#               'played': 1,
#               'clara': 1,
#               'from': 46,
#               'average': 2,
#               'karakalpakstan': 1,
#               'mayhew': 1,
#               '"also': 1,
#               'mazur': 1,
#               'villiers': 1,
#               'out': 2,
#               'american': 2,
#               'now': 2,
#               'only': 4,
#               'japanese': 1,
#               'workers': 1,
#               'bede': 1,
#               'bullfrogs': 1,
#               'male': 3,
#               '[his]': 1,
#               'charles': 1,
#               'carteret': 1,
#               '(1)': 2,
#               '1985,': 1,
#               'despite': 8,
#               'woven': 1,
#               'kochi': 1,
#               'palembang': 1,
#               'hamilton': 1,
#               'manora': 1,
#               'clemens': 1,
#               'hurtova': 1,
#               'mexican': 1,
#               'doak': 1,
#               'italian': 1,
#               'muttalib': 1,
#               '"girl,': 1,
#               'siachen': 1,
#               'work': 2,
#               'pir': 1,
#               'cd': 3,
#               'very': 3,
#               'karimabad': 1,
#               'picasa': 1,
#               'bazaar': 1,
#               'over': 3,
#               'wounded': 1,
#               'shelf': 1,
#               'various': 1,
#               '2006:': 1,
#               'pakistan': 1,
#               '(right-handed)': 1,
#               'above': 2,
#               'early': 2,
#               'orthodox': 1,
#               '(4)': 1,
#               '(5)': 4,
#               '(14)': 1,
#               '(3)': 3,
#               '(17)': 1,
#               '(20)': 1,
#               '(12)': 1,
#               'already': 1,
#               '(9)': 4,
#               '(15)': 1,
#               '(7)': 2,
#               'reads': 1,
#               '(8)': 1,
#               '(11)': 1,
#               'october': 1,
#               'july': 2,
#               'all': 209,
#               'ikev2': 1,
#               'prairie': 1,
#               'phetchabun': 1,
#               'updates': 1,
#               'therefore,': 1,
#               'heaton': 1,
#               'may': 2,
#               '--': 3,
#               'rips': 1,
#               'reproduction': 1,
#               '|': 2,
#               '(or': 23,
#               'jens': 1,
#               'drivers': 2,
#               "paterson's": 1,
#               'channels': 1,
#               'twenty-seven': 1,
#               'famous': 1,
#               'weatherford': 1,
#               '422': 1,
#               "germany's": 1,
#               'nicolae': 1,
#               'producers': 1,
#               '"disney\'s': 1,
#               'probably': 1,
#               'vendetta': 1,
#               'ss-obergruppenfuhrer': 1,
#               'hans': 2,
#               'aesthetic': 1,
#               'rifled': 1,
#               'ernst': 1,
#               'eg': 1,
#               'active': 1,
#               'boldface': 1,
#               'localization': 1,
#               'lilo': 1,
#               'pico': 3,
#               '"positif"': 1,
#               'knight:': 1,
#               'mexico': 1,
#               '(2)': 3,
#               'japan': 2,
#               'undefeated': 1,
#               'besides': 1,
#               'ibn': 1,
#               'without': 1,
#               '"e': 1,
#               'hansard': 1,
#               'leaves': 1,
#               'east': 1,
#               'tpl': 1,
#               'singers': 1,
#               "constructors'": 2,
#               '–': 3,
#               'just': 2,
#               'plan': 1,
#               'juan': 1,
#               'kim': 2,
#               'lukáš': 2,
#               'serena': 1,
#               'carly': 1,
#               'bernard': 1,
#               'heather': 1,
#               'marton': 1,
#               'valeria': 1,
#               'shingo': 2,
#               'esther': 3,
#               'stephane': 1,
#               'korie': 1,
#               'peter': 1,
#               'nick': 2,
#               'preko': 1,
#               '(players': 1,
#               'bonney': 1,
#               'within': 1,
#               'fennec': 1,
#               'khufu': 1,
#               'lask': 1,
#               'spent': 1,
#               'modern': 3,
#               'internationally,': 1,
#               'shows': 1,
#               'gluck’s': 1,
#               'alaska,': 1,
#               'hawaii,': 1,
#               'measured': 1,
#               'bruce': 2,
#               'sally': 1,
#               'immediately': 1,
#               'includes': 2,
#               'built': 1,
#               'wikimedia': 2,
#               'sundew': 1,
#               'mohammad': 1,
#               'can': 2,
#               'half': 1,
#               '90%': 1,
#               'are': 5,
#               'someone': 1,
#               'consonants': 1,
#               'good;': 1,
#               'plot"': 1,
#               'melodrama,': 1,
#               "white's": 1,
#               'epicurus': 1,
#               'usually,': 1,
#               'inadequate': 1,
#               '[laughs]': 1,
#               'haber': 1,
#               'usgs': 1,
#               'tyson': 1,
#               'hope': 1,
#               'rainfall': 2,
#               '||': 1,
#               'tsunayoshi': 1,
#               '(last': 40,
#               'pluto': 1,
#               'dadyal': 1,
#               '945': 1,
#               'ssv': 1,
#               'karim': 1,
#               'soviet': 1,
#               'gagarin': 1,
#               'iihf': 1,
#               'meanwhile,': 2,
#               'israel': 2,
#               'desert': 1,
#               'cena': 1,
#               'boston': 1,
#               'extremes': 1,
#               'once': 5,
#               'powered': 1,
#               'irene': 1,
#               'vernon': 1,
#               'following': 3,
#               'haugesund,': 2,
#               'mercedes-benz,': 1,
#               'under': 3,
#               'heidfeld': 1,
#               'sonic': 1,
#               'tabitha': 1,
#               'zuko': 1,
#               'protagonists': 1,
#               'otherwise': 1,
#               'valencia': 1,
#               'shōnan-shinjuku': 1,
#               'antigua': 1,
#               'rainfalls': 1,
#               'part': 5,
#               'scored': 1,
#               'then': 20,
#               'engines': 1,
#               'cosworth': 1,
#               'winds': 1,
#               'le': 1,
#               '"the': 2,
#               'cobalt(ii)': 1,
#               'luigi': 1,
#               'also,': 2,
#               'argentine': 1,
#               'shared': 1,
#               'abstract': 2,
#               'go-karts': 1,
#               'tony': 1,
#               'supposing': 1,
#               'competed': 1,
#               'placing': 1,
#               'winner': 1,
#               'health': 1,
#               'rafael': 1,
#               'bob': 1,
#               'vania': 1,
#               'liezel': 1,
#               'jack': 1,
#               'daria': 1,
#               'duilio': 1,
#               'tímea': 1,
#               'maikel': 1,
#               'david': 2,
#               'my': 3,
#               '”': 1,
#               "california's": 1,
#               'progress': 1,
#               '"mussaurus"': 1,
#               'men': 1,
#               'larger': 1,
#               'midseason': 1,
#               'z': 1,
#               'be': 2,
#               'certain': 2,
#               'would': 1,
#               'sometimes': 3,
#               'actuated': 1,
#               'robin': 1,
#               'petra': 1,
#               'alisa': 1,
#               'montgomery': 1,
#               'recent': 1,
#               'nanmadol': 1,
#               'soon': 3,
#               'strong': 1,
#               "joannie's": 1,
#               'growing': 1,
#               'rochette': 3,
#               'ivory': 1,
#               'next,': 3,
#               'counter-strike:': 1,
#               'oxpeckers': 1,
#               'hundertwasser': 1,
#               'colour': 1,
#               'karun': 1,
#               'alexander': 1,
#               'unwilling': 1,
#               'electronic': 1,
#               'logging': 1,
#               'six': 2,
#               'twelve': 1,
#               '(2001': 1,
#               'initially': 1,
#               'common': 1,
#               'marfa': 1,
#               'walburga': 1,
#               'hudson': 1,
#               'bomis': 1,
#               'bill': 2,
#               'considerable': 1,
#               'lizard': 1,
#               ',': 12,
#               'rahm': 1,
#               'had': 1,
#               '1995': 2,
#               "contestant's": 1,
#               "aurelian's": 1,
#               'closed': 1,
#               'winslow': 1,
#               'compares': 1,
#               'later': 7,
#               'weighing': 1,
#               'pups': 1,
#               'maturity': 1,
#               'bmw': 1,
#               'sauber,': 1,
#               'russian': 1,
#               'ichinoseki': 1,
#               'tamil': 1,
#               'afterwards,': 1,
#               'alveolar': 1,
#               'confident': 1,
#               'fernanda': 1,
#               'hasekura': 1,
#               'annual': 2,
#               'record': 1,
#               'or': 3,
#               'recommends': 1,
#               "stewart's": 1,
#               '(sc': 1,
#               'ocala': 1,
#               'so,': 1,
#               'amphibians': 1,
#               'beats': 1,
#               'remodelling': 1,
#               'fusa': 1,
#               'area': 1,
#               'airport': 4,
#               'atmospheric': 1,
#               'bundi': 1,
#               'deoli': 1,
#               'burns': 1,
#               'douglas': 1,
#               'films': 1,
#               'manet': 1,
#               'oppuurs': 1,
#               'grisi': 1,
#               '[the': 1,
#               'treats': 1,
#               "go-kōgon's": 2,
#               'but,': 1,
#               'engineers': 1,
#               'curious,': 1,
#               'returns;': 1,
#               'arching': 1,
#               'glen': 1,
#               'spasmodic': 1,
#               'should': 1,
#               'shophouses': 1,
#               '""': 1,
#               "kōgon's": 3,
#               "go-komatsu's": 2,
#               'ships': 1,
#               'near': 3,
#               'pound': 1,
#               ':': 2,
#               'listed': 1,
#               'hare': 1,
#               'south': 1,
#               'changes': 1,
#               'ic': 1,
#               'close': 1,
#               "anita's": 1,
#               'norman': 1,
#               '("': 1,
#               'yoshitsune': 1,
#               'bear': 1,
#               'amar': 1,
#               'india': 27,
#               'cox': 1,
#               'päijänne': 1,
#               'kallavesi': 1,
#               'nb': 1,
#               'alternatively,': 1,
#               'depressed,': 1,
#               'cao': 1,
#               'karimganj': 1,
#               'elizabeth\xa0': 1,
#               'suddenly': 1,
#               'seems': 1,
#               'act': 1,
#               'dipstick': 1,
#               'st': 1,
#               'berlioz': 1,
#               '[and': 1,
#               'historical': 1,
#               '"and': 1,
#               'sign': 1,
#               'tjuntjuntjara': 1,
#               'lead': 1,
#               'amanda': 1,
#               'calahorra': 1,
#               'william': 1,
#               'television': 1,
#               'premios': 1,
#               'estimated': 1,
#               'skiers': 1,
#               'top': 1,
#               'well,': 1,
#               'neighbouring': 2,
#               'severe': 1,
#               'based': 2,
#               'barnum': 1,
#               'will': 2,
#               'how': 2,
#               'along': 2,
#               'hgnc': 1,
#               'halti': 1,
#               'repairing': 1,
#               'permission': 1,
#               'pollux': 1,
#               'geoffrey': 1,
#               '[stephen]': 1,
#               'hibernians': 1,
#               'birkirkara': 2,
#               'wright': 1,
#               'baldwin': 1,
#               'your': 1,
#               'clone': 1,
#               '\xa0': 3,
#               'rain': 1,
#               'mika': 1,
#               'ealdormen': 1,
#               'sixteen': 1,
#               'cage': 1,
#               'cenwalh,': 1,
#               'touring': 2,
#               'were': 2,
#               'octene': 1,
#               'cold': 1,
#               'total:': 1,
#               'members': 1,
#               'burgess': 1,
#               'nothing': 2,
#               '(short': 1,
#               'tenants': 1,
#               'marcia': 1,
#               '"lexington"': 1,
#               'j': 1,
#               'works': 1,
#               'matilda': 1,
#               'medieval': 1,
#               'alassane': 1,
#               '",': 1,
#               "we're": 1,
#               'x-ray': 1,
#               'oswald': 1,
#               'inside': 1,
#               'poi': 1,
#               'bergström': 1,
#               '(1877)': 1,
#               'unfortunately,': 2,
#               'scalise': 1,
#               "'high": 1,
#               'agent': 1,
#               't': 1,
#               'retrieved': 6,
#               'pulbah': 1,
#               'federation"': 1,
#               'orange': 1,
#               'demotic': 1,
#               "'well,": 1,
#               'extended': 1,
#               'do': 3,
#               'katy': 2,
#               'cartoons': 1,
#               'such': 3,
#               'limited': 1,
#               '"matica': 1,
#               'yamato': 1,
#               'sei': 1,
#               'depending': 1,
#               'bellvale': 1,
#               'stretching': 1,
#               'cen': 1,
#               'walter': 1,
#               "canada's": 1,
#               'jdam-equipped': 1,
#               'riders': 1,
#               'maha': 1,
#               'forgiveness': 1,
#               'broccoli': 1,
#               '2000': 1,
#               'air': 1,
#               'ironically': 1,
#               'unlike': 4,
#               'populists': 1,
#               'kratos': 1,
#               'strangely': 1,
#               'irises': 1,
#               'borussia': 1,
#               'bełżec': 1,
#               'words': 1,
#               'dangi': 1,
#               'wrangel': 1,
#               'into': 1,
#               'farnes': 1,
#               'denotes': 1,
#               'throughout': 3,
#               'announced': 1,
#               "'": 1,
#               'back': 1,
#               'drums': 1,
#               'fifteen': 1,
#               'statutes': 1,
#               'champions\xa0\xa0': 5,
#               '"new': 1,
#               'technology': 1,
#               'skyrim': 1,
#               'major': 2,
#               'immature': 1,
#               '[but': 1,
#               'desktop': 1,
#               'tied': 1,
#               'rights': 1,
#               '[we]': 1,
#               '<br>': 2,
#               'eighth': 1,
#               'literature"': 1,
#               'pre-war': 1,
#               'byun': 1,
#               'yugoslav': 2,
#               'playing': 1,
#               '1993': 2,
#               '"vigilant",': 1,
#               'williams': 1,
#               'you': 3,
#               'natalya': 1,
#               'vegetables': 1,
#               'total': 1,
#               'lake': 1,
#               'full': 1,
#               'kneževo': 1,
#               'void': 1,
#               'lodève': 1,
#               'still': 1,
#               'gasoline"': 1,
#               'analysis': 1,
#               'fish': 1,
#               'history': 1,
#               'khas': 1,
#               'rock': 1,
#               'turnout': 4,
#               'jarek': 1,
#               'hyderabad': 1,
#               'lavery': 1,
#               '[he]': 1,
#               'sanders': 1,
#               'levin,': 1,
#               'designed': 1,
#               '"my': 1,
#               'player': 4,
#               'paradiso': 1,
#               'nandini,': 1,
#               'aya': 1,
#               'majursahi': 1,
#               'phoksundo': 1,
#               'jenkins': 1,
#               '135': 1,
#               'census': 1,
#               'ksrtc': 1,
#               'irrespective': 1,
#               'put': 1,
#               '2014': 1,
#               'space': 1,
#               'classmates': 1,
#               'attracted': 1,
#               'manoj': 1,
#               'composed': 1,
#               'mull': 1,
#               '(19)': 1,
#               'nasa': 1,
#               'kids': 1,
#               'though': 1,
#               'across': 1,
#               'storm': 1,
#               'damage': 1,
#               'parks': 1,
#               'mcmillan': 1,
#               'underwood': 1,
#               'cantwell': 1,
#               'good': 1,
#               'tempted': 1,
#               '(a': 1,
#               'nikolai': 1,
#               'keetmanshoop': 1,
#               'susanna': 1,
#               'chicago': 1,
#               'ishi': 1,
#               'opening': 1,
#               'schonberg': 1,
#               'bird"': 1,
#               'economic': 1,
#               'nova': 1,
#               'sheppard': 1,
#               'indicates': 2,
#               'pagasa': 1,
#               'nominations': 1,
#               '"as': 1,
#               'back-flip': 1,
#               'formal': 1,
#               'johnson': 1,
#               'green': 1,
#               'recently': 1,
#               "acastus's": 1,
#               'norton': 1,
#               'roarke': 1,
#               'vaillant': 1,
#               'lekima': 1,
#               "lekima's": 1,
#               'institutional': 1,
#               'jiří': 1,
#               'arceo': 1,
#               'shifted': 1,
#               'jethmalani': 1,
#               'partaking': 1,
#               'armonk': 1,
#               'west': 1,
#               'tornado': 1,
#               'thanks': 1,
#               '(continue': 1,
#               'ifugao': 1,
#               'howard': 1,
#               'semjonova': 1,
#               'buru': 1,
#               'inge': 1,
#               'catherine': 1,
#               'rashford': 1,
#               'bieber': 1,
#               'marand': 1,
#               'm’baku': 1,
#               'magar,': 1,
#               '(04%)': 1,
#               'names': 10,
#               'siberia': 1,
#               'far': 1,
#               'sverdlovsk': 1,
#               'idel-ural': 1,
#               'nenetsia': 1,
#               'kuban': 1,
#               'lenard': 1,
#               'september': 2,
#               'mud': 1,
#               'richeze': 1,
#               'fernando': 1,
#               'ekland': 1,
#               'arnous': 1,
#               '870%': 1,
#               '953%': 1,
#               '951%': 1,
#               '762%': 1,
#               '915%': 1,
#               '881%': 1,
#               '988%': 1,
#               '794%': 1,
#               '902%': 1,
#               '928%': 1,
#               'puttur': 1,
#               '"she"': 1,
#               'marlenee': 1,
#               'australian': 2,
#               '(6)': 2,
#               "won't": 1,
#               'norway': 1,
#               ...}),
#  'arnette': defaultdict(int, {'"missy"': 1, 'jens': 1}),
#  '(islam)': defaultdict(int, {'<eos>': 3}),
#  'al-jazeera': defaultdict(int,
#              {'channel': 1,
#               'does': 1,
#               'the': 1,
#               'university': 1,
#               'in': 1,
#               'while': 1,
#               'for': 1,
#               '<eos>': 1}),
#  '"diario"': defaultdict(int, {'wrote': 1, 'has': 1}),
#  'krang,': defaultdict(int, {'and': 1, 'casey': 1, 'bebop': 1}),
#  'spurgeon': defaultdict(int,
#              {'<eos>': 4,
#               '(19': 1,
#               'preached': 2,
#               'would': 2,
#               'than': 1,
#               'was': 7,
#               'suffered': 1,
#               'his': 1,
#               'read': 2,
#               'knew': 1,
#               'became': 2,
#               'being': 1,
#               'had': 2,
#               'got': 1,
#               'by': 1,
#               'liked': 1,
#               'never': 1,
#               'spurgeon': 1,
#               'gave': 1,
#               'later': 1,
#               'wrote': 1,
#               'used': 1,
#               'meant': 1,
#               'spoke': 1,
#               'to': 1,
#               'did': 1,
#               'in': 2,
#               'started': 1,
#               'library': 3,
#               'he': 1,
#               '(20': 1,
#               'it': 1,
#               '(december': 1,
#               'died': 1,
#               'bloxom': 1,
#               'is': 1}),
#  "bc's": defaultdict(int, {'demographic': 1, 'location': 1}),
#  'cohí': defaultdict(int,
#              {'<eos>': 1, 'fornell': 1, 'raced': 1, 'has': 1, 'skied': 1}),
#  'rabin': defaultdict(int,
#              {'was': 9,
#               '<eos>': 4,
#               '(march': 1,
#               'and': 5,
#               'became': 1,
#               'he': 1,
#               'medical': 1,
#               'it': 1,
#               'on': 1,
#               'because': 1,
#               'government': 1,
#               'in': 4,
#               '"for': 2,
#               'haber': 1,
#               'sent': 1,
#               'respectively,': 1,
#               'happened': 1,
#               'walked': 1,
#               'with': 1,
#               'took': 1,
#               'from': 1,
#               'cabinets': 1,
#               'square,': 1,
#               '(born': 1,
#               'married': 1,
#               'has': 1,
#               'koirala': 2}),
#  'arguments': defaultdict(int,
#              {'in': 19,
#               'from': 4,
#               'are': 8,
#               'for': 20,
#               'against': 14,
#               'conclusions': 1,
#               'between': 28,
#               '<eos>': 12,
#               'about': 32,
#               'among': 4,
#               '': 3,
#               'and': 15,
#               'with': 18,
#               'make': 1,
#               'of': 5,
#               'such': 4,
#               'on': 5,
#               'these': 2,
#               'over': 4,
#               'that': 7,
#               'or': 4,
#               'start': 1,
#               'several': 1,
#               'he': 3,
#               'based': 1,
#               'revealing': 1,
#               'can': 5,
#               'may': 1,
#               'it': 3,
#               'to': 12,
#               'as': 4,
#               'by': 2,
#               'because': 3,
#               'promoting': 1,
#               'made': 4,
#               'almost': 1,
#               'wer': 1,
#               'was': 2,
#               'were': 4,
#               'fielded': 1,
#               'they': 4,
#               'an': 2,
#               'another': 1,
#               'within': 3,
#               'after': 1,
#               'eg': 1,
#               'had': 1,
#               'alistair': 1,
#               'also': 1,
#               'clearly': 1,
#               'supporting': 2,
#               'which': 1,
#               'used': 1,
#               'hold': 1,
#               'kristen': 1,
#               'at': 1,
#               'the': 6,
#               'anne': 1,
#               'home,': 1,
#               'economists': 1,
#               'a': 1,
#               'into': 1,
#               'caused': 1,
#               'both': 1,
#               'this': 1,
#               'many': 1,
#               'have': 1,
#               'during': 1,
#               'coming': 1,
#               'most': 1,
#               'must': 1,
#               'pointed': 1,
#               'applied': 1,
#               'apparently': 1,
#               'is': 1,
#               'then': 1,
#               'similar': 1,
#               'instead': 1,
#               'do': 1,
#               'but': 1,
#               'she': 1,
#               'there': 1,
#               'become': 1,
#               'eleaticism': 1}),
#  'baudette,': defaultdict(int, {'minnesota)': 1, 'minnesota': 1}),
#  '(recent': defaultdict(int, {'research': 1}),
#  'ansbert': defaultdict(int, {'or': 1, 'was': 1}),
#  'rasmussen': defaultdict(int,
#              {'reports': 4,
#               'poll,': 1,
#               'rasmussen': 1,
#               'had': 1,
#               '<eos>': 7,
#               '(born': 1,
#               'as': 1,
#               'was': 2,
#               'has': 1,
#               'college,': 1,
#               'in': 1,
#               'he': 1,
#               '(22': 1,
#               '(;': 2,
#               'is': 1,
#               'global': 1,
#               '(,': 1,
#               'from': 1,
#               '(7': 1}),
#  'raid"': defaultdict(int,
#              {'this': 1,
#               'in': 1,
#               'happened': 1,
#               "morgan's": 1,
#               'by': 1,
#               '(1962),': 1,
#               'was': 1}),
#  'curiel': defaultdict(int,
#              {'(guitar': 1, 'described': 1, '<eos>': 1, '(22': 1, 'died': 1}),
#  'gagnef': defaultdict(int, {'municipality': 3, '<eos>': 2, 'is': 1}),
#  'gleijer': defaultdict(int, {'until': 1, '': 1}),
#  'helper;': defaultdict(int, {'and': 1, 'earl': 1}),
#  'monthiers': defaultdict(int, {'<eos>': 1, 'is': 1}),
#  '1,400': defaultdict(int,
#              {'mw': 1,
#               'miles': 1,
#               'lakes': 1,
#               'grams)': 1,
#               'years': 2,
#               'species': 4,
#               'm': 1,
#               'meters': 2,
#               'tonnes': 1,
#               'people': 10,
#               'spectators': 1,
#               'surrounding': 1,
#               'others': 1,
#               'branches': 1,
#               'km': 1,
#               'faculty': 1,
#               'units': 1,
#               'acres,': 1,
#               '<eos>': 3,
#               'soldiers': 1,
#               'in': 1,
#               'of': 3,
#               'weekly': 1,
#               'students': 2,
#               'or': 1,
#               'bce': 1,
#               'cadets': 1,
#               'years,': 1,
#               'different': 1,
#               'flowering': 1,
#               'comanche': 1,
#               'seats': 1,
#               'employees': 1,
#               'authentic': 1,
#               'tons': 1,
#               'were': 1,
#               'parsecs': 1,
#               'feet': 1,
#               'movies': 1,
#               'residents,': 1,
#               'and': 1,
#               'votes': 1,
#               'to': 1,
#               'brands,': 1,
#               'locations': 1}),
#  'hachiman-gū': defaultdict(int, {'are': 1, '<eos>': 2, 'was': 1}),
#  'snow)': defaultdict(int,
#              {'in': 1, 'condition,': 1, 'as': 1, 'and': 1, 'is': 1}),
#  'champawat': defaultdict(int, {'district': 1, '<eos>': 1}),
#  'meconopsis': defaultdict(int, {'gakyidiana': 2}),
#  'loud!"': defaultdict(int, {'finale': 2, 'maddie': 1, 'ended': 1}),
#  'corrugated': defaultdict(int,
#              {'(also': 1,
#               'cardboard': 7,
#               'iron': 4,
#               'steel': 3,
#               'metal,': 1,
#               'boxes': 1,
#               'aluminum': 1,
#               'and': 1,
#               'metal': 5,
#               'curves,': 1}),
#  'yañez': defaultdict(int, {'(october': 1, '(september': 1}),
#  'guidance,': defaultdict(int,
#              {'they': 1,
#               'and': 3,
#               'such': 1,
#               'along': 1,
#               'she': 2,
#               'in': 1,
#               'inspiration': 1,
#               'the': 4,
#               'communication,': 1,
#               'clarifying': 1,
#               'he': 1,
#               'navigation': 1,
#               'develops': 1,
#               'wild': 1,
#               'especially': 1}),
#  "cixi's": defaultdict(int, {'rule': 1, 'influence,': 1}),
#  'geestemünde': defaultdict(int,
#              {'was': 1, 'and': 1, 'in': 1, 'at': 1, 'did': 1, 'to': 1}),
#  'saint-laurent-les-bains': defaultdict(int, {'<eos>': 1, 'is': 1, '(the': 1}),
#  'of)': defaultdict(int,
#              {'every': 2,
#               'all': 1,
#               'their': 2,
#               'for': 1,
#               'the': 17,
#               'they': 1,
#               'of': 1,
#               'with': 1,
#               '<eos>': 4,
#               '"two': 1,
#               'time"': 1,
#               'another': 1,
#               'files': 1,
#               'austria': 1,
#               'a': 5,
#               'bacteria': 1,
#               'by': 1,
#               'florence': 1,
#               'great': 1,
#               'sydney': 1,
#               'chefs': 1,
#               'and': 3,
#               'him,': 1,
#               'so': 1,
#               'it': 2,
#               'was': 1,
#               'this': 2,
#               'electron(s)': 1,
#               "breakin'": 1,
#               'buchenwald': 1,
#               'breasts': 1,
#               'nitrogen': 1,
#               'countries': 1,
#               'parts': 1,
#               'huntingdon': 1,
#               'moltke': 1,
#               '"20/20"': 1,
#               'chains': 1,
#               'or': 1,
#               'nana': 1,
#               'texel': 1,
#               'conservativism': 1,
#               'chemosynthesis': 1,
#               'countless': 1,
#               'allah;': 1,
#               'regions': 1,
#               'infantry': 1,
#               'trust': 1,
#               'greed",': 1,
#               'early': 1,
#               'out-of-date': 1,
#               'lyon': 1}),
#  'bell-like': defaultdict(int, {'sound': 1, 'drooping': 1}),
#  'chukwuemeka': defaultdict(int, {'ndubuisi': 1}),
#  'misses,': defaultdict(int,
#              {'so': 1, 'the': 1, 'she': 1, "it's": 1, 'or': 1}),
#  '(snrna)': defaultdict(int, {'join': 1, 'without': 1}),
#  'sneap': defaultdict(int, {'at': 1, '"is': 1}),
#  'koti': defaultdict(int, {'in': 2, 'takar': 2, 'communities': 1}),
#  'karan': defaultdict(int,
#              {'sharma': 1,
#               '&': 2,
#               'has': 3,
#               'new': 2,
#               '<eos>': 2,
#               '(born': 1,
#               'singh': 12,
#               'johar,': 4,
#               'johar': 16,
#               "johar's": 1,
#               'brar,': 2,
#               'brar': 2,
#               'vohra': 1,
#               'jotwani': 2,
#               'mehra,': 1,
#               'came': 1,
#               'to': 1,
#               'is': 1,
#               'gets': 1,
#               'supernatural': 1,
#               'ever': 1,
#               'kumar': 1,
#               'nath': 1,
#               'deol': 1,
#               'deol,': 1,
#               'soni': 1,
#               'was': 1,
#               'and': 1,
#               '(767': 1}),
#  'lumberjack': defaultdict(int,
#              {'is': 2,
#               '<eos>': 1,
#               'match,': 5,
#               'in': 3,
#               'match': 2,
#               'james': 1,
#               'joseph': 1,
#               'he': 1,
#               'until': 1,
#               'renamed': 1}),
#  'kidskin': defaultdict(int, {'(young': 1, 'many': 1, 'satin': 1}),
#  'von': defaultdict(int,
#              {'neumann': 25,
#               'hayek,': 3,
#               'goethe': 24,
#               'clausewitz': 11,
#               'bellingham': 1,
#               'erlach': 1,
#               'humboldt': 29,
#               'neumann,': 4,
#               'bismarck': 33,
#               'hindenburg': 23,
#               'mohl': 2,
#               'fallersleben': 4,
#               'westphalen,': 2,
#               'linné': 3,
#               'bora': 2,
#               'herder': 1,
#               'stein': 1,
#               'papen': 18,
#               'frisch': 9,
#               'goethe,': 4,
#               'struve': 6,
#               'lutz,': 1,
#               'richthofen,': 4,
#               'zeppelin,': 2,
#               'guericke': 4,
#               'tschermak': 6,
#               'hohenzollern,': 1,
#               'bismarck,': 10,
#               'otter,': 2,
#               'siemens)': 2,
#               'krafft-ebing,': 3,
#               'geyr': 2,
#               'rundstedt': 12,
#               "hayek's": 1,
#               'bismarck-schönhausen': 3,
#               'moltke': 6,
#               'meck': 7,
#               'willebrand': 2,
#               'fleischl-marxow': 1,
#               'blücher': 2,
#               'trapp': 15,
#               'trapp,': 2,
#               'zähringen': 1,
#               'soxhlet': 2,
#               'beust,': 3,
#               'detten,': 3,
#               'ribbentrop': 6,
#               'braun': 29,
#               'hardenberg': 1,
#               'list': 2,
#               'liebenfels': 2,
#               'karajan,': 6,
#               'gluck': 2,
#               'nürnberg"': 8,
#               'nűrnberg"': 2,
#               'bülow': 25,
#               "tschermak's": 3,
#               'weber,': 4,
#               'wallenstein': 2,
#               'schiller': 1,
#               'helmholtz': 8,
#               'amsberg,': 2,
#               'hofmann': 2,
#               'der': 53,
#               'weber': 16,
#               'frisch,': 1,
#               'bülow,': 6,
#               'baer': 2,
#               'siemens': 9,
#               '1899': 1,
#               'henselt': 2,
#               'dem': 18,
#               'vaihingen': 1,
#               'tschirnhaus': 4,
#               'hohenzollern;': 1,
#               'westen': 1,
#               'eichendorff': 3,
#               'volk': 1,
#               'hindenburg,': 6,
#               'neurath,': 2,
#               'krosigk': 9,
#               "hindenburg's": 1,
#               'romberg': 1,
#               'nürnberg': 3,
#               'tetzchner': 2,
#               'strassburg': 1,
#               'epp': 4,
#               'stauffenberg': 6,
#               'rothschild,': 1,
#               'strassburg,': 2,
#               'eschenbach,': 1,
#               'schleicher': 9,
#               'webern': 2,
#               'karajan': 23,
#               'richthofen': 8,
#               'karma': 1,
#               'berlichingen': 2,
#               'dohnányi': 2,
#               'anhalt': 1,
#               'tussle': 2,
#               'eschenbach': 2,
#               'habsburg': 7,
#               'köpenick"': 1,
#               'suppé': 2,
#               'caprivi': 3,
#               'berlin': 1,
#               'weizsäcker': 12,
#               "papen's": 5,
#               'papen,': 4,
#               'ludendorff': 2,
#               'grünberg,': 1,
#               'schwerin': 3,
#               'plettenberg': 1,
#               'simmern,': 1,
#               'cromvoirt': 2,
#               'sydow': 19,
#               'sydow,': 16,
#               'humboldt,': 2,
#               'colomb': 1,
#               'montfort': 1,
#               'braun,': 3,
#               'trott': 1,
#               'hassell': 1,
#               'werth': 1,
#               'dohnanyi': 4,
#               'knobelsdorff': 2,
#               'henneberg': 3,
#               'ziegesar': 2,
#               'raven': 1,
#               'colloredo,': 1,
#               'hayek': 2,
#               'moers': 2,
#               'mises': 7,
#               'bernstorff': 3,
#               'eckardt': 1,
#               'manstein': 2,
#               'laue': 1,
#               'hell': 3,
#               'beethoven,': 5,
#               'metternich': 3,
#               'manteuffel': 3,
#               "manteuffel's": 2,
#               'lüttwitz,': 1,
#               'hippel': 2,
#               'nägeli': 3,
#               'steiner': 1,
#               'steinbach': 1,
#               "braun's": 3,
#               'hohenheim': 1,
#               'schirach': 4,
#               'bingen,': 1,
#               'schmeling': 1,
#               'detten': 3,
#               'on': 1,
#               'sacher-masoch': 4,
#               'weizsäcker,': 3,
#               'liebig': 7,
#               'bohlen': 5,
#               'stradonitz': 2,
#               'lieben': 1,
#               'mises,': 5,
#               "goethe's": 3,
#               'saba"': 1,
#               'behring': 2,
#               'biron': 1,
#               'steiglitz': 2,
#               'weingartner,': 2,
#               'arent': 4,
#               'arendt': 1,
#               'zelewski': 2,
#               'zalewski,': 2,
#               'hohberg': 3,
#               'schill': 1,
#               'neurath': 6,
#               'epenstein': 2,
#               'blomberg': 2,
#               'eltz-rübenach': 2,
#               'erich': 7,
#               'thoma': 1,
#               'schubert': 1,
#               'weingartner': 1,
#               'brenner': 2,
#               'laudon,': 1,
#               "kleist's": 2,
#               'laban': 1,
#               'hutier': 1,
#               'magnus,': 1,
#               'krusenstern': 1,
#               'meck,': 1,
#               'rothbart': 3,
#               'sanders': 2,
#               'otter': 2,
#               'hofmannsthal': 1,
#               'koopa': 1,
#               'rothschild': 1,
#               'mespelbrunn,': 1,
#               'osten': 6,
#               'schlieffen': 2,
#               'zemlinsky,': 1,
#               'südland]': 2,
#               'd': 5,
#               'hofmann,': 2,
#               'kleist': 6,
#               "klein's": 1,
#               'lübeck': 3,
#               'huene': 2,
#               'habsburg,': 3,
#               'bruno': 1,
#               'bitter': 1,
#               'ossietzky': 6,
#               'bandel': 1,
#               'bibern': 1,
#               'nürnberg,': 1,
#               'thoma,': 1,
#               'berlin")': 1,
#               'seckendorff,': 1,
#               'wrangel': 2,
#               'békésy': 2,
#               'und': 6,
#               'beust': 8,
#               'hohenzollern': 2,
#               'horstenau': 2,
#               'steuben': 28,
#               'borneo': 1,
#               'arx': 3,
#               'holtzbrinck': 1,
#               'jankó': 3,
#               'trier': 9,
#               'eggers': 1,
#               'alt': 1,
#               'euler': 2,
#               'notre': 1,
#               'baeyer': 2,
#               'teese': 3,
#               'müller': 2,
#               'auersperg': 1,
#               'stroheim': 4,
#               'kant,': 1,
#               'steyr': 2,
#               "weber's": 2,
#               'windsor"': 1,
#               'sternberg': 5,
#               'mueller': 1,
#               'kármán': 3,
#               'coudenhove-kalergi': 2,
#               'wafer': 1,
#               'fraunhofer': 3,
#               'gontard': 5,
#               'oy': 1,
#               'oÿ': 2,
#               'schlözer': 2,
#               'kempelen': 11,
#               'drei': 1,
#               'haast': 1,
#               'leers': 2,
#               'wurmb': 4,
#               'buchenwald"': 2,
#               'bingen': 1,
#               'turczaninow': 1,
#               'jacquin': 1,
#               'fritsch': 3,
#               'koenigsegg': 1,
#               'berchtold': 1,
#               'suttner': 2,
#               'kluck': 2,
#               'helmholtz,': 3,
#               'borsody': 6,
#               'he': 1,
#               'küchler': 2,
#               'bock': 2,
#               'meyer': 1,
#               'morsleben': 2,
#               'grofé': 1,
#               'kleist-schmenzin': 2,
#               'eschscholtz': 2,
#               'erich,': 2,
#               'preußen': 2,
#               'essen,': 2,
#               'arnim': 2,
#               'drake': 6,
#               'wilczek': 3,
#               'troppau': 1,
#               'hertling': 2,
#               'essen': 8,
#               'rosen': 6,
#               'bagh': 4,
#               'françois': 1,
#               'homburg': 3,
#               'rittberg': 2,
#               'ranke': 5,
#               '1494': 1,
#               'tiesenhausen': 3,
#               'rosenstein': 1,
#               'rosenstein,': 2,
#               'scheele': 1,
#               'fersen': 1,
#               'eichhorn': 2,
#               'dutch': 1,
#               'clausewitz,': 1,
#               'schober': 1,
#               'ahn': 10,
#               'bienefeldt': 3,
#               'zingler': 1,
#               'bagdad': 2,
#               'crap': 1,
#               'wasserburg': 1,
#               'westphalen': 4,
#               'werneck': 1,
#               'baer,': 1,
#               'barth': 3,
#               'barth,': 1,
#               'ivan"': 1,
#               'dreyse': 1,
#               'kant"': 2,
#               'brunn': 29,
#               "brunn's": 4,
#               'brunn,': 1,
#               'hoffman': 1,
#               'hoffman,': 1,
#               'koerber': 5,
#               'schoen': 4,
#               'bethmann': 4,
#               'löffelholz': 3,
#               'ryan': 1,
#               'triers': 1,
#               'jawlensky': 5,
#               'jawlensky,': 2,
#               'werefkin': 2,
#               'hackl': 3,
#               'hassel': 2,
# ...
#               '135': 1,
#               '243': 2,
#               '38': 12,
#               'center': 7,
#               'urawa': 1,
#               '142': 1,
#               'club': 37,
#               'fletcher': 1,
#               'jack': 3,
#               'dc': 1,
#               '1,030': 1,
#               '752': 1,
#               'sound': 1,
#               'ronald': 2,
#               'lucy': 6,
#               'bellatrix': 1,
#               'mrs': 18,
#               'well-known': 2,
#               'versus': 12,
#               'england': 2,
#               'covers': 2,
#               'kent': 3,
#               'now': 2,
#               '"god': 1,
#               'modern': 1,
#               '217': 1,
#               '33': 5,
#               'equally': 1,
#               'attacking': 1,
#               'italy': 1,
#               '94': 5,
#               '51': 4,
#               '119': 7,
#               'abroad': 7,
#               'privately': 1,
#               'classic': 1,
#               '297': 1,
#               '27': 17,
#               '145': 4,
#               'southern': 1,
#               '404': 2,
#               '433': 1,
#               'organ': 3,
#               'till': 16,
#               'loudly': 2,
#               'princess': 4,
#               'kingpin': 1,
#               'chakotay': 1,
#               'first': 14,
#               '67': 5,
#               '8': 30,
#               '148': 1,
#               '49': 9,
#               '103': 3,
#               'r&b,': 1,
#               '88': 3,
#               'marjorie': 1,
#               '39': 14,
#               '91': 3,
#               "japan's": 1,
#               '176': 1,
#               '90': 5,
#               'usl': 1,
#               '146': 3,
#               '136': 2,
#               '248': 1,
#               '112': 1,
#               '167': 3,
#               '313': 2,
#               '144': 5,
#               'association': 2,
#               '68': 3,
#               'eleven': 15,
#               'guy': 2,
#               'polo,': 1,
#               'pop': 3,
#               '400': 1,
#               '178': 1,
#               'central': 1,
#               'blues,': 1,
#               '42': 7,
#               '328': 1,
#               'bayer': 1,
#               'buriram': 1,
#               '127': 3,
#               '79': 4,
#               '163': 2,
#               '62': 7,
#               'little': 5,
#               '74': 6,
#               'gibbs': 1,
#               '209': 1,
#               '65': 6,
#               'unheard,': 1,
#               'prior': 1,
#               'jerôme': 1,
#               'petrushka,': 1,
#               '264': 1,
#               '125': 1,
#               '161': 3,
#               '59': 7,
#               '97': 3,
#               '239': 2,
#               'elfsborg': 1,
#               '222': 1,
#               'yokohama': 1,
#               '1986': 2,
#               'total': 1,
#               'organized': 1,
#               'piano,': 5,
#               '2,062': 1,
#               'willie': 1,
#               'midfielder': 3,
#               'slovakia': 2,
#               'om': 1,
#               "it's": 1,
#               'successfully': 4,
#               'newly': 1,
#               'her,': 2,
#               'lex': 1,
#               '85,000': 1,
#               'exhibitions': 1,
#               'mosconi': 1,
#               'hitting': 1,
#               'festus': 1,
#               '149': 3,
#               'poker': 1,
#               '"alan': 2,
#               'cassandra': 1,
#               'centre': 6,
#               '41': 7,
#               "max's": 1,
#               'missi': 1,
#               'lacrosse': 3,
#               'soccer,': 2,
#               'malcolm': 3,
#               'whip': 1,
#               '63': 6,
#               '120': 1,
#               "na'vi": 2,
#               'mondays,': 1,
#               '117': 2,
#               '156': 2,
#               'international': 8,
#               'elvis': 2,
#               'bach': 1,
#               'sarah': 10,
#               'wherever': 1,
#               'selena': 1,
#               'bebop': 2,
#               'also,': 1,
#               '(every': 1,
#               'softball': 3,
#               '1½': 1,
#               'metal': 2,
#               'defensive': 5,
#               'anand': 1,
#               'on)': 1,
#               'world': 2,
#               'italy,': 1,
#               'paraguay': 1,
#               'percy': 2,
#               'grover': 1,
#               'chiron': 1,
#               'pamela': 5,
#               'juliet': 6,
#               'olivia': 1,
#               'reply': 1,
#               'matches': 5,
#               '"with': 1,
#               '526': 1,
#               '85': 4,
#               'beating': 1,
#               'locally': 2,
#               '95': 2,
#               '139': 2,
#               '200': 5,
#               '121': 4,
#               'irina': 1,
#               'extensively': 1,
#               'board': 1,
#               '175': 2,
#               'nowadays,': 1,
#               'bass,': 3,
#               '92': 4,
#               '147': 4,
#               '573': 1,
#               'captain': 9,
#               'appear,': 1,
#               'again,': 3,
#               'east': 1,
#               '124': 3,
#               '106': 2,
#               '128': 2,
#               '107': 1,
#               '36': 4,
#               '201': 2,
#               '131': 3,
#               '23': 8,
#               '164': 4,
#               '454': 1,
#               '83': 2,
#               'stoke': 1,
#               'additional': 1,
#               'outfield': 1,
#               '100': 3,
#               'keio': 1,
#               'next': 3,
#               'top-flight': 2,
#               'kramnik': 1,
#               'black': 3,
#               'jolson,': 1,
#               '172': 1,
#               '151': 1,
#               '154': 2,
#               'briefly': 8,
#               '96': 5,
#               '193': 1,
#               '160': 1,
#               '113': 3,
#               '132': 3,
#               '230': 1,
#               '153': 2,
#               '140': 2,
#               '81': 3,
#               '155': 5,
#               '87': 2,
#               '150': 3,
#               '195': 2,
#               'fifa': 2,
#               'gaelic': 1,
#               'part': 2,
#               'player': 1,
#               '152': 2,
#               'authentic': 1,
#               'world-wide': 1,
#               'collegiately': 2,
#               '407': 1,
#               'linebacker': 2,
#               'vancouver': 1,
#               'ingrid': 2,
#               '141': 3,
#               'katara': 2,
#               'dwayne': 1,
#               'jake': 1,
#               'plo': 1,
#               'alma': 3,
#               'mala': 1,
#               'bernice': 1,
#               'cindy': 5,
#               'thirteen': 3,
#               'senior': 3,
#               '401': 1,
#               'major-junior': 1,
#               'fullback': 1,
#               '"kim"': 1,
#               'dave': 2,
#               "'tough": 1,
#               'tendulkar': 1,
#               'internationally': 5,
#               '348': 1,
#               'bagpipes': 2,
#               'dignitaries': 1,
#               'although': 1,
#               '210': 1,
#               'holiday': 1,
#               'twice,': 1,
#               '286': 1,
#               '425': 1,
#               'primarily': 5,
#               '500': 1,
#               'celebrities': 1,
#               'could': 1,
#               'chess,': 1,
#               'bugle': 1,
#               'bach’s': 1,
#               'difficult': 1,
#               'horn': 1,
#               'immediately,': 1,
#               '5exf6': 1,
#               'moves': 1,
#               'fourth': 1,
#               '502': 1,
#               'leading': 7,
#               'alcyr': 2,
#               'ferris': 1,
#               'sammy': 2,
#               'senior-level': 1,
#               'tracy': 3,
#               'jo': 2,
#               'carrie': 6,
#               'selina': 2,
#               'net': 1,
#               'hugh': 1,
#               'roxanne': 1,
#               'nicky': 2,
#               'jenny': 5,
#               'lenore': 1,
#               'instrumental': 1,
#               'cecilia': 1,
#               'strawberry': 1,
#               'ruth': 5,
#               'country': 2,
#               'olive': 1,
#               'betty': 3,
#               'maggie': 10,
#               'carol': 5,
#               'lorelei': 1,
#               'dolly': 1,
#               'trombone': 2,
#               'shannon': 1,
#               'shirley': 2,
#               'alexis': 1,
#               'eponine': 1,
#               'sue': 6,
#               'guard': 1,
#               'joe': 3,
#               'dr': 25,
#               'robert': 3,
#               'lieutenant': 3,
#               'jesse': 2,
#               'inexperienced': 1,
#               'joy': 2,
#               'edward': 3,
#               'julia': 6,
#               'samantha': 5,
#               'lucius,': 1,
#               'dutch': 1,
#               'mike': 6,
#               'afterwards': 2,
#               'morgan': 2,
#               'senator': 2,
#               'napoleon': 1,
#               'wade': 1,
#               'judas': 1,
#               'colt': 1,
#               'detective': 5,
#               'adam': 1,
#               'audra': 1,
#               'cowboy': 1,
#               'regularly,': 2,
#               'cybil': 1,
#               '37': 10,
#               'relegationmatches': 1,
#               'of': 2,
#               'thea': 1,
#               'it;': 1,
#               '6-': 1,
#               '"one': 1,
#               'cookie': 2,
#               'pitcher': 2,
#               'upright': 1,
#               ...}),
#  'solution"': defaultdict(int,
#              {'by': 3,
#               'soon': 1,
#               'often': 1,
#               '<eos>': 3,
#               'heydrich': 1,
#               'it': 1,
#               'however,': 1,
#               'this': 1,
#               'hitler': 1,
#               'the': 1,
#               '-': 1,
#               '(1976),': 1,
#               'and': 1,
#               'that': 1}),
#  'andel-schipper': defaultdict(int, {'of': 2}),
#  'hall:': defaultdict(int, {'the': 2, 'big': 1, '<eos>': 1}),
#  'friz': defaultdict(int, {'freleng': 5}),
#  'outokumpu': defaultdict(int, {'and': 1, '<eos>': 4, 'is': 1, 'the': 1}),
#  'inconspicuous': defaultdict(int,
#              {'and': 2, 'to': 1, '(not': 1, 'bird': 1, 'man': 1, 'except': 1}),
#  '"bansuri"': defaultdict(int, {'player': 1, 'is': 1, 'can': 1, 'with': 1}),
#  'padru': defaultdict(int, {'<eos>': 1}),
#  'ressha': defaultdict(int,
#              {'<eos>': 1,
#               'is': 1,
#               'sentai': 2,
#               'these': 1,
#               'are': 1,
#               'de': 1}),
#  "nirvana's": defaultdict(int,
#              {'first': 2,
#               'best': 1,
#               '"nevermind",': 1,
#               'singer,': 1,
#               'style': 1,
#               '"bleach",': 1,
#               'second': 1,
#               'lyrics': 1,
#               'west': 1,
#               'third': 2,
#               'self-titled': 1,
#               '"smells': 1,
#               'album': 1}),
#  '59||8||6||0||8||1||73||9': defaultdict(int, {'<eos>': 2}),
#  '"astika"': defaultdict(int,
#              {'schools;': 1, 'is': 1, 'schools,': 1, 'schools"': 1, 'and': 1}),
#  'folies-bergère"': defaultdict(int, {'<eos>': 1, '': 1}),
#  'yaya': defaultdict(int,
#              {'touré': 3, 'dacosta': 1, 'dub,': 1, 'aden,': 2, 'aden': 1}),
#  'nardello': defaultdict(int, {'took': 2}),
#  'abrahams"': defaultdict(int, {'by': 2}),
#  'cœdès': defaultdict(int, {'thinks': 1, 'believes': 1}),
#  'wednesday,': defaultdict(int,
#              {'then': 1,
#               'thursday': 7,
#               'september': 3,
#               '4': 1,
#               'which': 2,
#               'after': 1,
#               'october': 2,
#               'march': 3,
#               'december': 5,
#               '1': 2,
#               '7th': 1,
#               'february': 2,
#               '5': 1,
#               'the': 1,
#               'again': 1,
#               'and': 3,
#               'mother’s': 2,
#               'presidents': 2,
#               'thanksgiving': 2,
#               'st': 1,
#               'labor': 2,
#               'veterans': 2,
#               'named': 1,
#               'so': 1,
#               'derby,': 1,
#               'november': 2,
#               'april': 4,
#               'june': 6,
#               'january': 4,
#               'this': 1,
#               '28': 1,
#               'friday': 2,
#               '2': 1,
#               'thursday,': 1,
#               'july': 2,
#               'portsmouth': 1,
#               '9': 1,
#               'doncaster': 1,
#               'plymouth': 1,
#               'there': 1,
#               'august': 1,
#               'cardiff': 1,
#               'york': 1,
#               'barnsley': 1,
#               'with': 1,
#               'everton,': 1,
#               'we': 1,
#               '30': 1,
#               'november\xa030': 1,
#               'in': 1}),
#  'squads"': defaultdict(int, {'<eos>': 6}),
#  'pristine': defaultdict(int,
#              {'in': 2,
#               'coral': 1,
#               'qualities': 1,
#               'form': 1,
#               'beaches,': 1,
#               'beaches': 1,
#               '(not': 1,
#               'purity': 1,
#               'tropical': 1,
#               'patches': 1,
#               'pop': 1,
#               'sandy': 1,
#               'white': 1}),
#  'contostavlos': defaultdict(int,
#              {'(formerly': 1,
#               '<eos>': 1,
#               'he': 2,
#               'was': 5,
#               'and': 2,
#               'his': 1,
#               'pleaded': 1,
#               '(born': 1,
#               'revealed': 1,
#               'has': 1,
#               'image': 1}),
#  'sec,': defaultdict(int, {'the': 1, 'occ': 1}),
#  'sievierodonetsk': defaultdict(int,
#              {'is': 1, 'raion': 2, '(2022)': 1, 'was': 1, 'and': 1}),
#  'prohibition,': defaultdict(int,
#              {'are': 1,
#               'it': 1,
#               'wine': 1,
#               'so': 1,
#               'many': 1,
#               'or': 4,
#               'and': 1,
#               'the': 1}),
#  'prähnu': defaultdict(int, {'<eos>': 1, 'is': 1}),
#  'spheroid)': defaultdict(int, {'objects': 1, 'this': 1, 'the': 1}),
#  'anthers': defaultdict(int,
#              {'let': 1,
#               'may': 1,
#               'release': 1,
#               'are': 1,
#               'the': 1,
#               'fruits': 1,
#               '': 1,
#               '(also': 2,
#               'growing': 1}),
#  '"metal': defaultdict(int,
#              {'gods"': 1,
#               'machine': 1,
#               'heroes"': 1,
#               'for': 1,
#               'age"': 1,
#               'hammer"': 3,
#               'postcard': 1,
#               'up': 1,
#               'gear"': 9,
#               'blade': 1,
#               'health"': 2,
#               'health",': 1,
#               'god"': 1,
#               'by': 1,
#               'max"': 4,
#               'max': 3,
#               'saga"': 2,
#               'resistance"': 1,
#               'galaxy"': 1,
#               'attack"': 1,
#               'church"': 1,
#               'church",': 1,
#               'gear': 2,
#               'rectifier"': 2,
#               'fight': 1,
#               'hero"': 1,
#               'matsuri"': 1,
#               'queen"': 1}),
#  'orangeville,': defaultdict(int,
#              {'ontario)': 1, 'where': 1, 'ontario': 1, 'utah': 1}),
#  '10–6': defaultdict(int, {'record,': 1, 'and': 2, 'to': 1, 'in': 1}),
#  'beseech': defaultdict(int, {'thee': 1, '<eos>': 1}),
#  'chives,': defaultdict(int, {'thyme,': 1, 'slices': 1}),
#  "ancestor's": defaultdict(int,
#              {'arms': 1, 'life': 1, 'homeland': 1, 'death': 1}),
#  'marijampolė': defaultdict(int, {'county': 3, 'on': 1, '<eos>': 2, 'is': 2}),
#  'telegraphs,': defaultdict(int,
#              {'some': 1, 'microscopes,': 1, 'railways,': 1, 'and': 1}),
#  'valdeblore': defaultdict(int, {'<eos>': 1, 'is': 1}),
#  '"reeds"': defaultdict(int, {'are': 1, '(a': 1}),
#  'melanophryniscus': defaultdict(int, {'<eos>': 1, '(south': 1}),
#  'biomes': defaultdict(int,
#              {'their': 1,
#               'are': 5,
#               'in': 2,
#               'that': 1,
#               'major': 1,
#               'with': 1,
#               'is': 1,
#               'among': 1,
#               'correspond': 1,
#               '<eos>': 3,
#               'a': 1,
#               'declined:': 1,
#               'different': 1,
#               'have': 1,
#               'ranging': 1,
#               'and': 1}),
#  ...}

# %%
bigram_probabilities = {v: defaultdict(int) for v in vocab}
# Find out the bi-gram probabilities. For this divide the Bi-gram counts of x1,x2 by Uni-gram counts of x1
for x1 in bigram_counts:
    for x2 in bigram_counts[x1]:
      # Your Code here
        bigram_probabilities[x1][x2] = bigram_counts[x1][x2] / unigram_counts[x1]

# %%
# Print Bi-gram probability of black cat
bigram_probabilities["black"]["cat"]
# Out:
# 0.0022091310751104565

# %%
# Print Bi-gram probability of green cat
# From the probability you can understand that green cats do not exist (at least are not common)
bigram_probabilities["green"]["cat"]
# Out:
# 0

# %%
# Complete the function to find probability of a sequence.
# if you have sequence s = {w1,w2,w3,w4}
# P(s) = p(w1,w2)*p(w2,w3)*p(w3,w4)
def sequence_probability(s):
    # words contain list of words in sequence s
    words = preprocess(s)
    # List to contain all transition Bi-gram probabilities, i.e., [p(w1,w2),p(w2,w3),p(w3,w4)]
    transition_probs = []
    for i in range(len(words)-1):
        # Gets consecutive words. x1,x2 will get w1,w2 then w2,w3 and so on
        x1, x2 = words[i], words[i+1]
        # Get the bi-gram probabilities of the transitions, i.e., p(w1,w2)
        # Your code here
        transition_prob = bigram_probabilities[x1][x2]
        # Insert the transition prob in list transition_probs
        # Your code here
        transition_probs.append(transition_prob)

    # Calculate the sequence probability using transition_probs list.
    # Hint: transition_prob contains [p(w1,w2),p(w2,w3),p(w3,w4)] and your sequence prob P(s) = p(w1,w2)*p(w2,w3)*p(w3,w4)
    # Your Code here
    prob = 1
    for transition_prob in transition_probs:
        prob += transition_prob
    
    return prob

# %%
sequences = ["i like fish", "i likes fish", "me likes fish"]
probs = [(s, sequence_probability(s)) for s in sequences]
sorted(probs, key = lambda x: x[1], reverse=True)
# it can catch ungrammatical constructions
# Out:
# [('i like fish', 1.0598181288715858),
#  ('i likes fish', 1.0567765490663619),
#  ('me likes fish', 1.0562380237452258)]

# %%
sequences = ["i like burgers", "i like fish", "i like snakes"]
probs = [(s, sequence_probability(s)) for s in sequences]
sorted(probs, key = lambda x: x[1], reverse=True)
# burgers are in the unigrams, but there is no fitting bigram --> unknown / low-frequency word problem
# Out:
# [('i like burgers', 1.0864018451806203),
#  ('i like snakes', 1.064612363072076),
#  ('i like fish', 1.0598181288715858)]

# %%
sequences = ["i like fish", "i like fried fish", "i like fried fish with potatoes"]
probs = [(s, sequence_probability(s)) for s in sequences]
sorted(probs, key = lambda x: x[1], reverse=True)
# longer sequences will have lower probability
# Out:
# [('i like fried fish with potatoes', 1.126865258765832),
#  ('i like fried fish', 1.0733548148072751),
#  ('i like fish', 1.0598181288715858)]

# %%
# Comlete the function on generating sequences. For this you will follow a greedy approach where you select the next word on the basis of highest bi-gram probability.
# Basically if the last word is w, you find the word x which has the highest bi-gram probability P(w,x)
# The function takes the starting word and the length of the sequence you want to generate
def generate(start_word, length = 2):
    output = [start_word]
    # You need to generate length-1 number of words so loop over that many times
    for i in range(0, length-1):
        # If last word in output(till now) is not in bigram_probabilities we will stop the generation
        if output[i] not in bigram_probabilities:
            break
        else:
          # Find the Bi-gram probabilities of all words with the last word in output(till now). The last word in output(till now) is basically output[i]
          # Then find the word which has the highest probability and add it to the output string
          # Your code here
          output.append(max(bigram_probabilities[output[i]], key=bigram_probabilities[output[i]].get))

    return output

# %%
# Use the generate function to generate a sequence of length 10 starting with the word "cats"
# Your Code here
generate('cats', 10)
# Out:
# ['cats', 'are', 'the', 'first', 'time', 'in', 'the', 'first', 'time', 'in']

# %%
# Use the generate function to generate a sequence of length 10 starting with the word "we"
# Your Code here
generate('we', 10)
# Out:
# ['we', 'can', 'be', 'a', 'commune', 'it', 'is', 'a', 'commune', 'it']

# %% [markdown]
# ## Watermarking

# %%
# Two sentences
s1 = "pigeons known for their remarkable homing ability and adaptability to urban environments have been companions and messengers to humans for thousands of years ."
s2 = "with their iridescent feathers and distinctive cooing pigeons add a unique charm to cityscapes around the world ."

# %%
w = s1.split(" ") + s2.split(" ")
vocab = set(w)

# %%
import pickle

with open('data/red_list.data', 'rb') as f:
        red_list = pickle.load(f)

# red_list contains which are words are red/green as next words. If the value of red_list[w1][w2] is True that means w2 cannot follow w1 and it is a violation.
# If the value of red_list[w1][w2] is False that means w2 can follow w1 and it is not a violation.

# %%
red_list['with']['their']
# Out:
# True

# %%
red_list['and']['distinctive']
# Out:
# False

# %%
# Now you have the red list in red_list
# Write a function to check the number of violations
# The function takes the sentence s and the redlist as inputs
def check(s, redlist):
    # Get the list of words
    w = s.split(" ")
    # Count number of violations
    # Remember the red list contains true and flase
    # You need to check if the value corresponding to consecutive words in w are True in redlist. If so violations count will go up by 1.
    violations = 0
    for i in range(0, len(w)-1):
        violations += 1 if  redlist[w[i]][w[i+1]] is True else 0
    return violations

check(s1, red_list), check(s2, red_list)
# Out:
# (0, 10)

# %%
# Calculate the probability of a human writing a sentence of the same length as s1 without ever violating the red list
print(1 / (2 ** len(s1)))
# Out:
# 1.3684555315672042e-48

# %%
# Calculate the probability of a human writing a sentence of the same length as s2 without ever violating the red list
print(1 / (2 ** len(s2)))
# Out:
# 9.62964972193618e-35
