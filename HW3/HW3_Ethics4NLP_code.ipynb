# %% [markdown]
# ## Task 1: Toy Bi-Gram LM

# %%
from collections import Counter, defaultdict
import random
import tqdm

# %%
# <BOS> is the beginning of sentence token
# <EOS> is the end of sentence token
def preprocess(s):
    s = "<BOS> " + s + " <EOS>"
    words = [w.replace(".", "") for w in s.lower().split(" ")]
    return words

# %%
# Mount your google drive
# Remove this code if you do not upload the file to your google drive
# Download it from: https://hessenbox.tu-darmstadt.de/getlink/fiCd4Ym2C61sGD2dVd1RqFNh/simple_wikipedia.zip
# from google.colab import drive
# drive.mount('/content/drive')

# %%
corpus = []
# Insert path to the text file
with open("data/simple_wikipedia.txt") as f:
    for line in f.readlines():
        line = line.replace("\n", "")
        if line:
            corpus += preprocess(line)

# %%
print(len(corpus))
# Out:
# 31756752

# %%
corpus[:10]
# Out:
# ['<bos>',
#  'april',
#  '<eos>',
#  '<bos>',
#  'april',
#  '(apr)',
#  'is',
#  'the',
#  'fourth',
#  'month']

# %%
# Counts the frequency of each word
c = Counter(corpus)

# %%
c
# Out:
# Counter({'the': 2019819,
#          '<bos>': 977830,
#          '<eos>': 977830,
#          'of': 959455,
#          'in': 943150,
#          'and': 760404,
#          'a': 684641,
#          'is': 568699,
#          'to': 502970,
#          'was': 452046,
#          'it': 268659,
#          'he': 263238,
#          'on': 235740,
#          'for': 230421,
#          'as': 198648,
#          'by': 183094,
#          'from': 167653,
#          'that': 158897,
#          'with': 153606,
#          'are': 147833,
#          'at': 140200,
#          'an': 130035,
#          'his': 127013,
#          'they': 104974,
#          'or': 92598,
#          'also': 91516,
#          'this': 88630,
#          'were': 87805,
#          'has': 87283,
#          'she': 84216,
#          '': 82948,
#          'be': 79419,
#          'people': 69889,
#          'which': 69247,
#          'first': 68312,
#          'not': 68291,
#          'have': 65044,
#          'one': 64075,
#          'their': 59631,
#          'there': 58565,
#          'had': 58248,
#          'after': 55698,
#          'her': 52567,
#          'new': 52158,
#          'but': 52135,
#          'united': 51956,
#          'other': 50375,
#          'many': 49080,
#          'who': 49013,
#          'its': 48641,
#          'can': 48599,
#          'when': 47039,
#          'known': 46551,
#          'about': 45974,
#          'city': 44066,
#          'american': 43152,
#          'called': 43131,
#          'used': 42748,
#          'two': 41936,
#          'made': 41717,
#          'states': 41421,
#          'most': 41048,
#          'some': 39908,
#          'born': 39186,
#          'may': 38635,
#          'been': 37109,
#          'more': 35844,
#          'all': 35609,
#          '–': 35247,
#          'died': 35107,
#          'into': 33914,
#          'world': 33257,
#          'during': 32823,
#          'became': 32455,
#          'national': 31108,
#          'part': 30102,
#          'because': 29949,
#          'movie': 29717,
#          'time': 29181,
#          'played': 28491,
#          'only': 28335,
#          'state': 28273,
#          'these': 28081,
#          '"the': 26799,
#          '(born': 26780,
#          'than': 26441,
#          'years': 26168,
#          'name': 26162,
#          'between': 26125,
#          'january': 24626,
#          'like': 24481,
#          'up': 24243,
#          'would': 24235,
#          'over': 24143,
#          'county': 23956,
#          'where': 23877,
#          'number': 23823,
#          'very': 23758,
#          'south': 23289,
#          'north': 23255,
#          'them': 23203,
#          'such': 23129,
#          'won': 23086,
#          'team': 22943,
#          'until': 22626,
#          'released': 22033,
#          'then': 21994,
#          'three': 21709,
#          'found': 21528,
#          'france': 21308,
#          'him': 20715,
#          'different': 20705,
#          'age': 20510,
#          'since': 20372,
#          'march': 20342,
#          'university': 20163,
#          'out': 19810,
#          'later': 19633,
#          'september': 19498,
#          'before': 19468,
#          'second': 19436,
#          'series': 19261,
#          'july': 19258,
#          'music': 19257,
#          'will': 19253,
#          'august': 19249,
#          'area': 19202,
#          'october': 19124,
#          'so': 19092,
#          'june': 19084,
#          'us': 19038,
#          'war': 18661,
#          'november': 18503,
#          'april': 18374,
#          'december': 18330,
#          'member': 18241,
#          'president': 18222,
#          'department': 18218,
#          'town': 18074,
#          'make': 17878,
#          'de': 17743,
#          'same': 17720,
#          'best': 17713,
#          'if': 17688,
#          'february': 17529,
#          'region': 17498,
#          'being': 17485,
#          'district': 17482,
#          'football': 17437,
#          'group': 17395,
#          'started': 17388,
#          'named': 17077,
#          'song': 16998,
#          'no': 16958,
#          'use': 16899,
#          'year': 16857,
#          'often': 16807,
#          'both': 16666,
#          'album': 16622,
#          'through': 16601,
#          'british': 16164,
#          'each': 16106,
#          'said': 15941,
#          '2020': 15899,
#          'did': 15897,
#          'while': 15789,
#          'against': 15671,
#          'commune': 15640,
#          'television': 15285,
#          'government': 15068,
#          'around': 15051,
#          'party': 15014,
#          'work': 14997,
#          'family': 14995,
#          'game': 14988,
#          'do': 14974,
#          'player': 14712,
#          'population': 14383,
#          'river': 14346,
#          'well': 14260,
#          'under': 14250,
#          'several': 14217,
#          'could': 14124,
#          'school': 14021,
#          'lived': 14000,
#          'place': 13928,
#          'main': 13889,
#          'former': 13823,
#          'west': 13742,
#          'however,': 13730,
#          'usually': 13630,
#          'including': 13610,
#          'municipality': 13447,
#          'four': 13373,
#          'county,': 13310,
#          'league': 13295,
#          'english': 13261,
#          'began': 13249,
#          'john': 13237,
#          '1': 13178,
#          'small': 13129,
#          'went': 12886,
#          'east': 12881,
#          'long': 12850,
#          'york': 12728,
#          'created': 12657,
#          'based': 12494,
#          'live': 12452,
#          'water': 12418,
#          'international': 12360,
#          'province': 12234,
#          'important': 12233,
#          'show': 12233,
#          'back': 12184,
#          'early': 12101,
#          'house': 11910,
#          'band': 11853,
#          'home': 11798,
#          'another': 11793,
#          'large': 11779,
#          'season': 11711,
#          'any': 11692,
#          'high': 11645,
#          'french': 11608,
#          'king': 11567,
#          'club': 11253,
#          'games': 11251,
#          'get': 11227,
#          'now': 11223,
#          'death': 11192,
#          '()': 11127,
#          'person': 11106,
#          '-': 11071,
#          'system': 11054,
#          'politician': 11009,
#          'country': 10947,
#          'end': 10880,
#          'old': 10810,
#          'much': 10753,
#          '2': 10745,
#          'last': 10736,
#          'company': 10733,
#          'what': 10721,
#          'means': 10539,
#          'famous': 10435,
#          'way': 10422,
#          'popular': 10410,
#          'century': 10345,
#          'life': 10335,
#          'written': 10325,
#          'million': 10314,
#          'single': 10295,
#          'near': 10291,
#          'germany': 10234,
#          'still': 10203,
#          'even': 10180,
#          'took': 10173,
#          'married': 10143,
#          'minister': 10099,
#          'left': 10019,
#          'moved': 9989,
#          'capital': 9973,
#          'how': 9857,
#          'language': 9856,
#          'list': 9777,
#          'award': 9768,
#          'day': 9719,
#          'general': 9694,
#          'england': 9693,
#          'largest': 9689,
#          'built': 9687,
#          'great': 9645,
#          'book': 9642,
#          'include': 9627,
#          'wrote': 9614,
#          'directed': 9555,
#          'play': 9530,
#          'came': 9516,
#          'german': 9497,
#          'sometimes': 9483,
#          'become': 9453,
#          'common': 9401,
#          'worked': 9364,
#          'japan': 9316,
#          'species': 9310,
#          'major': 9308,
#          'held': 9213,
#          'countries': 9181,
#          'third': 9155,
#          'children': 9132,
#          'island': 9030,
#          'own': 9021,
#          'following': 8963,
#          'living': 8944,
#          'given': 8944,
#          'members': 8867,
#          'central': 8816,
#          'i': 8763,
#          'five': 8738,
#          '3': 8679,
#          'served': 8641,
#          'form': 8617,
#          'cup': 8603,
#          'times': 8582,
#          'summer': 8561,
#          'western': 8526,
#          'using': 8446,
#          'good': 8380,
#          'aged': 8333,
#          'white': 8325,
#          'sea': 8317,
#          'army': 8311,
#          'northern': 8279,
#          'set': 8273,
#          'public': 8256,
#          'just': 8253,
#          'land': 8239,
#          'does': 8225,
#          'top': 8159,
#          'you': 8152,
#          '10': 8151,
#          'black': 8148,
#          'kingdom': 8143,
#          'role': 8122,
#          'founded': 8092,
#          '4': 8084,
#          'history': 8076,
#          'word': 8060,
#          'california': 8057,
#          'got': 8023,
#          'along': 8008,
#          'go': 7909,
#          'next': 7823,
#          'professional': 7802,
#          'power': 7788,
#          'film': 7787,
#          'down': 7763,
#          'published': 7749,
#          'together': 7737,
#          'every': 7735,
#          'church': 7728,
#          'air': 7682,
#          'again': 7681,
#          'video': 7664,
#          'things': 7662,
#          'actor': 7627,
#          'union': 7625,
#          'career': 7605,
#          'india': 7602,
#          'european': 7570,
#          'plays': 7547,
#          'parts': 7541,
#          'london': 7536,
#          'rock': 7518,
#          'political': 7516,
#          'center': 7502,
#          'order': 7495,
#          'seat': 7494,
#          'few': 7481,
#          'body': 7478,
#          'help': 7441,
#          'stars': 7439,
#          'located': 7425,
#          'station': 7423,
#          '2010': 7415,
#          'line': 7378,
#          'those': 7355,
#          'young': 7352,
#          '2019': 7321,
#          'making': 7303,
#          '2018': 7271,
#          'japanese': 7244,
#          'thought': 7234,
#          'southern': 7230,
#          '5': 7227,
#          'frog': 7219,
#          'human': 7209,
#          'father': 7206,
#          '2017': 7157,
#          'term': 7137,
#          'received': 7136,
#          'due': 7117,
#          'indian': 7116,
#          'take': 7109,
#          'village': 7106,
#          'killed': 7098,
#          'australia': 7081,
#          'women': 7049,
#          'seen': 7036,
#          'park': 7010,
#          'la': 7010,
#          'head': 7008,
#          'type': 6984,
#          'law': 6975,
#          '2011': 6970,
#          'works': 6946,
#          'red': 6946,
#          'championship': 6942,
#          'big': 6924,
#          'according': 6901,
#          'movies': 6893,
#          'studio': 6881,
#          'modern': 6840,
#          'st': 6833,
#          'led': 6778,
#          'college': 6754,
#          '2021': 6695,
#          'republic': 6672,
#          'son': 6663,
#          'without': 6661,
#          'military': 6656,
#          'election': 6640,
#          'joined': 6607,
#          'produced': 6602,
#          'six': 6580,
#          '2014': 6546,
#          'prime': 6502,
#          'ii': 6483,
#          'similar': 6482,
#          'special': 6457,
#          'james': 6449,
#          ',': 6447,
#          'italian': 6447,
#          'caused': 6428,
#          'announced': 6414,
#          'formed': 6406,
#          'man': 6400,
#          'lost': 6389,
#          'although': 6386,
#          '2008': 6384,
#          'put': 6339,
#          '12': 6330,
#          '20': 6320,
#          'original': 6306,
#          'off': 6305,
#          '2013': 6301,
#          'late': 6299,
#          'america': 6276,
#          'actress': 6262,
#          'lot': 6251,
#          'san': 6248,
#          'makes': 6232,
#          'songs': 6230,
#          'william': 6216,
#          'lives': 6193,
#          '2016': 6186,
#          'roman': 6179,
#          '15': 6151,
#          'playing': 6122,
#          'total': 6120,
#          '2007': 6108,
#          '2012': 6106,
#          'eastern': 6096,
#          'version': 6094,
#          'singer': 6092,
#          '6': 6086,
#          'elected': 6078,
#          'building': 6075,
#          'local': 6074,
#          'short': 6070,
#          'leader': 6068,
#          'story': 6066,
#          'changed': 6063,
#          'court': 6049,
#          "women's": 6038,
#          'george': 6035,
#          '2009': 6032,
#          'gave': 6030,
#          'appeared': 6021,
#          'mostly': 6016,
#          'time,': 6015,
#          'money': 5992,
#          'men': 5986,
#          'days': 5981,
#          '2006': 5962,
#          'side': 5945,
#          '2020,': 5941,
#          'italy': 5938,
#          'example,': 5919,
#          'away': 5897,
#          'director': 5894,
#          'we': 5893,
#          'royal': 5865,
#          'battle': 5865,
#          'others': 5857,
#          'office': 5848,
#          'title': 5845,
#          'australian': 5840,
#          'food': 5818,
#          'soviet': 5780,
#          'character': 5766,
#          'lake': 5766,
#          'record': 5758,
#          'social': 5745,
#          '&': 5732,
#          'governor': 5722,
#          '2015': 5715,
#          'among': 5697,
#          'right': 5673,
#          'little': 5672,
#          'less': 5672,
#          'wanted': 5664,
#          '8': 5662,
#          'census': 5644,
#          'olympics': 5638,
#          'art': 5631,
#          'included': 5622,
#          '7': 5618,
#          '2022': 5618,
#          'comes': 5614,
#          'change': 5605,
#          'light': 5590,
#          'see': 5578,
#          'within': 5556,
#          'academy': 5556,
#          'includes': 5553,
#          'service': 5553,
#          'should': 5548,
#          '100': 5513,
#          '(;': 5504,
#          'civil': 5497,
#          'control': 5470,
#          'having': 5469,
#          '11': 5468,
#          'robert': 5446,
#          'shows': 5440,
#          'final': 5433,
#          'current': 5407,
#          'awards': 5386,
#          'period': 5365,
#          'russian': 5361,
#          'must': 5360,
#          'studied': 5360,
#          'community': 5359,
#          'ancient': 5347,
#          'taken': 5343,
#          'almost': 5340,
#          'books': 5329,
#          'event': 5322,
#          'official': 5314,
#          'mother': 5308,
#          'europe': 5303,
#          'rights': 5303,
#          'los': 5265,
#          'attack': 5258,
#          'come': 5255,
#          '18': 5255,
#          'canada': 5254,
#          'middle': 5252,
#          'police': 5249,
#          'groups': 5245,
#          'female': 5241,
#          'considered': 5236,
#          '13': 5228,
#          'canadian': 5228,
#          'china': 5226,
#          '2005': 5215,
#          'match': 5215,
#          '30': 5196,
#          '14': 5188,
#          'places': 5178,
#          'level': 5170,
#          '(the': 5167,
#          'david': 5156,
#          '1,': 5153,
#          'though': 5152,
#          'drama': 5145,
#          'better': 5127,
#          'council': 5127,
#          'division': 5110,
#          'run': 5106,
#          '2001': 5102,
#          'democratic': 5100,
#          'says': 5097,
#          '16': 5096,
#          'areas': 5095,
#          '2004': 5087,
#          'switzerland': 5087,
#          'sold': 5061,
#          'hockey': 5055,
#          'heart': 5044,
#          'texas': 5031,
#          'grand': 5023,
#          'developed': 5019,
#          'players': 5008,
#          'once': 5000,
#          'able': 4967,
#          'point': 4959,
#          '25': 4948,
#          'empire': 4946,
#          '2000': 4946,
#          'never': 4945,
#          'spanish': 4933,
#          'working': 4930,
#          'force': 4910,
#          'tropical': 4888,
#          'charles': 4880,
#          'too': 4854,
#          '9': 4838,
#          'done': 4816,
#          'michael': 4803,
#          'free': 4802,
#          '17': 4788,
#          'chinese': 4786,
#          'association': 4764,
#          'animals': 4761,
#          'above': 4756,
#          'natural': 4732,
#          'parliament': 4724,
#          'uses': 4719,
#          'seven': 4714,
#          'cities': 4698,
#          'retired': 4695,
#          'sent': 4683,
#          'radio': 4675,
#          'race': 4666,
#          'instead': 4653,
#          'various': 4631,
#          'find': 4624,
#          'currently': 4617,
#          'support': 4614,
#          'teams': 4614,
#          'science': 4604,
#          'cancer': 4601,
#          'problems': 4575,
#          'mainly': 4555,
#          'islands': 4546,
#          'research': 4534,
#          'medal': 4528,
#          'greek': 4487,
#          '2020)': 4484,
#          'give': 4477,
#          '2003': 4465,
#          'movement': 4461,
#          'example': 4460,
#          'competed': 4460,
#          'star': 4459,
#          'gold': 4454,
#          'spain': 4452,
#          '24': 4448,
#          'languages': 4444,
#          'census,': 4431,
#          'federal': 4426,
#          'say': 4420,
#          'lead': 4417,
#          'across': 4416,
#          'ended': 4410,
#          'energy': 4410,
#          'space': 4383,
#          'records': 4383,
#          'study': 4376,
#          'love': 4371,
#          'woman': 4367,
#          'ice': 4364,
#          '2019,': 4362,
#          'start': 4360,
#          'helped': 4360,
#          'god': 4348,
#          'hit': 4345,
#          '2002': 4337,
#          'opened': 4325,
#          'tv': 4322,
#          'computer': 4317,
#          'comedy': 4316,
#          'wife': 4311,
#          'act': 4303,
#          'forces': 4303,
#          'types': 4287,
#          'highest': 4281,
#          'reached': 4277,
#          'average': 4271,
#          'native': 4270,
#          'coast': 4264,
#          'lower': 4262,
#          'paul': 4260,
#          'recorded': 4251,
#          'green': 4240,
#          'writer': 4237,
#          'states,': 4233,
#          '(or': 4222,
#          'storm': 4221,
#          'win': 4209,
#          'health': 4207,
#          'richard': 4201,
#          'open': 4193,
#          'scientists': 4191,
#          'fourth': 4187,
#          'think': 4186,
#          'earth': 4184,
#          'least': 4177,
#          'dutch': 4175,
#          'either': 4170,
#          'move': 4169,
#          'fire': 4165,
#          'originally': 4164,
#          '2,': 4164,
#          'canton': 4163,
#          '19': 4155,
#          'meaning': 4154,
#          'development': 4151,
#          'roles': 4150,
#          'program': 4147,
#          'road': 4136,
#          'africa': 4134,
#          'hall': 4131,
#          'decided': 4129,
#          'might': 4129,
#          'cause': 4124,
#          'later,': 4118,
#          'hot': 4117,
#          'tree': 4117,
#          'child': 4116,
#          '21': 4110,
#          'field': 4101,
#          'returned': 4093,
#          'performed': 4091,
#          'close': 4086,
#          'class': 4081,
#          'sports': 4079,
#          '22': 4052,
#          'words': 4038,
#          'network': 4034,
#          'today': 4025,
#          'strong': 4023,
#          'stage': 4021,
#          'replaced': 4015,
#          '1999': 4013,
#          'information': 4013,
#          'plants': 4010,
#          'always': 4005,
#          'daughter': 4000,
#          'museum': 4000,
#          'prize': 3999,
#          'chief': 3997,
#          'episode': 3995,
#          'certain': 3990,
#          'students': 3988,
#          'signed': 3986,
#          'peter': 3985,
#          'real': 3985,
#          'established': 3983,
#          'hurricane': 3982,
#          'car': 3974,
#          'christian': 3966,
#          'illinois': 3965,
#          'debut': 3964,
#          'idea': 3946,
#          'especially': 3941,
#          'mountain': 3937,
#          'writing': 3930,
#          'city,': 3920,
#          '23': 3913,
#          'business': 3910,
#          'african': 3906,
#          'shown': 3903,
#          'inside': 3899,
#          '3,': 3894,
#          '1996': 3888,
#          'henry': 3886,
#          'ten': 3876,
#          'himself': 3872,
#          'railway': 3864,
#          'names': 3861,
#          'channel': 3861,
#          'professor': 3858,
#          'thomas': 3852,
#          'pakistan': 3850,
#          'hospital': 3844,
#          '4,': 3843,
#          'catholic': 3840,
#          'disease': 3829,
#          'need': 3825,
#          'half': 3824,
#          'fc': 3814,
#          'nominated': 3813,
#          'outside': 3809,
#          'per': 3803,
#          'sweden': 3799,
#          'florida': 3799,
#          'going': 3796,
#          'position': 3795,
#          'chicago': 3787,
#          'stop': 3786,
#          'bad': 3784,
#          'goes': 3780,
#          'airport': 3779,
#          'sound': 3775,
#          '26': 3767,
#          'allowed': 3760,
#          'society': 3752,
#          'takes': 3739,
#          'paris': 3739,
#          'medical': 3720,
#          'republican': 3718,
#          '1998': 3715,
#          'color': 3701,
#          'successful': 3696,
#          '1992': 3696,
#          'night': 3694,
#          'months': 3693,
#          'mexico': 3679,
#          'independent': 3670,
#          'queen': 3655,
#          'look': 3643,
#          'characters': 3643,
#          'virginia': 3635,
#          'media': 3633,
#          'added': 3628,
#          'continued': 3615,
#          'russia': 3613,
#          'site': 3612,
#          'uk': 3607,
#          'divided': 3603,
#          'male': 3597,
#          'education': 3581,
#          'eight': 3568,
#          'related': 3564,
#          'want': 3564,
#          '1995': 3563,
#          '15,': 3563,
#          'believed': 3557,
#          'prince': 3554,
#          'changes': 3551,
#          '2016,': 3548,
#          'enough': 3547,
#          'blue': 3546,
#          'musical': 3538,
#          '2010,': 3534,
#          'ever': 3533,
#          'brother': 3533,
#          'winter': 3529,
#          'centre': 3522,
#          'secretary': 3516,
#          'finished': 3515,
#          'years,': 3514,
#          'latin': 3514,
#          'hard': 3513,
#          'soon': 3512,
#          'zealand': 3512,
#          '1994': 3500,
#          '2021,': 3493,
#          'events': 3491,
#          'owned': 3489,
#          '(also': 3484,
#          '28': 3480,
#          '7,': 3477,
#          'far': 3476,
#          '12,': 3475,
#          'cannot': 3474,
#          'full': 3473,
#          ')': 3473,
#          'kind': 3469,
#          '27': 3467,
#          'brown': 3466,
#          'know': 3464,
#          '10,': 3462,
#          'told': 3452,
#          'metal': 3443,
#          '5,': 3442,
#          'here': 3437,
#          'blood': 3436,
#          'something': 3432,
#          'production': 3431,
#          'front': 3431,
#          '6,': 3424,
#          'chemical': 3422,
#          '20th': 3422,
#          '11,': 3420,
#          '16,': 3406,
#          '1997': 3402,
#          'model': 3398,
#          'style': 3397,
#          'awarded': 3394,
#          'smaller': 3393,
#          'parents': 3392,
#          'senate': 3390,
#          'tried': 3382,
#          'voice': 3381,
#          'kansas': 3379,
#          'coach': 3377,
#          'longer': 3376,
#          'washington': 3375,
#          'possible': 3370,
#          '2018,': 3368,
#          '20,': 3363,
#          'range': 3361,
#          'plant': 3358,
#          'services': 3358,
#          '1993': 3355,
#          'case': 3351,
#          'designed': 3350,
#          'street': 3348,
#          '18,': 3348,
#          '""': 3348,
#          'presidential': 3339,
#          '8,': 3339,
#          'austrian': 3331,
#          'van': 3330,
#          '2017,': 3329,
#          'artist': 3328,
#          'keep': 3318,
#          'described': 3317,
#          'people,': 3312,
#          'oldest': 3310,
#          'valley': 3307,
#          '9,': 3306,
#          '13,': 3305,
#          'mayor': 3304,
#          'throughout': 3303,
#          'fight': 3294,
#          '(,': 3291,
#          'distributed': 3278,
#          'my': 3275,
#          'novel': 3271,
#          'festival': 3269,
#          'climate': 3267,
#          'ireland': 3267,
#          'northwest': 3239,
#          '17,': 3229,
#          '14,': 3225,
#          'discovered': 3209,
#          'border': 3206,
#          'happened': 3200,
#          'square': 3199,
#          'action': 3198,
#          'release': 3192,
#          'territory': 3190,
#          '29': 3190,
#          'low': 3188,
#          'traditional': 3188,
#          'ground': 3187,
#          'brought': 3186,
#          'fish': 3184,
#          'saw': 3182,
#          'data': 3176,
#          'news': 3173,
#          'commonly': 3173,
#          'numbers': 3169,
#          'ran': 3168,
#          'bank': 3168,
#          'assembly': 3166,
#          'culture': 3150,
#          '1991': 3147,
#          'round': 3141,
#          'gets': 3140,
#          'wrestling': 3139,
#          'stadium': 3133,
#          'amount': 3132,
#          'features': 3132,
#          '"a': 3125,
#          'believe': 3125,
#          'lee': 3120,
#          'leading': 3115,
#          'starring': 3112,
#          'soldiers': 3111,
#          '21,': 3109,
#          'beginning': 3107,
#          'upper': 3105,
#          'starting': 3102,
#          '1990': 3101,
#          'louis': 3099,
#          'grew': 3097,
#          '19,': 3092,
#          'congress': 3091,
#          'larger': 3089,
#          'process': 3080,
#          'mountains': 3079,
#          'this,': 3078,
#          'opera': 3077,
#          'organization': 3073,
#          'design': 3061,
#          '22,': 3056,
#          'create': 3055,
#          'matches': 3054,
#          'religious': 3052,
#          '23,': 3052,
#          '25,': 3051,
#          'pictures': 3049,
#          '27,': 3048,
#          '2007,': 3047,
#          'your': 3044,
#          '26,': 3043,
#          'higher': 3039,
#          'are:': 3027,
#          'foreign': 3025,
#          'ocean': 3023,
#          '24,': 3021,
#          'available': 3020,
#          'olympic': 3017,
#          'board': 3015,
#          'bridge': 3013,
#          '2022,': 3002,
#          'size': 2998,
#          'emperor': 2995,
#          'refer': 2993,
#          'edward': 2992,
#          'nations': 2988,
#          'followed': 2985,
#          'producer': 2983,
#          '28,': 2983,
#          ...})

# %%
unigram_counts = {k: v for k,v in c.items() if v>1} # also freq filter: each word should appear at least twice

# %%
# A set of words with unigram counts
vocab = set([k for k,v in c.items() if v>1])

# %%
bigram_counts = {v: defaultdict(int) for v in vocab} #takes few seconds

# %%
# Takes some time (a minute maybe)
for i in tqdm.tqdm(range(len(corpus)-1)):
    x1, x2 = corpus[i], corpus[i+1]
    # Check if x1 and x2 are in vocab and if they are increase bigram_couts[x1][x2] by 1
    # Your Code here
    if x1 in vocab and x2 in vocab:
        bigram_counts[x1][x2] += 1
# Out:
# 100%|██████████| 31756751/31756751 [00:27<00:00, 1160665.67it/s]

# %%
bigram_counts
# Out:
# {'': defaultdict(int,
#              {'<eos>': 74687,
#               'for': 22,
#               'around': 3,
#               '': 924,
#               'earth': 2,
#               'it': 813,
#               'we': 14,
#               'the': 1524,
#               '→': 1,
#               'people': 12,
#               '"': 9,
#               'increases': 1,
#               'this': 245,
#               '-': 13,
#               'mediawiki': 1,
#               'both': 13,
#               'mercury': 1,
#               'mariner': 1,
#               'several': 6,
#               'however,': 29,
#               'summers': 1,
#               'new': 5,
#               'honolulu,': 1,
#               'platonic': 1,
#               'because': 17,
#               'its': 164,
#               'seven': 2,
#               'in': 309,
#               'scientists': 4,
#               'they': 158,
#               '3': 5,
#               '0': 4,
#               'at': 66,
#               'herodotus': 1,
#               '/': 1,
#               'that': 26,
#               'he': 383,
#               'using': 3,
#               'more': 8,
#               'german': 1,
#               'vladimir': 1,
#               "moscow's": 2,
#               'moscow': 1,
#               'los': 2,
#               'tags': 1,
#               'during': 15,
#               'everton': 1,
#               'previous': 1,
#               '•': 1,
#               'lumps': 1,
#               'with': 29,
#               'mount': 2,
#               'an': 13,
#               'here': 5,
#               'cnn': 1,
#               'alberta': 1,
#               'most': 25,
#               'a': 52,
#               'electric': 1,
#               'today': 3,
#               'and': 28,
#               'former': 2,
#               'low': 1,
#               'medium-level': 1,
#               'vertical': 1,
#               'george': 3,
#               'tom,': 1,
#               'been': 2,
#               'her': 20,
#               'ph': 1,
#               'on': 43,
#               'january': 2,
#               'these': 38,
#               'eyes,': 1,
#               'she': 131,
#               'some': 26,
#               'since': 15,
#               'august': 1,
#               'is': 38,
#               'today,': 5,
#               'large': 2,
#               'females': 15,
#               'mature': 1,
#               'oxygen': 1,
#               'there': 131,
#               'sources': 1,
#               'means': 2,
#               'liberation': 1,
#               'louisiana': 2,
#               'cartier': 1,
#               'season': 58,
#               'of': 265,
#               'other': 16,
#               'gorbachev': 1,
#               'casting': 1,
#               'trying': 1,
#               'reformation': 1,
#               "jehovah's": 1,
#               'their': 31,
#               'belarus': 1,
#               '(which': 1,
#               'his': 33,
#               'sealand': 1,
#               "alabama's": 1,
#               'temperatures': 2,
#               'bremen': 1,
#               'about': 18,
#               "it's": 10,
#               'spring': 1,
#               'nesmith': 1,
#               'as': 63,
#               'others': 7,
#               'mineralogists': 1,
#               'mandate': 1,
#               '()': 4,
#               'thousands': 1,
#               "croatia's": 1,
#               "chad's": 1,
#               'freezers': 1,
#               'arctic': 1,
#               'humidity': 1,
#               'high': 1,
#               'saying': 2,
#               '"later': 1,
#               'to': 31,
#               'was': 23,
#               'iowa': 1,
#               'congress': 1,
#               'nations"': 1,
#               'rifles': 1,
#               'another': 3,
#               'older': 1,
#               'before': 13,
#               'theophrastus': 1,
#               'libya': 1,
#               'oklahoma': 1,
#               'winters': 4,
#               'until': 4,
#               'reason': 1,
#               '[and]': 3,
#               "franklin's": 1,
#               'newcastle': 1,
#               'summer': 2,
#               'foreign': 1,
#               'stood': 1,
#               'mongolia': 1,
#               'land': 1,
#               'tropical': 3,
#               '9': 1,
#               '6': 1,
#               'much': 2,
#               'measurable': 1,
#               'wichita': 1,
#               '(chorus)': 1,
#               'de': 2,
#               'burkina': 1,
#               'five': 2,
#               'longboard': 1,
#               '15': 1,
#               'emperor': 1,
#               'every': 6,
#               'snowfall': 1,
#               'averages': 1,
#               'wolverines': 1,
#               'after': 54,
#               '=': 1,
#               'print': 1,
#               'f1': 1,
#               'guillotin': 1,
#               'svalbard': 1,
#               'suppose': 1,
#               'eleven': 2,
#               'like': 9,
#               'each': 8,
#               'if': 21,
#               '[due': 1,
#               'highlights': 1,
#               'possibly': 1,
#               '(for': 1,
#               'two': 6,
#               'khartoum': 1,
#               'karma': 1,
#               'but': 18,
#               'scotty': 1,
#               'general': 4,
#               'get': 7,
#               'selene': 1,
#               'joe': 2,
#               'four': 2,
#               'toyota': 1,
#               'together,': 1,
#               'helena': 1,
#               'constantine': 2,
#               '(': 1,
#               'sometimes,': 3,
#               'snow': 1,
#               'railways': 1,
#               'lava': 1,
#               'pajamas': 1,
#               'did': 10,
#               'formula_7,': 1,
#               'next': 3,
#               'helplessness': 1,
#               '[that': 2,
#               'somewhere': 1,
#               'sexual': 1,
#               'first': 3,
#               'rachmaninoff': 1,
#               '"(let\'s': 1,
#               'males': 7,
#               'flowing': 2,
#               'now,': 1,
#               'thor': 1,
#               'referees': 1,
#               'dr': 2,
#               'one': 13,
#               'making': 1,
#               'borzois': 1,
#               'has': 4,
#               'taken': 1,
#               'whispered': 1,
#               "loki's": 1,
#               'many': 17,
#               'by': 9,
#               'then)': 1,
#               'instead': 1,
#               "there's": 2,
#               'apres': 1,
#               'so': 9,
#               'lenses': 1,
#               'annie': 1,
#               'excluded': 1,
#               'fossils': 1,
#               '"-"': 1,
#               'host': 1,
#               'everywhere': 1,
#               '[find': 2,
#               'who': 7,
#               'feces': 1,
#               'yet': 1,
#               'mal': 1,
#               'accounts': 1,
#               'nero': 1,
#               'sevan': 1,
#               'usually': 2,
#               'also': 7,
#               'officials': 1,
#               'capital': 1,
#               'there,': 3,
#               'no': 6,
#               'when': 37,
#               'well': 1,
#               'schubert': 1,
#               'historically,': 1,
#               'not': 4,
#               'concussions': 1,
#               "n'djamena": 1,
#               'according': 20,
#               'gazi': 1,
#               'čair': 1,
#               'butel': 1,
#               'gjorče': 1,
#               'college': 1,
#               'towns': 1,
#               'female': 2,
#               'music': 1,
#               'mozart': 1,
#               'thus': 2,
#               '"9"': 1,
#               'old': 2,
#               'instead,': 1,
#               'however': 4,
#               "moon's": 1,
#               'diocletian': 1,
#               'ü': 1,
#               'nautilus': 1,
#               'neither': 1,
#               'hirohito': 1,
#               'melkonian': 1,
#               'killed': 1,
#               'approximately': 1,
#               'have': 3,
#               'even': 6,
#               'team': 4,
#               'gerry': 1,
#               'cdf': 1,
#               'together': 4,
#               'volume': 1,
#               'i': 22,
#               'caprivi': 1,
#               'multiple': 1,
#               'lack': 1,
#               'population': 1,
#               'city': 2,
#               'use': 3,
#               '"2': 1,
#               'currently,': 1,
#               'zu': 1,
#               'almost': 5,
#               '2,000,000': 1,
#               'hurling': 1,
#               'lee': 1,
#               'although': 13,
#               'checkpoint': 1,
#               'between': 5,
#               'won': 5,
#               'aalborg': 1,
#               'driver': 4,
#               'which': 1,
#               'while': 9,
#               'fiction': 1,
#               'oceans,': 1,
#               '*': 7,
#               '"yellow': 2,
#               'meldorf': 1,
#               'public': 2,
#               'seyß-inquart': 1,
#               '92%': 1,
#               'eventually,': 1,
#               'gary': 1,
#               'getting': 1,
#               'three': 2,
#               'any': 3,
#               'port-au-prince,': 1,
#               'overall': 1,
#               'non-building': 1,
#               'hundreds': 1,
#               'having': 2,
#               'clio': 1,
#               'played': 1,
#               'clara': 1,
#               'from': 46,
#               'average': 2,
#               'karakalpakstan': 1,
#               'mayhew': 1,
#               '"also': 1,
#               'mazur': 1,
#               'villiers': 1,
#               'out': 2,
#               'american': 2,
#               'now': 2,
#               'only': 4,
#               'japanese': 1,
#               'workers': 1,
#               'bede': 1,
#               'bullfrogs': 1,
#               'male': 3,
#               '[his]': 1,
#               'charles': 1,
#               'carteret': 1,
#               '(1)': 2,
#               '1985,': 1,
#               'despite': 8,
#               'woven': 1,
#               'kochi': 1,
#               'palembang': 1,
#               'hamilton': 1,
#               'manora': 1,
#               'clemens': 1,
#               'hurtova': 1,
#               'mexican': 1,
#               'doak': 1,
#               'italian': 1,
#               'muttalib': 1,
#               '"girl,': 1,
#               'siachen': 1,
#               'work': 2,
#               'pir': 1,
#               'cd': 3,
#               'very': 3,
#               'karimabad': 1,
#               'picasa': 1,
#               'bazaar': 1,
#               'over': 3,
#               'wounded': 1,
#               'shelf': 1,
#               'various': 1,
#               '2006:': 1,
#               'pakistan': 1,
#               '(right-handed)': 1,
#               'above': 2,
#               'early': 2,
#               'orthodox': 1,
#               '(4)': 1,
#               '(5)': 4,
#               '(14)': 1,
#               '(3)': 3,
#               '(17)': 1,
#               '(20)': 1,
#               '(12)': 1,
#               'already': 1,
#               '(9)': 4,
#               '(15)': 1,
#               '(7)': 2,
#               'reads': 1,
#               '(8)': 1,
#               '(11)': 1,
#               'october': 1,
#               'july': 2,
#               'all': 209,
#               'ikev2': 1,
#               'prairie': 1,
#               'phetchabun': 1,
#               'updates': 1,
#               'therefore,': 1,
#               'heaton': 1,
#               'may': 2,
#               '--': 3,
#               'rips': 1,
#               'reproduction': 1,
#               '|': 2,
#               '(or': 23,
#               'jens': 1,
#               'drivers': 2,
#               "paterson's": 1,
#               'channels': 1,
#               'twenty-seven': 1,
#               'famous': 1,
#               'weatherford': 1,
#               '422': 1,
#               "germany's": 1,
#               'nicolae': 1,
#               'producers': 1,
#               '"disney\'s': 1,
#               'probably': 1,
#               'vendetta': 1,
#               'ss-obergruppenfuhrer': 1,
#               'hans': 2,
#               'aesthetic': 1,
#               'rifled': 1,
#               'ernst': 1,
#               'eg': 1,
#               'active': 1,
#               'boldface': 1,
#               'localization': 1,
#               'lilo': 1,
#               'pico': 3,
#               '"positif"': 1,
#               'knight:': 1,
#               'mexico': 1,
#               '(2)': 3,
#               'japan': 2,
#               'undefeated': 1,
#               'besides': 1,
#               'ibn': 1,
#               'without': 1,
#               '"e': 1,
#               'hansard': 1,
#               'leaves': 1,
#               'east': 1,
#               'tpl': 1,
#               'singers': 1,
#               "constructors'": 2,
#               '–': 3,
#               'just': 2,
#               'plan': 1,
#               'juan': 1,
#               'kim': 2,
#               'lukáš': 2,
#               'serena': 1,
#               'carly': 1,
#               'bernard': 1,
#               'heather': 1,
#               'marton': 1,
#               'valeria': 1,
#               'shingo': 2,
#               'esther': 3,
#               'stephane': 1,
#               'korie': 1,
#               'peter': 1,
#               'nick': 2,
#               'preko': 1,
#               '(players': 1,
#               'bonney': 1,
#               'within': 1,
#               'fennec': 1,
#               'khufu': 1,
#               'lask': 1,
#               'spent': 1,
#               'modern': 3,
#               'internationally,': 1,
#               'shows': 1,
#               'gluck’s': 1,
#               'alaska,': 1,
#               'hawaii,': 1,
#               'measured': 1,
#               'bruce': 2,
#               'sally': 1,
#               'immediately': 1,
#               'includes': 2,
#               'built': 1,
#               'wikimedia': 2,
#               'sundew': 1,
#               'mohammad': 1,
#               'can': 2,
#               'half': 1,
#               '90%': 1,
#               'are': 5,
#               'someone': 1,
#               'consonants': 1,
#               'good;': 1,
#               'plot"': 1,
#               'melodrama,': 1,
#               "white's": 1,
#               'epicurus': 1,
#               'usually,': 1,
#               'inadequate': 1,
#               '[laughs]': 1,
#               'haber': 1,
#               'usgs': 1,
#               'tyson': 1,
#               'hope': 1,
#               'rainfall': 2,
#               '||': 1,
#               'tsunayoshi': 1,
#               '(last': 40,
#               'pluto': 1,
#               'dadyal': 1,
#               '945': 1,
#               'ssv': 1,
#               'karim': 1,
#               'soviet': 1,
#               'gagarin': 1,
#               'iihf': 1,
#               'meanwhile,': 2,
#               'israel': 2,
#               'desert': 1,
#               'cena': 1,
#               'boston': 1,
#               'extremes': 1,
#               'once': 5,
#               'powered': 1,
#               'irene': 1,
#               'vernon': 1,
#               'following': 3,
#               'haugesund,': 2,
#               'mercedes-benz,': 1,
#               'under': 3,
#               'heidfeld': 1,
#               'sonic': 1,
#               'tabitha': 1,
#               'zuko': 1,
#               'protagonists': 1,
#               'otherwise': 1,
#               'valencia': 1,
#               'shōnan-shinjuku': 1,
#               'antigua': 1,
#               'rainfalls': 1,
#               'part': 5,
#               'scored': 1,
#               'then': 20,
#               'engines': 1,
#               'cosworth': 1,
#               'winds': 1,
#               'le': 1,
#               '"the': 2,
#               'cobalt(ii)': 1,
#               'luigi': 1,
#               'also,': 2,
#               'argentine': 1,
#               'shared': 1,
#               'abstract': 2,
#               'go-karts': 1,
#               'tony': 1,
#               'supposing': 1,
#               'competed': 1,
#               'placing': 1,
#               'winner': 1,
#               'health': 1,
#               'rafael': 1,
#               'bob': 1,
#               'vania': 1,
#               'liezel': 1,
#               'jack': 1,
#               'daria': 1,
#               'duilio': 1,
#               'tímea': 1,
#               'maikel': 1,
#               'david': 2,
#               'my': 3,
#               '”': 1,
#               "california's": 1,
#               'progress': 1,
#               '"mussaurus"': 1,
#               'men': 1,
#               'larger': 1,
#               'midseason': 1,
#               'z': 1,
#               'be': 2,
#               'certain': 2,
#               'would': 1,
#               'sometimes': 3,
#               'actuated': 1,
#               'robin': 1,
#               'petra': 1,
#               'alisa': 1,
#               'montgomery': 1,
#               'recent': 1,
#               'nanmadol': 1,
#               'soon': 3,
#               'strong': 1,
#               "joannie's": 1,
#               'growing': 1,
#               'rochette': 3,
#               'ivory': 1,
#               'next,': 3,
#               'counter-strike:': 1,
#               'oxpeckers': 1,
#               'hundertwasser': 1,
#               'colour': 1,
#               'karun': 1,
#               'alexander': 1,
#               'unwilling': 1,
#               'electronic': 1,
#               'logging': 1,
#               'six': 2,
#               'twelve': 1,
#               '(2001': 1,
#               'initially': 1,
#               'common': 1,
#               'marfa': 1,
#               'walburga': 1,
#               'hudson': 1,
#               'bomis': 1,
#               'bill': 2,
#               'considerable': 1,
#               'lizard': 1,
#               ',': 12,
#               'rahm': 1,
#               'had': 1,
#               '1995': 2,
#               "contestant's": 1,
#               "aurelian's": 1,
#               'closed': 1,
#               'winslow': 1,
#               'compares': 1,
#               'later': 7,
#               'weighing': 1,
#               'pups': 1,
#               'maturity': 1,
#               'bmw': 1,
#               'sauber,': 1,
#               'russian': 1,
#               'ichinoseki': 1,
#               'tamil': 1,
#               'afterwards,': 1,
#               'alveolar': 1,
#               'confident': 1,
#               'fernanda': 1,
#               'hasekura': 1,
#               'annual': 2,
#               'record': 1,
#               'or': 3,
#               'recommends': 1,
#               "stewart's": 1,
#               '(sc': 1,
#               'ocala': 1,
#               'so,': 1,
#               'amphibians': 1,
#               'beats': 1,
#               'remodelling': 1,
#               'fusa': 1,
#               'area': 1,
#               'airport': 4,
#               'atmospheric': 1,
#               'bundi': 1,
#               'deoli': 1,
#               'burns': 1,
#               'douglas': 1,
#               'films': 1,
#               'manet': 1,
#               'oppuurs': 1,
#               'grisi': 1,
#               '[the': 1,
#               'treats': 1,
#               "go-kōgon's": 2,
#               'but,': 1,
#               'engineers': 1,
#               'curious,': 1,
#               'returns;': 1,
#               'arching': 1,
#               'glen': 1,
#               'spasmodic': 1,
#               'should': 1,
#               'shophouses': 1,
#               '""': 1,
#               "kōgon's": 3,
#               "go-komatsu's": 2,
#               'ships': 1,
#               'near': 3,
#               'pound': 1,
#               ':': 2,
#               'listed': 1,
#               'hare': 1,
#               'south': 1,
#               'changes': 1,
#               'ic': 1,
#               'close': 1,
#               "anita's": 1,
#               'norman': 1,
#               '("': 1,
#               'yoshitsune': 1,
#               'bear': 1,
#               'amar': 1,
#               'india': 27,
#               'cox': 1,
#               'päijänne': 1,
#               'kallavesi': 1,
#               'nb': 1,
#               'alternatively,': 1,
#               'depressed,': 1,
#               'cao': 1,
#               'karimganj': 1,
#               'elizabeth\xa0': 1,
#               'suddenly': 1,
#               'seems': 1,
#               'act': 1,
#               'dipstick': 1,
#               'st': 1,
#               'berlioz': 1,
#               '[and': 1,
#               'historical': 1,
#               '"and': 1,
#               'sign': 1,
#               'tjuntjuntjara': 1,
#               'lead': 1,
#               'amanda': 1,
#               'calahorra': 1,
#               'william': 1,
#               'television': 1,
#               'premios': 1,
#               'estimated': 1,
#               'skiers': 1,
#               'top': 1,
#               'well,': 1,
#               'neighbouring': 2,
#               'severe': 1,
#               'based': 2,
#               'barnum': 1,
#               'will': 2,
#               'how': 2,
#               'along': 2,
#               'hgnc': 1,
#               'halti': 1,
#               'repairing': 1,
#               'permission': 1,
#               'pollux': 1,
#               'geoffrey': 1,
#               '[stephen]': 1,
#               'hibernians': 1,
#               'birkirkara': 2,
#               'wright': 1,
#               'baldwin': 1,
#               'your': 1,
#               'clone': 1,
#               '\xa0': 3,
#               'rain': 1,
#               'mika': 1,
#               'ealdormen': 1,
#               'sixteen': 1,
#               'cage': 1,
#               'cenwalh,': 1,
#               'touring': 2,
#               'were': 2,
#               'octene': 1,
#               'cold': 1,
#               'total:': 1,
#               'members': 1,
#               'burgess': 1,
#               'nothing': 2,
#               '(short': 1,
#               'tenants': 1,
#               'marcia': 1,
#               '"lexington"': 1,
#               'j': 1,
#               'works': 1,
#               'matilda': 1,
#               'medieval': 1,
#               'alassane': 1,
#               '",': 1,
#               "we're": 1,
#               'x-ray': 1,
#               'oswald': 1,
#               'inside': 1,
#               'poi': 1,
#               'bergström': 1,
#               '(1877)': 1,
#               'unfortunately,': 2,
#               'scalise': 1,
#               "'high": 1,
#               'agent': 1,
#               't': 1,
#               'retrieved': 6,
#               'pulbah': 1,
#               'federation"': 1,
#               'orange': 1,
#               'demotic': 1,
#               "'well,": 1,
#               'extended': 1,
#               'do': 3,
#               'katy': 2,
#               'cartoons': 1,
#               'such': 3,
#               'limited': 1,
#               '"matica': 1,
#               'yamato': 1,
#               'sei': 1,
#               'depending': 1,
#               'bellvale': 1,
#               'stretching': 1,
#               'cen': 1,
#               'walter': 1,
#               "canada's": 1,
#               'jdam-equipped': 1,
#               'riders': 1,
#               'maha': 1,
#               'forgiveness': 1,
#               'broccoli': 1,
#               '2000': 1,
#               'air': 1,
#               'ironically': 1,
#               'unlike': 4,
#               'populists': 1,
#               'kratos': 1,
#               'strangely': 1,
#               'irises': 1,
#               'borussia': 1,
#               'bełżec': 1,
#               'words': 1,
#               'dangi': 1,
#               'wrangel': 1,
#               'into': 1,
#               'farnes': 1,
#               'denotes': 1,
#               'throughout': 3,
#               'announced': 1,
#               "'": 1,
#               'back': 1,
#               'drums': 1,
#               'fifteen': 1,
#               'statutes': 1,
#               'champions\xa0\xa0': 5,
#               '"new': 1,
#               'technology': 1,
#               'skyrim': 1,
#               'major': 2,
#               'immature': 1,
#               '[but': 1,
#               'desktop': 1,
#               'tied': 1,
#               'rights': 1,
#               '[we]': 1,
#               '<br>': 2,
#               'eighth': 1,
#               'literature"': 1,
#               'pre-war': 1,
#               'byun': 1,
#               'yugoslav': 2,
#               'playing': 1,
#               '1993': 2,
#               '"vigilant",': 1,
#               'williams': 1,
#               'you': 3,
#               'natalya': 1,
#               'vegetables': 1,
#               'total': 1,
#               'lake': 1,
#               'full': 1,
#               'kneževo': 1,
#               'void': 1,
#               'lodève': 1,
#               'still': 1,
#               'gasoline"': 1,
#               'analysis': 1,
#               'fish': 1,
#               'history': 1,
#               'khas': 1,
#               'rock': 1,
#               'turnout': 4,
#               'jarek': 1,
#               'hyderabad': 1,
#               'lavery': 1,
#               '[he]': 1,
#               'sanders': 1,
#               'levin,': 1,
#               'designed': 1,
#               '"my': 1,
#               'player': 4,
#               'paradiso': 1,
#               'nandini,': 1,
#               'aya': 1,
#               'majursahi': 1,
#               'phoksundo': 1,
#               'jenkins': 1,
#               '135': 1,
#               'census': 1,
#               'ksrtc': 1,
#               'irrespective': 1,
#               'put': 1,
#               '2014': 1,
#               'space': 1,
#               'classmates': 1,
#               'attracted': 1,
#               'manoj': 1,
#               'composed': 1,
#               'mull': 1,
#               '(19)': 1,
#               'nasa': 1,
#               'kids': 1,
#               'though': 1,
#               'across': 1,
#               'storm': 1,
#               'damage': 1,
#               'parks': 1,
#               'mcmillan': 1,
#               'underwood': 1,
#               'cantwell': 1,
#               'good': 1,
#               'tempted': 1,
#               '(a': 1,
#               'nikolai': 1,
#               'keetmanshoop': 1,
#               'susanna': 1,
#               'chicago': 1,
#               'ishi': 1,
#               'opening': 1,
#               'schonberg': 1,
#               'bird"': 1,
#               'economic': 1,
#               'nova': 1,
#               'sheppard': 1,
#               'indicates': 2,
#               'pagasa': 1,
#               'nominations': 1,
#               '"as': 1,
#               'back-flip': 1,
#               'formal': 1,
#               'johnson': 1,
#               'green': 1,
#               'recently': 1,
#               "acastus's": 1,
#               'norton': 1,
#               'roarke': 1,
#               'vaillant': 1,
#               'lekima': 1,
#               "lekima's": 1,
#               'institutional': 1,
#               'jiří': 1,
#               'arceo': 1,
#               'shifted': 1,
#               'jethmalani': 1,
#               'partaking': 1,
#               'armonk': 1,
#               'west': 1,
#               'tornado': 1,
#               'thanks': 1,
#               '(continue': 1,
#               'ifugao': 1,
#               'howard': 1,
#               'semjonova': 1,
#               'buru': 1,
#               'inge': 1,
#               'catherine': 1,
#               'rashford': 1,
#               'bieber': 1,
#               'marand': 1,
#               'm’baku': 1,
#               'magar,': 1,
#               '(04%)': 1,
#               'names': 10,
#               'siberia': 1,
#               'far': 1,
#               'sverdlovsk': 1,
#               'idel-ural': 1,
#               'nenetsia': 1,
#               'kuban': 1,
#               'lenard': 1,
#               'september': 2,
#               'mud': 1,
#               'richeze': 1,
#               'fernando': 1,
#               'ekland': 1,
#               'arnous': 1,
#               '870%': 1,
#               '953%': 1,
#               '951%': 1,
#               '762%': 1,
#               '915%': 1,
#               '881%': 1,
#               '988%': 1,
#               '794%': 1,
#               '902%': 1,
#               '928%': 1,
#               'puttur': 1,
#               '"she"': 1,
#               'marlenee': 1,
#               'australian': 2,
#               '(6)': 2,
#               "won't": 1,
#               'norway': 1,
#               ...}),
#  'plastic': defaultdict(int,
#              {'arts,': 2,
#               'drinks': 1,
#               'it': 12,
#               '<eos>': 22,
#               'is': 14,
#               'some': 3,
#               'will': 1,
#               'looks': 1,
#               'in': 6,
#               'stronger': 1,
#               'these': 3,
#               'there': 4,
#               'and': 28,
#               'roof': 3,
#               'case': 5,
#               'wrap': 7,
#               'ice': 1,
#               'or': 53,
#               'objects': 3,
#               'products': 4,
#               'handles': 1,
#               'umbrella': 1,
#               'surgery': 36,
#               'for': 4,
#               'has': 1,
#               'when': 1,
#               'fibre': 1,
#               'condoms': 1,
#               'shaft': 1,
#               'ruler': 1,
#               'finish': 1,
#               'all': 2,
#               'leads': 1,
#               'to': 3,
#               'but': 2,
#               'ono': 15,
#               'discs': 1,
#               'card': 4,
#               'sacks': 1,
#               'many': 2,
#               'bags,': 5,
#               'casing': 1,
#               'cards': 6,
#               'things;': 1,
#               'surgeons': 1,
#               'they': 2,
#               'surgeries,': 1,
#               'light': 1,
#               'crockery': 1,
#               'bag': 17,
#               'safety': 1,
#               'made': 2,
#               'their': 1,
#               'this': 3,
#               'you': 1,
#               'bubble': 1,
#               'enclosure': 1,
#               'tube': 3,
#               'tipped': 2,
#               'tip': 1,
#               'man,': 2,
#               'may': 2,
#               'package': 1,
#               'pen': 1,
#               'recycling': 1,
#               'tape': 2,
#               'containers,': 2,
#               'sometimes': 1,
#               'cars,': 1,
#               'cutlery': 2,
#               'pins': 1,
#               'trees",': 1,
#               'trees"': 1,
#               'materials': 4,
#               'material': 4,
#               'bottles': 8,
#               'cartridges': 1,
#               'insulation': 1,
#               'recorders': 2,
#               'material"': 1,
#               'food': 1,
#               'sheets': 1,
#               'lamination': 1,
#               'bullet-proof': 1,
#               '': 2,
#               'eggs': 1,
#               'wheel': 1,
#               'strength': 1,
#               'body,': 1,
#               'wood,': 1,
#               'wood': 2,
#               'handcuffs,': 1,
#               'strips': 1,
#               'handcuffs': 1,
#               'restraints': 2,
#               'restraints,': 1,
#               'helmets': 3,
#               'tool': 1,
#               'can': 3,
#               'product': 1,
#               'automatically': 1,
#               'are': 4,
#               'boxes,': 2,
#               '"wood"': 1,
#               'building': 1,
#               'lego': 1,
#               'cases': 1,
#               'big': 1,
#               'tokens,': 1,
#               'one': 2,
#               'construction': 1,
#               'that': 10,
#               'coating': 1,
#               'which': 5,
#               'sacrificial': 1,
#               'from': 3,
#               'bag,': 2,
#               'the': 10,
#               'cover': 1,
#               'bottles,': 2,
#               'caps': 1,
#               'bottle': 2,
#               'shuttles': 1,
#               'shuttlecocks': 2,
#               '"clay",': 1,
#               'clay': 1,
#               'container': 4,
#               'polymer,': 1,
#               'facial': 1,
#               'deformation': 11,
#               'deformations,': 1,
#               'deformation,': 4,
#               'mixture': 1,
#               'sheet': 2,
#               'paste': 1,
#               'drinking': 2,
#               'body': 2,
#               'walls': 1,
#               'cylinder,': 1,
#               'used': 2,
#               'base': 1,
#               'parts,': 1,
#               'tubes,': 1,
#               '"vinyl"': 1,
#               'bubble"': 1,
#               'changes': 1,
#               'mate': 1,
#               'vacuum': 1,
#               'cuvettes': 1,
#               'pipes': 1,
#               'surgeries': 2,
#               'known': 1,
#               'raspberry': 1,
#               'base,': 1,
#               'on': 3,
#               'stylus': 1,
#               'acts': 1,
#               'stoppers,': 1,
#               'so': 1,
#               'exist': 1,
#               'glasses': 1,
#               'ribbon': 1,
#               'homeware': 1,
#               'mouthpiece': 1,
#               'because': 3,
#               'heads': 1,
#               'bags': 39,
#               'box': 2,
#               'ball': 1,
#               'waste': 9,
#               'eaten': 1,
#               'stops': 1,
#               'bait': 1,
#               'matrix': 1,
#               '(grp)': 1,
#               'frps': 1,
#               'similar': 1,
#               'wire,': 1,
#               'instead': 1,
#               'called': 2,
#               'gymnasts': 2,
#               'flooring': 1,
#               'a': 2,
#               'kitchen': 1,
#               'ones': 1,
#               'bottle,': 1,
#               'dolls': 1,
#               'jointed': 1,
#               'clothes': 1,
#               'age",': 1,
#               'before,': 1,
#               'confetti': 1,
#               'with': 4,
#               'except': 1,
#               'joystick': 1,
#               'bath': 1,
#               'rings,': 1,
#               'later': 2,
#               'cursor': 1,
#               'models': 1,
#               'intraocular': 1,
#               'pots': 2,
#               'containers': 2,
#               'apple': 1,
#               'explosives': 7,
#               'adult': 1,
#               'pieces': 2,
#               'soup': 2,
#               'straws': 1,
#               'come': 1,
#               'island': 2,
#               'toward': 1,
#               'handle': 1,
#               'spoons': 1,
#               'layer': 4,
#               'clogs': 1,
#               'support': 1,
#               'glued': 1,
#               'type': 1,
#               'cylinder': 1,
#               'parts': 3,
#               'guitar': 1,
#               'saxophone': 2,
#               'crucifix': 1,
#               'hairbrush': 1,
#               'by': 1,
#               'company': 1,
#               'version': 1,
#               'vuvuzela,': 1,
#               'art': 1,
#               'art,': 1,
#               'uses': 1,
#               'paint': 1,
#               'coated,': 1,
#               'cones': 1,
#               'collars': 1,
#               'helmet': 1,
#               'explosive': 4,
#               'teeth': 1,
#               'business,': 1,
#               'beads,': 1,
#               'arts)': 1,
#               'chairs': 1,
#               'surgery,': 7,
#               'beads': 1,
#               'finger': 1,
#               'tiles': 1,
#               'injection': 2,
#               'scale': 1,
#               'hand': 1,
#               'handguard': 1,
#               'magazines': 1,
#               'people': 8,
#               'case,': 1,
#               'plate': 2,
#               'mouth': 1,
#               'pens': 1,
#               'casings': 1,
#               'cable,': 1,
#               'object': 1,
#               'rod': 1,
#               'lets': 1,
#               'film': 4,
#               'provides': 1,
#               'balls': 1,
#               'soldiers,': 1,
#               'unlike': 1,
#               'toy': 1,
#               'toys,': 2,
#               'resin': 1,
#               'lenses': 1,
#               'duplicate': 1,
#               'man': 3,
#               'surgeon': 6,
#               'buttstock': 2,
#               'potentiometers,': 1,
#               'potentiometers': 1,
#               'lens': 1,
#               'shielding': 1,
#               'panelling,': 1,
#               'supports': 1,
#               'dog': 1,
#               'bug': 1,
#               'fish': 1,
#               'brit': 1,
#               'explosive,': 1,
#               'reflector': 1,
#               'covered': 1,
#               'usually,': 1,
#               'ski': 1,
#               'pistol': 1,
#               'compounds': 1,
#               'sheds': 1,
#               'arts': 5,
#               'lures,': 1,
#               'worms': 1,
#               'renewal': 1,
#               'wrapping': 2,
#               'weights': 1,
#               'fishing': 1,
#               'shell': 1,
#               'steel': 1,
#               'became': 1,
#               'pollution"': 1,
#               'floating': 1,
#               'window': 1,
#               'enclosures,': 1,
#               'rollers': 1,
#               'was': 2,
#               'artist,': 1,
#               '(such': 1,
#               'part': 1,
#               'bucket': 1,
#               'artists': 1,
#               'pollution': 5,
#               'optical': 1,
#               'neck': 1,
#               'lid': 1,
#               'frame': 1,
#               'exercise': 1,
#               'disposable': 1,
#               'screen': 1,
#               'frame,': 1,
#               'gloves': 1,
#               'cards,': 1,
#               'an': 1,
#               'debris': 1,
#               'rubbish': 1,
#               'frills': 1,
#               'toothpicks,': 1,
#               'film,': 1,
#               'textile': 1,
#               'films': 1,
#               'behaviour': 1,
#               'model': 1,
#               'photographic': 1,
#               'mouse': 1,
#               'surgeon,': 1,
#               'shopping': 1,
#               'pellets': 2,
#               'garbage': 1,
#               'cans,': 1,
#               'behind': 1,
#               'between': 1,
#               'trophy': 1,
#               'wheels': 1,
#               'waste,': 1,
#               'according': 1,
#               'contribute': 1,
#               'surgery-related': 1,
#               'experience,': 1,
#               'inquiry': 1,
#               'club,': 1,
#               'media': 1,
#               "it's": 1,
#               'glider': 1,
#               'bullets': 1,
#               'shoes': 1,
#               'specifically': 1,
#               'sliding': 1,
#               'carryout': 1,
#               'particles': 2,
#               'sheen,': 1,
#               'through': 1,
#               'tanks': 2,
#               'then': 1,
#               'hearts': 3,
#               'before': 1}),
#  'rostal': defaultdict(int,
#              {'that': 1,
#               'was': 1,
#               'there': 1,
#               'the': 1,
#               '<eos>': 1,
#               '(born': 1,
#               'played': 1,
#               'who': 1}),
#  'buras': defaultdict(int, {'is': 1, '<eos>': 1}),
#  'classique"': defaultdict(int, {'according': 1, 'and': 1}),
#  '"feed': defaultdict(int,
#              {'reader",': 1,
#               'and': 1,
#               'the': 1,
#               'me': 1,
#               'our': 1,
#               'tha': 2,
#               'your': 1,
#               'my': 1}),
#  'animatronics': defaultdict(int,
#              {'': 1,
#               'and': 1,
#               '<eos>': 1,
#               'is': 1,
#               'began': 1,
#               'for': 1,
#               'in': 2,
#               'are': 1,
#               'wandering': 1,
#               'as': 1,
#               'from': 3,
#               '-': 1,
#               'will': 1,
#               'getting': 1,
#               'may': 1,
#               'cannot': 1,
#               'figure': 1,
#               'freddy': 1}),
#  'stoyanka': defaultdict(int, {'mutafova': 2}),
#  'nothing"': defaultdict(int,
#              {'london': 1,
#               'since': 1,
#               '<eos>': 9,
#               'with': 3,
#               'but': 1,
#               'ronaldo': 1,
#               '': 5,
#               'a': 1,
#               'he': 1,
#               'and': 6,
#               'by': 3,
#               'she': 1,
#               'as': 1,
#               'in': 1,
#               '(1993),': 3,
#               ';': 1,
#               'it': 2,
#               '(2002),': 1,
#               'the': 1,
#               'when': 1,
#               '(1985)': 1,
#               'which': 1,
#               '(2002)': 1,
#               'is': 2,
#               'was': 1,
#               'has': 1,
#               'created': 1,
#               '(2007),': 1,
#               'gamble': 1,
#               'cody': 1}),
#  'else': defaultdict(int,
#              {'these': 3,
#               'they': 20,
#               'every': 2,
#               'on': 26,
#               'larger': 1,
#               'are': 2,
#               'from': 10,
#               'people': 1,
#               'who': 9,
#               'may': 3,
#               '<eos>': 84,
#               'take': 1,
#               'astronomers': 1,
#               '': 16,
#               'being': 2,
#               'has': 13,
#               'for': 11,
#               'all': 2,
#               'can': 21,
#               'that': 23,
#               'many': 3,
#               'at': 4,
#               'it': 18,
#               'in': 88,
#               'affecting': 1,
#               'is': 34,
#               'die,': 1,
#               'some': 5,
#               'when': 9,
#               'such': 2,
#               'started': 1,
#               'did': 4,
#               'the': 39,
#               'again': 1,
#               'to': 67,
#               'without': 4,
#               'owns': 1,
#               'this': 12,
#               'werther': 1,
#               'had': 7,
#               'he': 21,
#               'i': 5,
#               'wants': 1,
#               'needs': 1,
#               '"freedom': 1,
#               'would': 5,
#               'or': 3,
#               'cameras': 1,
#               'bid': 1,
#               'invaded': 1,
#               'acts': 1,
#               'and': 15,
#               'you': 3,
#               'before': 2,
#               'could': 12,
#               'while': 5,
#               'a': 6,
#               'laughs': 1,
#               'was': 12,
#               'but': 9,
#               'sees': 2,
#               'used': 1,
#               'most': 3,
#               '"an': 1,
#               'fungi': 1,
#               'telling': 1,
#               'about': 10,
#               'plato,': 1,
#               'than': 9,
#               'created': 1,
#               'if': 11,
#               'erections': 1,
#               'own': 1,
#               'copies': 1,
#               'because': 5,
#               'fails': 1,
#               'later,': 2,
#               'usually,': 3,
#               'others': 2,
#               'against': 1,
#               'finds': 1,
#               'among': 1,
#               'so': 4,
#               'then': 2,
#               'drivers': 1,
#               'sexually,': 3,
#               'were': 1,
#               'eileen': 1,
#               'do': 5,
#               'should': 2,
#               'what': 1,
#               'sometimes': 1,
#               'realise': 1,
#               'not': 2,
#               'hypnotic': 1,
#               'block': 2,
#               '{': 2,
#               'with': 4,
#               'above': 1,
#               '(one': 1,
#               'matters"': 2,
#               'often,': 1,
#               'makes': 1,
#               '(latin': 1,
#               'matters",': 2,
#               '(49%)': 1,
#               'which': 1,
#               'brings': 1,
#               'meant': 1,
#               'very': 1,
#               'extinction': 1,
#               'as': 5,
#               'atoms': 1,
#               'says': 1,
#               'thrown': 1,
#               'flammable': 1,
#               'labor': 1,
#               'made': 1,
#               'mistaking': 1,
#               'there': 8,
#               'marked': 1,
#               'comes': 2,
#               'have': 1,
#               'asked': 2,
#               '-': 2,
#               '(which': 1,
#               'understands': 1,
#               'will': 9,
#               'someone': 1,
#               'robson': 1,
#               'uses': 2,
#               'believe': 1,
#               'can,': 1,
#               'hears': 1,
#               'transformed': 1,
#               'tickled': 1,
#               'knows': 2,
#               'around': 2,
#               'by': 3,
#               'holding': 1,
#               'where': 3,
#               'does': 2,
#               'cannot': 1,
#               'useful,': 1,
#               'his': 1,
#               'wrote': 2,
#               'soon': 1,
#               'wanted': 2,
#               'usually': 2,
#               'miller': 1,
#               'too': 1,
#               'much': 1,
#               'put': 1,
#               '(called': 1,
#               'sent': 1,
#               'pretending': 1,
#               'worse': 1,
#               'better': 1,
#               'secondly,': 1,
#               'thus,': 1,
#               'talking': 1,
#               'using': 1,
#               'amy': 1,
#               'normally,': 1,
#               'its': 1,
#               'cuban': 1,
#               'robbers': 1,
#               'answer': 1,
#               'amory': 1,
#               'those': 1,
#               'scientists': 2,
#               'happened:': 1,
#               'go,': 1,
#               'thinks': 1,
#               'believed': 1,
#               'starts': 1,
#               'she': 2,
#               'be': 3,
#               'actually': 1,
#               'card': 1,
#               'one': 2,
#               'alfelt': 7,
#               'knut': 1,
#               'lewicki': 1,
#               'appeared': 1,
#               'nozick': 1,
#               'interested': 1,
#               '"proxy"': 1,
#               'really': 1,
#               '(see': 1,
#               'played': 1,
#               'moscow': 1,
#               'her': 1,
#               'entirely': 1,
#               'instead': 2,
#               'calling': 1,
#               'bears': 1,
#               'during': 4,
#               'kuzco': 1,
#               'chaos': 1,
#               'due': 1,
#               'suited': 1,
#               'won': 1,
#               'drumming': 1,
#               '(usually': 2,
#               '("false': 1,
#               'opposes': 1,
#               '"els"': 1,
#               'discover': 1,
#               'written': 1,
#               'gets"': 1,
#               'pursued': 1,
#               'politicians': 1,
#               'runs': 1,
#               'stanley': 1,
#               'claiming': 1,
#               'forgiveness': 1,
#               'immigrants': 1,
#               "it's": 1,
#               'tries': 1,
#               'so,': 2,
#               'islands': 1,
#               '"nothing': 1,
#               '(for': 1,
#               'aerosol': 1,
#               'until': 1,
#               'suspected': 1,
#               'later': 1,
#               'kidnapped': 1,
#               'almost': 1,
#               'minarchists': 1,
#               'ran': 1,
#               'käte': 1,
#               'ever': 1,
#               'willing': 1,
#               'except': 1,
#               'united': 1,
#               'joseph': 1,
#               'koch,': 1,
#               'middle': 1,
#               'other': 2,
#               'commit': 1,
#               'families': 1,
#               'endemic': 1,
#               'interfering': 1,
#               'under': 1,
#               "you'd": 1,
#               'beneath': 1,
#               'fail': 1,
#               'canadian': 1,
#               'heller,': 1,
#               'satisfaction': 1,
#               'martin': 1,
#               'go': 1,
#               'builds': 1,
#               'guru': 1,
#               'running)': 1,
#               'listened': 1,
#               'marie': 2,
#               'we': 1,
#               'dinosaurs': 1,
#               'outside': 1,
#               '(plants,': 1,
#               'did,': 2,
#               "that's": 1,
#               'suffers': 1,
#               'sings': 1,
#               'sahiban': 1,
#               'attack,': 1,
#               "alfelt's": 2,
#               'alfelts': 2,
#               'male': 1,
#               'open': 1,
#               'matters': 1,
#               'mounted': 1,
#               'j': 1,
#               'left,': 1,
#               'just': 1,
#               'devastated,': 1,
#               "nizami's": 1,
#               'might': 1,
#               'means': 1}),
#  'juegos"': defaultdict(int, {'described': 1, '<eos>': 1}),
#  "sunflower's": defaultdict(int, {'cluster': 1, 'head': 1}),
#  'coursera': defaultdict(int,
#              {'<eos>': 2,
#               '100%': 1,
#               'courses': 2,
#               'is': 1,
#               'partners': 1,
#               'also': 1}),
#  '(43)': defaultdict(int, {'the': 1, 'of': 1}),
#  '"established': defaultdict(int,
#              {'a': 1, 'permanent': 2, 'the': 1, 'landholding': 2}),
#  'tebet': defaultdict(int, {'is': 1, 'em': 1, '<eos>': 1, '(;': 1, 'came': 1}),
#  "book'": defaultdict(int, {'in': 1, 'he': 1, 'both': 1}),
#  'wbf': defaultdict(int, {'is': 1, 'for': 1, 'heavyweight': 1}),
#  '"vodka"': defaultdict(int, {'comes': 1, 'in': 1}),
#  'bygone': defaultdict(int, {'memory': 1, 'environment': 1, 'years': 1}),
#  'keyboardists,': defaultdict(int, {'such': 1, 'for': 1}),
#  'healthful': defaultdict(int, {'a': 1, 'than': 1, 'while': 1}),
#  "abigail's": defaultdict(int,
#              {'act': 1,
#               'distraction,': 1,
#               'relatives,': 1,
#               'appearances': 1,
#               'final': 1,
#               'town': 1}),
#  'punjab,': defaultdict(int,
#              {'india': 34,
#               'british': 16,
#               'pakistan': 77,
#               'the': 5,
#               'sir': 2,
# ...
#  'niger-congo': defaultdict(int,
#              {'languages': 6,
#               'language': 10,
#               'bantu': 1,
#               'group': 1,
#               "languages'": 1,
#               'languages,': 1}),
#  'auto-tune': defaultdict(int,
#              {'the': 2,
#               'processor': 1,
#               'and': 2,
#               '<eos>': 2,
#               'is': 1,
#               'uses': 1,
#               'can': 2,
#               'has': 1,
#               'was': 2,
#               'became': 1,
#               'in': 3,
#               'to': 2,
#               'bandwagon': 1,
#               "wasn't": 1,
#               'people': 1,
#               'a': 1,
#               'save': 1,
#               'for': 2,
#               'although': 1,
#               'pitch': 1,
#               'it': 1,
#               'other': 1,
#               'over': 1}),
#  'bbl': defaultdict(int,
#              {'determines': 1, 'in': 1, '<eos>': 1, 'or': 1, 'was': 1}),
#  '"iceland\'s': defaultdict(int, {'biggest': 1, 'cozy,': 1}),
#  'teresa': defaultdict(int,
#              {'heinz': 4,
#               'rodríguez': 1,
#               'johnson': 1,
#               'is': 2,
#               'caught': 1,
#               'took': 1,
#               'quickly': 1,
#               'have': 1,
#               'benedicta': 2,
#               'white': 1,
#               '<eos>': 4,
#               '(26': 1,
#               'of': 26,
#               'was': 6,
#               'recieved': 1,
#               'received': 1,
#               'called': 2,
#               'antónia': 1,
#               'stratas,': 2,
#               'victoria': 1,
#               'carpio,': 1,
#               '(née': 1,
#               '(although': 1,
#               'they': 1,
#               'stratas': 2,
#               'stuart': 2,
#               'and': 5,
#               'rafaela': 5,
#               'antonia': 2,
#               'married': 3,
#               'to': 1,
#               "d'este": 1,
#               '(india)': 1,
#               'as': 1,
#               'anna,': 1,
#               'carpenter,': 1,
#               'jusino': 1,
#               'anna': 1,
#               'cheng,': 1,
#               'hospital,': 1,
#               'chose': 1,
#               'marie': 1,
#               'sánchez': 3,
#               'palmer': 1,
#               'mary': 1,
#               'palmer,': 2,
#               'scanlan': 1,
#               'michelle': 1,
#               'kilmer': 1,
#               'eory': 1,
#               'herreras': 2,
#               'wright': 2,
#               'wright;': 1,
#               'perales': 3,
#               'stowe': 1,
#               'in': 3,
#               "o'brien": 1,
#               'brewer': 2,
#               'brewer,': 1,
#               'de': 4,
#               'felicitas': 3,
#               'gorman': 1,
#               'ellen': 1,
#               'it': 1,
#               'wore': 1,
#               'changed': 1,
#               'died': 2,
#               'bagioli': 1,
#               'at': 1,
#               'li': 1,
#               'francesca': 1,
#               'marta': 1,
#               'gisbert': 2,
#               'banks': 1,
#               'krzyżanowska': 1,
#               'gallura': 2,
#               'orlowski': 1,
#               'brittain': 1,
#               'petrillo': 1,
#               'estela': 1,
#               'mother': 1,
#               'she': 1,
#               'supported': 1,
#               'aquino-oreta': 2,
#               'aquino': 1,
#               'horta': 3,
#               'mascarenhas': 1,
#               'colom': 1,
#               'i': 1,
#               'his': 1,
#               '(born': 1,
#               'mestre': 1,
#               'carpio)': 1,
#               'wright,': 4,
#               'leger': 3,
#               'betancourt': 1,
#               'later': 1,
#               'moreau': 1,
#               'had': 1,
#               'airport': 1,
#               'żylis-gara': 2,
#               'carpenter': 1,
#               'squerciati': 1,
#               'jiménez': 2,
#               'memorial': 1,
#               'lisbon': 1,
#               'berganza': 2,
#               'taylor,': 1,
#               'anne': 1,
#               'di': 1,
#               'gallagher': 2,
#               'ruiz': 1,
#               'cristina,': 1,
#               'edwards': 1,
#               'nuñez': 2,
#               'competed': 1,
#               'mcdonnell': 2,
#               'giudice': 2,
#               'russo': 1,
#               'cortez': 1,
#               '': 1,
#               'charlotte': 1}),
#  'unlisted': defaultdict(int, {'his': 1, 'public': 1}),
#  'dharmachakra': defaultdict(int, {'comes': 1}),
#  'rottaro': defaultdict(int, {'<eos>': 1, 'is': 1}),
#  'wharf"),': defaultdict(int, {'also': 1, 'is': 1}),
#  'sigrid,': defaultdict(int, {'gunhilda': 1, 'sigrid': 1}),
#  'hdl': defaultdict(int,
#              {'(high': 1,
#               'cholesterol': 1,
#               '(good)': 2,
#               'is': 1,
#               '("good"': 1,
#               'code': 1,
#               'and': 1}),
#  '"111"': defaultdict(int, {'in': 1, '-': 1, '<eos>': 1}),
#  'saint-yan': defaultdict(int,
#              {'and': 1,
#               'or': 1,
#               '<eos>': 2,
#               'is': 1,
#               'in': 1,
#               'welcomes': 1,
#               'airport': 2}),
#  '"madame': defaultdict(int,
#              {'doubtfire"': 1,
#               'x",': 2,
#               'a': 1,
#               'figaro"': 1,
#               'bovary"': 4,
#               'butterfly"': 4,
#               'butterfly",': 1,
#               'la': 2,
#               'royale",': 3,
#               'première"': 1,
#               'infante"': 2,
#               'royale"': 2,
#               'du': 3,
#               'cézanne': 1,
#               'pimp"': 1,
#               'satan",': 1,
#               'de': 1,
#               'de"': 1,
#               'rosa",': 1,
#               'sin"': 1,
#               'curie"': 1,
#               'web"': 3}),
#  'bellicourt': defaultdict(int, {'<eos>': 1, 'is': 1}),
#  'sungkyunkwan': defaultdict(int, {'university,': 2, 'university': 3}),
#  'khawla': defaultdict(int, {'bint': 2}),
#  'oxymoron': defaultdict(int,
#              {'<eos>': 1, 'is': 2, 'for': 2, 'this': 1, 'because': 1}),
#  '"es",': defaultdict(int, {'"ha",': 2}),
#  'adjust': defaultdict(int,
#              {'a': 1,
#               'the': 42,
#               'this': 1,
#               'their': 15,
#               'your': 3,
#               'to': 33,
#               'and': 1,
#               'what': 1,
#               "one's": 1,
#               'his': 2,
#               'our': 2,
#               'its': 3,
#               'or': 1,
#               'for': 4,
#               'it': 2,
#               'any': 1,
#               'them': 1,
#               'itself': 1,
#               'in': 1,
#               'appetite': 1,
#               'over': 1,
#               'mortar': 1,
#               'loudness,': 1,
#               'they': 1,
#               'how': 1,
#               'brain': 1,
#               'as': 1,
#               'color': 1,
#               'boundaries': 1,
#               'things': 1}),
#  'konex': defaultdict(int,
#              {'award': 5, 'awards;': 1, 'foundation': 1, 'prize': 1}),
#  'bhartiya': defaultdict(int, {'janta': 2, 'kshatriya': 1}),
#  'semi-autonomous': defaultdict(int,
#              {'within': 1,
#               'province': 1,
#               'region': 1,
#               'elderly': 1,
#               'with': 1,
#               'jurisdiction': 1}),
#  'basilé': defaultdict(int, {'national': 2}),
#  'stadiums': defaultdict(int,
#              {'or': 1,
#               'have': 2,
#               'in': 25,
#               'use': 1,
#               'such': 1,
#               'rock': 1,
#               'were': 5,
#               'include': 1,
#               'are': 8,
#               '<eos>': 14,
#               'ready': 1,
#               'and': 8,
#               'the': 3,
#               'will': 1,
#               'by': 4,
#               'called': 2,
#               'listed': 2,
#               'they': 1,
#               'it': 3,
#               'to': 3,
#               'caused': 1,
#               'around': 2,
#               'of': 2,
#               'laid': 1,
#               'as': 2,
#               'where': 9,
#               'has': 1,
#               'named': 1,
#               'there': 1,
#               'with': 1,
#               'which': 4,
#               'began': 1,
#               'had': 1,
#               'because': 1,
#               'on': 1,
#               'can': 1,
#               'for': 3,
#               'shared': 1,
#               'used': 3,
#               'across': 2,
#               'that': 2,
#               'one': 1,
#               'also': 1,
#               'without': 1,
#               'located': 2,
#               'nearby': 1,
#               'instead': 1,
#               'owned': 2,
#               'at': 1,
#               '': 3,
#               'each': 1}),
#  '"all\'s': defaultdict(int, {'well"': 1, 'fair:': 1, 'well': 1}),
#  '37-year-old': defaultdict(int,
#              {'man': 3, 'steve': 1, 'turkish': 1, 'male': 1}),
#  'veracity': defaultdict(int, {'of': 5}),
#  'voxel': defaultdict(int, {'art': 4, 'editor': 1, 'cube': 1}),
#  'spezia': defaultdict(int,
#              {'<eos>': 3,
#               'is': 1,
#               'province': 1,
#               'calcio': 2,
#               'he': 2,
#               '(,': 1,
#               'in': 1}),
#  '6349': defaultdict(int, {'hollywood': 1, 'child': 1}),
#  'kopparberg': defaultdict(int, {'county': 1, '<eos>': 2, 'is': 1}),
#  'sehol': defaultdict(int,
#              {'brand,': 1,
#               'a5,': 1,
#               'x4,': 1,
#               'x7': 1,
#               'brand': 5,
#               'models,': 1,
#               '(;': 1,
#               '<eos>': 2,
#               'models': 1}),
#  'compliance': defaultdict(int,
#              {'functions': 1,
#               'with': 19,
#               'for': 2,
#               'officer': 1,
#               'and': 4,
#               'alternatively,': 1,
#               'labs': 1,
#               'was': 2,
#               'chief,': 1,
#               'to': 3,
#               'of': 1,
#               '(medicine)': 1,
#               'or': 1,
#               'is': 4,
#               'rates': 1,
#               'other': 1,
#               'are': 1,
#               'have': 1,
#               'act)': 1,
#               'agreement': 1,
#               'in': 2,
#               'has': 1,
#               'edition': 1,
#               'duties': 1,
#               'solutions': 1,
#               'practices,': 1,
#               'solution"': 1,
#               'these': 1,
#               'she': 1,
#               'reaction': 1}),
#  'auxilia': defaultdict(int, {'and': 1, 'were': 1}),
#  'anholt': defaultdict(int,
#              {'during': 1,
#               'a': 1,
#               '<eos>': 3,
#               'known': 1,
#               'was': 1,
#               'of': 1,
#               'and': 1,
#               '(born': 1,
#               'his': 1}),
#  'awards”"': defaultdict(int, {'and': 1, 'several': 1}),
#  'mutinies': defaultdict(int, {'that': 1, 'in': 2, '': 1}),
#  "sudan's": defaultdict(int,
#              {'largest': 1,
#               'government': 2,
#               'government,': 1,
#               'resources"': 1,
#               'head': 1,
#               'economy': 2,
#               'people': 3,
#               'council': 1,
#               'human': 1}),
#  'biflagellate': defaultdict(int, {'gametes': 1}),
#  'kyber': defaultdict(int, {'crystal': 1}),
#  'carcinomas,': defaultdict(int,
#              {'10%': 1, 'with': 1, 'reflecting': 1, 'is': 1}),
#  '"europe': defaultdict(int, {'first"': 1, 'echecs"': 1, '–': 1}),
#  '1726–': defaultdict(int, {'december': 1, 'april': 1}),
#  'lignin,': defaultdict(int, {'a': 1, 'while': 1, 'among': 1, 'but': 1}),
#  'somehow': defaultdict(int,
#              {'a': 1,
#               'worked': 1,
#               'both': 3,
#               'make': 1,
#               'produces': 1,
#               '<eos>': 2,
#               'spawned': 1,
#               'lost': 1,
#               'managed': 4,
#               'tell': 1,
#               'more': 1,
#               'works"': 1,
#               'erased': 1,
#               'receives': 1,
#               'attached': 1,
#               'believe': 1,
#               'used': 1,
#               'survived,': 1,
#               'shaped': 1,
#               'he': 4,
#               'by': 1,
#               'resurrected,': 1,
#               'but': 1,
#               'in': 2,
#               'stop': 1,
#               'helped': 1,
#               'lessen': 1,
#               'less': 1,
#               'seemingly': 1,
#               'change': 1,
#               'not': 1,
#               'survived': 2,
#               '"both"': 1,
#               'involved': 1,
#               'became': 1,
#               'still': 1,
#               'hidden)': 1,
#               'related,': 1,
#               'before': 1,
#               'got': 1,
#               'part': 1,
#               'to': 1,
#               'leaked': 1,
#               'devolved': 1,
#               'goes': 1,
#               'problematic': 1,
#               'never': 1,
#               'stripped': 1,
#               'i': 1,
#               'has': 1,
#               'get': 1,
#               'gained': 1,
#               'the': 3,
#               'and': 2,
#               'becomes': 1,
#               'manages': 2,
#               'help': 1,
#               'an': 1,
#               'modifies': 1,
#               'confused': 1,
#               'able': 1,
#               'identical': 1,
#               'function': 1,
#               'influenced': 1,
#               'schrödinger': 1,
#               'seem': 1,
#               'caught': 1,
#               'they': 1,
#               'escaped': 2,
#               'interfere': 1,
#               'been': 1,
#               'it': 1,
#               'tries': 1,
#               'realizes': 1,
#               'knew': 1,
#               'rajapala': 1,
#               'cleverly': 1,
#               'globally': 1,
#               'prevent': 1,
#               'possessing': 1,
#               'created': 1,
#               'different': 1,
#               'raise': 1,
#               'resurrected': 1,
#               'with': 1,
#               'always': 1,
#               'she': 1,
#               'imitate': 1,
#               'criticized': 1,
#               'large': 1}),
#  'richie': defaultdict(int,
#              {'in': 2,
#               'performed': 1,
#               'cunningham': 1,
#               'faulkner': 2,
#               '<eos>': 5,
#               '(born': 2,
#               'was': 5,
#               'returned': 1,
#               'made': 1,
#               'adopted': 1,
#               'she': 1,
#               'after': 1,
#               'were': 1,
#               'and': 9,
#               'it': 4,
#               'faced': 1,
#               'is': 1,
#               'doing': 1,
#               'sambora,': 3,
#               'hide': 1,
#               'benaud': 2,
#               'west,': 1,
#               'unterberger': 2,
#               'ryan,': 1,
#               'barron,': 1,
#               'foran': 1,
#               'valens': 1,
#               'cunningham,': 1,
#               'tozier': 4,
#               'sang': 1,
#               'dunn': 2,
#               '(april': 1,
#               'died': 1,
#               'd': 1,
#               'havens': 1,
#               'steamboat': 1,
#               'pratt': 2,
#               'rich': 4,
#               'sambora': 1,
#               'morales,': 1,
#               'roberts': 1,
#               'of': 1,
#               'evans': 1,
#               'barker': 1,
#               'joseph': 1,
#               'aprile': 1,
#               'song)': 3,
#               'stringini': 6,
#               'began': 1,
#               'knocked': 1,
#               'album)': 1,
#               'williamson,': 1,
#               'berrington': 1}),
#  'vax': defaultdict(int, {'computers': 1, 'servers': 1}),
#  'paysandú': defaultdict(int,
#              {'<eos>': 4, 'department': 8, 'is': 4, 'and': 2, 'he': 1}),
#  'idiot"': defaultdict(int,
#              {'sold': 1,
#               'the': 2,
#               'and': 1,
#               'it': 1,
#               '(2004)': 1,
#               '<eos>': 2,
#               '': 1,
#               'is': 3,
#               'by': 1,
#               '(1951),': 1,
#               'he': 1,
#               'benny': 1}),
#  'cuillé': defaultdict(int, {'<eos>': 1, 'is': 1}),
#  'borutta': defaultdict(int, {'<eos>': 1}),
#  '"beluga"': defaultdict(int, {'to': 1, 'super': 1}),
#  'exclaves:': defaultdict(int, {}),
#  'icona': defaultdict(int, {'pop': 7, 'pop"': 1}),
#  ...}

# %%
bigram_probabilities = {v: defaultdict(int) for v in vocab}
# Find out the bi-gram probabilities. For this divide the Bi-gram counts of x1,x2 by Uni-gram counts of x1
for x1 in bigram_counts:
    for x2 in bigram_counts[x1]:
      # Your Code here
        bigram_probabilities[x1][x2] = bigram_counts[x1][x2] / unigram_counts[x1]

# %%
# Print Bi-gram probability of black cat
bigram_probabilities["black"]["cat"]
# Out:
# 0.0022091310751104565

# %%
# Print Bi-gram probability of green cat
# From the probability you can understand that green cats do not exist (at least are not common)
bigram_probabilities["green"]["cat"]
# Out:
# 0

# %%
# Complete the function to find probability of a sequence.
# if you have sequence s = {w1,w2,w3,w4}
# P(s) = p(w1,w2)*p(w2,w3)*p(w3,w4)
def sequence_probability(s):
    # words contain list of words in sequence s
    words = preprocess(s)
    # List to contain all transition Bi-gram probabilities, i.e., [p(w1,w2),p(w2,w3),p(w3,w4)]
    transition_probs = []
    for i in range(len(words)-1):
        # Gets consecutive words. x1,x2 will get w1,w2 then w2,w3 and so on
        x1, x2 = words[i], words[i+1]
        # Get the bi-gram probabilities of the transitions, i.e., p(w1,w2)
        # Your code here
        transition_prob = bigram_probabilities[x1][x2]
        # Insert the transition prob in list transition_probs
        # Your code here
        transition_probs.append(transition_prob)

    # Calculate the sequence probability using transition_probs list.
    # Hint: transition_prob contains [p(w1,w2),p(w2,w3),p(w3,w4)] and your sequence prob P(s) = p(w1,w2)*p(w2,w3)*p(w3,w4)
    # Your Code here
    prob = 1
    for transition_prob in transition_probs:
        prob += transition_prob
    
    return prob

# %%
sequences = ["i like fish", "i likes fish", "me likes fish"]
probs = [(s, sequence_probability(s)) for s in sequences]
sorted(probs, key = lambda x: x[1], reverse=True)
# it can catch ungrammatical constructions
# Out:
# [('i like fish', 1.0598181288715858),
#  ('i likes fish', 1.0567765490663619),
#  ('me likes fish', 1.0562380237452258)]

# %%
sequences = ["i like burgers", "i like fish", "i like snakes"]
probs = [(s, sequence_probability(s)) for s in sequences]
sorted(probs, key = lambda x: x[1], reverse=True)
# burgers are in the unigrams, but there is no fitting bigram --> unknown / low-frequency word problem
# Out:
# [('i like burgers', 1.0864018451806203),
#  ('i like snakes', 1.064612363072076),
#  ('i like fish', 1.0598181288715858)]

# %%
sequences = ["i like fish", "i like fried fish", "i like fried fish with potatoes"]
probs = [(s, sequence_probability(s)) for s in sequences]
sorted(probs, key = lambda x: x[1], reverse=True)
# longer sequences will have lower probability
# Out:
# [('i like fried fish with potatoes', 1.126865258765832),
#  ('i like fried fish', 1.0733548148072751),
#  ('i like fish', 1.0598181288715858)]

# %%
# Out:
# 'can'

# %%
# Comlete the function on generating sequences. For this you will follow a greedy approach where you select the next word on the basis of highest bi-gram probability.
# Basically if the last word is w, you find the word x which has the highest bi-gram probability P(w,x)
# The function takes the starting word and the length of the sequence you want to generate
def generate(start_word, length = 2):
    output = [start_word]
    # You need to generate length-1 number of words so loop over that many times
    for i in range(0, length-1):
        # If last word in output(till now) is not in bigram_probabilities we will stop the generation
        if output[i] not in bigram_probabilities:
            break
        else:
          # Find the Bi-gram probabilities of all words with the last word in output(till now). The last word in output(till now) is basically output[i]
          # Then find the word which has the highest probability and add it to the output string
          # Your code here
          output.append(max(bigram_probabilities[output[i]], key=bigram_probabilities[output[i]].get))

    return output

# %%
# Use the generate function to generate a sequence of length 10 starting with the word "cats"
# Your Code here
generate('cats', 10)
# Out:
# ['cats', 'are', 'the', 'first', 'time', 'in', 'the', 'first', 'time', 'in']

# %%
# Use the generate function to generate a sequence of length 10 starting with the word "we"
# Your Code here
generate('we', 10)
# Out:
# ['we', 'can', 'be', 'a', 'commune', 'it', 'is', 'a', 'commune', 'it']

# %% [markdown]
# ## Watermarking

# %%
# Two sentences
s1 = "pigeons known for their remarkable homing ability and adaptability to urban environments have been companions and messengers to humans for thousands of years ."
s2 = "with their iridescent feathers and distinctive cooing pigeons add a unique charm to cityscapes around the world ."

# %%
w = s1.split(" ") + s2.split(" ")
vocab = set(w)

# %%
import pickle

with open('data/red_list.data', 'rb') as f:
        red_list = pickle.load(f)

# red_list contains which are words are red/green as next words. If the value of red_list[w1][w2] is True that means w2 cannot follow w1 and it is a violation.
# If the value of red_list[w1][w2] is False that means w2 can follow w1 and it is not a violation.

# %%
red_list['with']['their']
# Out:
# True

# %%
red_list['and']['distinctive']
# Out:
# False

# %%
# Now you have the red list in red_list
# Write a function to check the number of violations
# The function takes the sentence s and the redlist as inputs
def check(s, redlist):
    # Get the list of words
    w = s.split(" ")
    # Count number of violations
    # Remember the red list contains true and flase
    # You need to check if the value corresponding to consecutive words in w are True in redlist. If so violations count will go up by 1.
    violations = 0
    for i in range(0, len(w)-1):
        violations += 1 if  redlist[w[i]][w[i+1]] is True else 0
    return violations

check(s1, red_list), check(s2, red_list)
# Out:
# (0, 10)

# %%
# Calculate the probability of a human writing a sentence of the same length as s1 without ever violating the red list

# %%
# Calculate the probability of a human writing a sentence of the same length as s2 without ever violating the red list
