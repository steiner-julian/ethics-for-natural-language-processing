# %% [markdown]
# ## Task 1: Toy Bi-Gram LM

# %%
from collections import Counter, defaultdict
import random
import tqdm

# %%
# <BOS> is the beginning of sentence token
# <EOS> is the end of sentence token
def preprocess(s):
    s = "<BOS> " + s + " <EOS>"
    words = [w.replace(".", "") for w in s.lower().split(" ")]
    return words

# %%
# Mount your google drive
# Remove this code if you do not upload the file to your google drive
# Download it from: https://hessenbox.tu-darmstadt.de/getlink/fiCd4Ym2C61sGD2dVd1RqFNh/simple_wikipedia.zip
# from google.colab import drive
# drive.mount('/content/drive')

# %%
corpus = []
# Insert path to the text file
with open("data/simple_wikipedia.txt") as f:
    for line in f.readlines():
        line = line.replace("\n", "")
        if line:
            corpus += preprocess(line)

# %%
print(len(corpus))
# Out:
# 31756752

# %%
corpus[:10]
# Out:
# ['<bos>',
#  'april',
#  '<eos>',
#  '<bos>',
#  'april',
#  '(apr)',
#  'is',
#  'the',
#  'fourth',
#  'month']

# %%
# Counts the frequency of each word
c = Counter(corpus)

# %%
c
# Out:
# Counter({'the': 2019819,
#          '<bos>': 977830,
#          '<eos>': 977830,
#          'of': 959455,
#          'in': 943150,
#          'and': 760404,
#          'a': 684641,
#          'is': 568699,
#          'to': 502970,
#          'was': 452046,
#          'it': 268659,
#          'he': 263238,
#          'on': 235740,
#          'for': 230421,
#          'as': 198648,
#          'by': 183094,
#          'from': 167653,
#          'that': 158897,
#          'with': 153606,
#          'are': 147833,
#          'at': 140200,
#          'an': 130035,
#          'his': 127013,
#          'they': 104974,
#          'or': 92598,
#          'also': 91516,
#          'this': 88630,
#          'were': 87805,
#          'has': 87283,
#          'she': 84216,
#          '': 82948,
#          'be': 79419,
#          'people': 69889,
#          'which': 69247,
#          'first': 68312,
#          'not': 68291,
#          'have': 65044,
#          'one': 64075,
#          'their': 59631,
#          'there': 58565,
#          'had': 58248,
#          'after': 55698,
#          'her': 52567,
#          'new': 52158,
#          'but': 52135,
#          'united': 51956,
#          'other': 50375,
#          'many': 49080,
#          'who': 49013,
#          'its': 48641,
#          'can': 48599,
#          'when': 47039,
#          'known': 46551,
#          'about': 45974,
#          'city': 44066,
#          'american': 43152,
#          'called': 43131,
#          'used': 42748,
#          'two': 41936,
#          'made': 41717,
#          'states': 41421,
#          'most': 41048,
#          'some': 39908,
#          'born': 39186,
#          'may': 38635,
#          'been': 37109,
#          'more': 35844,
#          'all': 35609,
#          '–': 35247,
#          'died': 35107,
#          'into': 33914,
#          'world': 33257,
#          'during': 32823,
#          'became': 32455,
#          'national': 31108,
#          'part': 30102,
#          'because': 29949,
#          'movie': 29717,
#          'time': 29181,
#          'played': 28491,
#          'only': 28335,
#          'state': 28273,
#          'these': 28081,
#          '"the': 26799,
#          '(born': 26780,
#          'than': 26441,
#          'years': 26168,
#          'name': 26162,
#          'between': 26125,
#          'january': 24626,
#          'like': 24481,
#          'up': 24243,
#          'would': 24235,
#          'over': 24143,
#          'county': 23956,
#          'where': 23877,
#          'number': 23823,
#          'very': 23758,
#          'south': 23289,
#          'north': 23255,
#          'them': 23203,
#          'such': 23129,
#          'won': 23086,
#          'team': 22943,
#          'until': 22626,
#          'released': 22033,
#          'then': 21994,
#          'three': 21709,
#          'found': 21528,
#          'france': 21308,
#          'him': 20715,
#          'different': 20705,
#          'age': 20510,
#          'since': 20372,
#          'march': 20342,
#          'university': 20163,
#          'out': 19810,
#          'later': 19633,
#          'september': 19498,
#          'before': 19468,
#          'second': 19436,
#          'series': 19261,
#          'july': 19258,
#          'music': 19257,
#          'will': 19253,
#          'august': 19249,
#          'area': 19202,
#          'october': 19124,
#          'so': 19092,
#          'june': 19084,
#          'us': 19038,
#          'war': 18661,
#          'november': 18503,
#          'april': 18374,
#          'december': 18330,
#          'member': 18241,
#          'president': 18222,
#          'department': 18218,
#          'town': 18074,
#          'make': 17878,
#          'de': 17743,
#          'same': 17720,
#          'best': 17713,
#          'if': 17688,
#          'february': 17529,
#          'region': 17498,
#          'being': 17485,
#          'district': 17482,
#          'football': 17437,
#          'group': 17395,
#          'started': 17388,
#          'named': 17077,
#          'song': 16998,
#          'no': 16958,
#          'use': 16899,
#          'year': 16857,
#          'often': 16807,
#          'both': 16666,
#          'album': 16622,
#          'through': 16601,
#          'british': 16164,
#          'each': 16106,
#          'said': 15941,
#          '2020': 15899,
#          'did': 15897,
#          'while': 15789,
#          'against': 15671,
#          'commune': 15640,
#          'television': 15285,
#          'government': 15068,
#          'around': 15051,
#          'party': 15014,
#          'work': 14997,
#          'family': 14995,
#          'game': 14988,
#          'do': 14974,
#          'player': 14712,
#          'population': 14383,
#          'river': 14346,
#          'well': 14260,
#          'under': 14250,
#          'several': 14217,
#          'could': 14124,
#          'school': 14021,
#          'lived': 14000,
#          'place': 13928,
#          'main': 13889,
#          'former': 13823,
#          'west': 13742,
#          'however,': 13730,
#          'usually': 13630,
#          'including': 13610,
#          'municipality': 13447,
#          'four': 13373,
#          'county,': 13310,
#          'league': 13295,
#          'english': 13261,
#          'began': 13249,
#          'john': 13237,
#          '1': 13178,
#          'small': 13129,
#          'went': 12886,
#          'east': 12881,
#          'long': 12850,
#          'york': 12728,
#          'created': 12657,
#          'based': 12494,
#          'live': 12452,
#          'water': 12418,
#          'international': 12360,
#          'province': 12234,
#          'important': 12233,
#          'show': 12233,
#          'back': 12184,
#          'early': 12101,
#          'house': 11910,
#          'band': 11853,
#          'home': 11798,
#          'another': 11793,
#          'large': 11779,
#          'season': 11711,
#          'any': 11692,
#          'high': 11645,
#          'french': 11608,
#          'king': 11567,
#          'club': 11253,
#          'games': 11251,
#          'get': 11227,
#          'now': 11223,
#          'death': 11192,
#          '()': 11127,
#          'person': 11106,
#          '-': 11071,
#          'system': 11054,
#          'politician': 11009,
#          'country': 10947,
#          'end': 10880,
#          'old': 10810,
#          'much': 10753,
#          '2': 10745,
#          'last': 10736,
#          'company': 10733,
#          'what': 10721,
#          'means': 10539,
#          'famous': 10435,
#          'way': 10422,
#          'popular': 10410,
#          'century': 10345,
#          'life': 10335,
#          'written': 10325,
#          'million': 10314,
#          'single': 10295,
#          'near': 10291,
#          'germany': 10234,
#          'still': 10203,
#          'even': 10180,
#          'took': 10173,
#          'married': 10143,
#          'minister': 10099,
#          'left': 10019,
#          'moved': 9989,
#          'capital': 9973,
#          'how': 9857,
#          'language': 9856,
#          'list': 9777,
#          'award': 9768,
#          'day': 9719,
#          'general': 9694,
#          'england': 9693,
#          'largest': 9689,
#          'built': 9687,
#          'great': 9645,
#          'book': 9642,
#          'include': 9627,
#          'wrote': 9614,
#          'directed': 9555,
#          'play': 9530,
#          'came': 9516,
#          'german': 9497,
#          'sometimes': 9483,
#          'become': 9453,
#          'common': 9401,
#          'worked': 9364,
#          'japan': 9316,
#          'species': 9310,
#          'major': 9308,
#          'held': 9213,
#          'countries': 9181,
#          'third': 9155,
#          'children': 9132,
#          'island': 9030,
#          'own': 9021,
#          'following': 8963,
#          'living': 8944,
#          'given': 8944,
#          'members': 8867,
#          'central': 8816,
#          'i': 8763,
#          'five': 8738,
#          '3': 8679,
#          'served': 8641,
#          'form': 8617,
#          'cup': 8603,
#          'times': 8582,
#          'summer': 8561,
#          'western': 8526,
#          'using': 8446,
#          'good': 8380,
#          'aged': 8333,
#          'white': 8325,
#          'sea': 8317,
#          'army': 8311,
#          'northern': 8279,
#          'set': 8273,
#          'public': 8256,
#          'just': 8253,
#          'land': 8239,
#          'does': 8225,
#          'top': 8159,
#          'you': 8152,
#          '10': 8151,
#          'black': 8148,
#          'kingdom': 8143,
#          'role': 8122,
#          'founded': 8092,
#          '4': 8084,
#          'history': 8076,
#          'word': 8060,
#          'california': 8057,
#          'got': 8023,
#          'along': 8008,
#          'go': 7909,
#          'next': 7823,
#          'professional': 7802,
#          'power': 7788,
#          'film': 7787,
#          'down': 7763,
#          'published': 7749,
#          'together': 7737,
#          'every': 7735,
#          'church': 7728,
#          'air': 7682,
#          'again': 7681,
#          'video': 7664,
#          'things': 7662,
#          'actor': 7627,
#          'union': 7625,
#          'career': 7605,
#          'india': 7602,
#          'european': 7570,
#          'plays': 7547,
#          'parts': 7541,
#          'london': 7536,
#          'rock': 7518,
#          'political': 7516,
#          'center': 7502,
#          'order': 7495,
#          'seat': 7494,
#          'few': 7481,
#          'body': 7478,
#          'help': 7441,
#          'stars': 7439,
#          'located': 7425,
#          'station': 7423,
#          '2010': 7415,
#          'line': 7378,
#          'those': 7355,
#          'young': 7352,
#          '2019': 7321,
#          'making': 7303,
#          '2018': 7271,
#          'japanese': 7244,
#          'thought': 7234,
#          'southern': 7230,
#          '5': 7227,
#          'frog': 7219,
#          'human': 7209,
#          'father': 7206,
#          '2017': 7157,
#          'term': 7137,
#          'received': 7136,
#          'due': 7117,
#          'indian': 7116,
#          'take': 7109,
#          'village': 7106,
#          'killed': 7098,
#          'australia': 7081,
#          'women': 7049,
#          'seen': 7036,
#          'park': 7010,
#          'la': 7010,
#          'head': 7008,
#          'type': 6984,
#          'law': 6975,
#          '2011': 6970,
#          'works': 6946,
#          'red': 6946,
#          'championship': 6942,
#          'big': 6924,
#          'according': 6901,
#          'movies': 6893,
#          'studio': 6881,
#          'modern': 6840,
#          'st': 6833,
#          'led': 6778,
#          'college': 6754,
#          '2021': 6695,
#          'republic': 6672,
#          'son': 6663,
#          'without': 6661,
#          'military': 6656,
#          'election': 6640,
#          'joined': 6607,
#          'produced': 6602,
#          'six': 6580,
#          '2014': 6546,
#          'prime': 6502,
#          'ii': 6483,
#          'similar': 6482,
#          'special': 6457,
#          'james': 6449,
#          ',': 6447,
#          'italian': 6447,
#          'caused': 6428,
#          'announced': 6414,
#          'formed': 6406,
#          'man': 6400,
#          'lost': 6389,
#          'although': 6386,
#          '2008': 6384,
#          'put': 6339,
#          '12': 6330,
#          '20': 6320,
#          'original': 6306,
#          'off': 6305,
#          '2013': 6301,
#          'late': 6299,
#          'america': 6276,
#          'actress': 6262,
#          'lot': 6251,
#          'san': 6248,
#          'makes': 6232,
#          'songs': 6230,
#          'william': 6216,
#          'lives': 6193,
#          '2016': 6186,
#          'roman': 6179,
#          '15': 6151,
#          'playing': 6122,
#          'total': 6120,
#          '2007': 6108,
#          '2012': 6106,
#          'eastern': 6096,
#          'version': 6094,
#          'singer': 6092,
#          '6': 6086,
#          'elected': 6078,
#          'building': 6075,
#          'local': 6074,
#          'short': 6070,
#          'leader': 6068,
#          'story': 6066,
#          'changed': 6063,
#          'court': 6049,
#          "women's": 6038,
#          'george': 6035,
#          '2009': 6032,
#          'gave': 6030,
#          'appeared': 6021,
#          'mostly': 6016,
#          'time,': 6015,
#          'money': 5992,
#          'men': 5986,
#          'days': 5981,
#          '2006': 5962,
#          'side': 5945,
#          '2020,': 5941,
#          'italy': 5938,
#          'example,': 5919,
#          'away': 5897,
#          'director': 5894,
#          'we': 5893,
#          'royal': 5865,
#          'battle': 5865,
#          'others': 5857,
#          'office': 5848,
#          'title': 5845,
#          'australian': 5840,
#          'food': 5818,
#          'soviet': 5780,
#          'character': 5766,
#          'lake': 5766,
#          'record': 5758,
#          'social': 5745,
#          '&': 5732,
#          'governor': 5722,
#          '2015': 5715,
#          'among': 5697,
#          'right': 5673,
#          'little': 5672,
#          'less': 5672,
#          'wanted': 5664,
#          '8': 5662,
#          'census': 5644,
#          'olympics': 5638,
#          'art': 5631,
#          'included': 5622,
#          '7': 5618,
#          '2022': 5618,
#          'comes': 5614,
#          'change': 5605,
#          'light': 5590,
#          'see': 5578,
#          'within': 5556,
#          'academy': 5556,
#          'includes': 5553,
#          'service': 5553,
#          'should': 5548,
#          '100': 5513,
#          '(;': 5504,
#          'civil': 5497,
#          'control': 5470,
#          'having': 5469,
#          '11': 5468,
#          'robert': 5446,
#          'shows': 5440,
#          'final': 5433,
#          'current': 5407,
#          'awards': 5386,
#          'period': 5365,
#          'russian': 5361,
#          'must': 5360,
#          'studied': 5360,
#          'community': 5359,
#          'ancient': 5347,
#          'taken': 5343,
#          'almost': 5340,
#          'books': 5329,
#          'event': 5322,
#          'official': 5314,
#          'mother': 5308,
#          'europe': 5303,
#          'rights': 5303,
#          'los': 5265,
#          'attack': 5258,
#          'come': 5255,
#          '18': 5255,
#          'canada': 5254,
#          'middle': 5252,
#          'police': 5249,
#          'groups': 5245,
#          'female': 5241,
#          'considered': 5236,
#          '13': 5228,
#          'canadian': 5228,
#          'china': 5226,
#          '2005': 5215,
#          'match': 5215,
#          '30': 5196,
#          '14': 5188,
#          'places': 5178,
#          'level': 5170,
#          '(the': 5167,
#          'david': 5156,
#          '1,': 5153,
#          'though': 5152,
#          'drama': 5145,
#          'better': 5127,
#          'council': 5127,
#          'division': 5110,
#          'run': 5106,
#          '2001': 5102,
#          'democratic': 5100,
#          'says': 5097,
#          '16': 5096,
#          'areas': 5095,
#          '2004': 5087,
#          'switzerland': 5087,
#          'sold': 5061,
#          'hockey': 5055,
#          'heart': 5044,
#          'texas': 5031,
#          'grand': 5023,
#          'developed': 5019,
#          'players': 5008,
#          'once': 5000,
#          'able': 4967,
#          'point': 4959,
#          '25': 4948,
#          'empire': 4946,
#          '2000': 4946,
#          'never': 4945,
#          'spanish': 4933,
#          'working': 4930,
#          'force': 4910,
#          'tropical': 4888,
#          'charles': 4880,
#          'too': 4854,
#          '9': 4838,
#          'done': 4816,
#          'michael': 4803,
#          'free': 4802,
#          '17': 4788,
#          'chinese': 4786,
#          'association': 4764,
#          'animals': 4761,
#          'above': 4756,
#          'natural': 4732,
#          'parliament': 4724,
#          'uses': 4719,
#          'seven': 4714,
#          'cities': 4698,
#          'retired': 4695,
#          'sent': 4683,
#          'radio': 4675,
#          'race': 4666,
#          'instead': 4653,
#          'various': 4631,
#          'find': 4624,
#          'currently': 4617,
#          'support': 4614,
#          'teams': 4614,
#          'science': 4604,
#          'cancer': 4601,
#          'problems': 4575,
#          'mainly': 4555,
#          'islands': 4546,
#          'research': 4534,
#          'medal': 4528,
#          'greek': 4487,
#          '2020)': 4484,
#          'give': 4477,
#          '2003': 4465,
#          'movement': 4461,
#          'example': 4460,
#          'competed': 4460,
#          'star': 4459,
#          'gold': 4454,
#          'spain': 4452,
#          '24': 4448,
#          'languages': 4444,
#          'census,': 4431,
#          'federal': 4426,
#          'say': 4420,
#          'lead': 4417,
#          'across': 4416,
#          'ended': 4410,
#          'energy': 4410,
#          'space': 4383,
#          'records': 4383,
#          'study': 4376,
#          'love': 4371,
#          'woman': 4367,
#          'ice': 4364,
#          '2019,': 4362,
#          'start': 4360,
#          'helped': 4360,
#          'god': 4348,
#          'hit': 4345,
#          '2002': 4337,
#          'opened': 4325,
#          'tv': 4322,
#          'computer': 4317,
#          'comedy': 4316,
#          'wife': 4311,
#          'act': 4303,
#          'forces': 4303,
#          'types': 4287,
#          'highest': 4281,
#          'reached': 4277,
#          'average': 4271,
#          'native': 4270,
#          'coast': 4264,
#          'lower': 4262,
#          'paul': 4260,
#          'recorded': 4251,
#          'green': 4240,
#          'writer': 4237,
#          'states,': 4233,
#          '(or': 4222,
#          'storm': 4221,
#          'win': 4209,
#          'health': 4207,
#          'richard': 4201,
#          'open': 4193,
#          'scientists': 4191,
#          'fourth': 4187,
#          'think': 4186,
#          'earth': 4184,
#          'least': 4177,
#          'dutch': 4175,
#          'either': 4170,
#          'move': 4169,
#          'fire': 4165,
#          'originally': 4164,
#          '2,': 4164,
#          'canton': 4163,
#          '19': 4155,
#          'meaning': 4154,
#          'development': 4151,
#          'roles': 4150,
#          'program': 4147,
#          'road': 4136,
#          'africa': 4134,
#          'hall': 4131,
#          'decided': 4129,
#          'might': 4129,
#          'cause': 4124,
#          'later,': 4118,
#          'hot': 4117,
#          'tree': 4117,
#          'child': 4116,
#          '21': 4110,
#          'field': 4101,
#          'returned': 4093,
#          'performed': 4091,
#          'close': 4086,
#          'class': 4081,
#          'sports': 4079,
#          '22': 4052,
#          'words': 4038,
#          'network': 4034,
#          'today': 4025,
#          'strong': 4023,
#          'stage': 4021,
#          'replaced': 4015,
#          '1999': 4013,
#          'information': 4013,
#          'plants': 4010,
#          'always': 4005,
#          'daughter': 4000,
#          'museum': 4000,
#          'prize': 3999,
#          'chief': 3997,
#          'episode': 3995,
#          'certain': 3990,
#          'students': 3988,
#          'signed': 3986,
#          'peter': 3985,
#          'real': 3985,
#          'established': 3983,
#          'hurricane': 3982,
#          'car': 3974,
#          'christian': 3966,
#          'illinois': 3965,
#          'debut': 3964,
#          'idea': 3946,
#          'especially': 3941,
#          'mountain': 3937,
#          'writing': 3930,
#          'city,': 3920,
#          '23': 3913,
#          'business': 3910,
#          'african': 3906,
#          'shown': 3903,
#          'inside': 3899,
#          '3,': 3894,
#          '1996': 3888,
#          'henry': 3886,
#          'ten': 3876,
#          'himself': 3872,
#          'railway': 3864,
#          'names': 3861,
#          'channel': 3861,
#          'professor': 3858,
#          'thomas': 3852,
#          'pakistan': 3850,
#          'hospital': 3844,
#          '4,': 3843,
#          'catholic': 3840,
#          'disease': 3829,
#          'need': 3825,
#          'half': 3824,
#          'fc': 3814,
#          'nominated': 3813,
#          'outside': 3809,
#          'per': 3803,
#          'sweden': 3799,
#          'florida': 3799,
#          'going': 3796,
#          'position': 3795,
#          'chicago': 3787,
#          'stop': 3786,
#          'bad': 3784,
#          'goes': 3780,
#          'airport': 3779,
#          'sound': 3775,
#          '26': 3767,
#          'allowed': 3760,
#          'society': 3752,
#          'takes': 3739,
#          'paris': 3739,
#          'medical': 3720,
#          'republican': 3718,
#          '1998': 3715,
#          'color': 3701,
#          'successful': 3696,
#          '1992': 3696,
#          'night': 3694,
#          'months': 3693,
#          'mexico': 3679,
#          'independent': 3670,
#          'queen': 3655,
#          'look': 3643,
#          'characters': 3643,
#          'virginia': 3635,
#          'media': 3633,
#          'added': 3628,
#          'continued': 3615,
#          'russia': 3613,
#          'site': 3612,
#          'uk': 3607,
#          'divided': 3603,
#          'male': 3597,
#          'education': 3581,
#          'eight': 3568,
#          'related': 3564,
#          'want': 3564,
#          '1995': 3563,
#          '15,': 3563,
#          'believed': 3557,
#          'prince': 3554,
#          'changes': 3551,
#          '2016,': 3548,
#          'enough': 3547,
#          'blue': 3546,
#          'musical': 3538,
#          '2010,': 3534,
#          'ever': 3533,
#          'brother': 3533,
#          'winter': 3529,
#          'centre': 3522,
#          'secretary': 3516,
#          'finished': 3515,
#          'years,': 3514,
#          'latin': 3514,
#          'hard': 3513,
#          'soon': 3512,
#          'zealand': 3512,
#          '1994': 3500,
#          '2021,': 3493,
#          'events': 3491,
#          'owned': 3489,
#          '(also': 3484,
#          '28': 3480,
#          '7,': 3477,
#          'far': 3476,
#          '12,': 3475,
#          'cannot': 3474,
#          'full': 3473,
#          ')': 3473,
#          'kind': 3469,
#          '27': 3467,
#          'brown': 3466,
#          'know': 3464,
#          '10,': 3462,
#          'told': 3452,
#          'metal': 3443,
#          '5,': 3442,
#          'here': 3437,
#          'blood': 3436,
#          'something': 3432,
#          'production': 3431,
#          'front': 3431,
#          '6,': 3424,
#          'chemical': 3422,
#          '20th': 3422,
#          '11,': 3420,
#          '16,': 3406,
#          '1997': 3402,
#          'model': 3398,
#          'style': 3397,
#          'awarded': 3394,
#          'smaller': 3393,
#          'parents': 3392,
#          'senate': 3390,
#          'tried': 3382,
#          'voice': 3381,
#          'kansas': 3379,
#          'coach': 3377,
#          'longer': 3376,
#          'washington': 3375,
#          'possible': 3370,
#          '2018,': 3368,
#          '20,': 3363,
#          'range': 3361,
#          'plant': 3358,
#          'services': 3358,
#          '1993': 3355,
#          'case': 3351,
#          'designed': 3350,
#          'street': 3348,
#          '18,': 3348,
#          '""': 3348,
#          'presidential': 3339,
#          '8,': 3339,
#          'austrian': 3331,
#          'van': 3330,
#          '2017,': 3329,
#          'artist': 3328,
#          'keep': 3318,
#          'described': 3317,
#          'people,': 3312,
#          'oldest': 3310,
#          'valley': 3307,
#          '9,': 3306,
#          '13,': 3305,
#          'mayor': 3304,
#          'throughout': 3303,
#          'fight': 3294,
#          '(,': 3291,
#          'distributed': 3278,
#          'my': 3275,
#          'novel': 3271,
#          'festival': 3269,
#          'climate': 3267,
#          'ireland': 3267,
#          'northwest': 3239,
#          '17,': 3229,
#          '14,': 3225,
#          'discovered': 3209,
#          'border': 3206,
#          'happened': 3200,
#          'square': 3199,
#          'action': 3198,
#          'release': 3192,
#          'territory': 3190,
#          '29': 3190,
#          'low': 3188,
#          'traditional': 3188,
#          'ground': 3187,
#          'brought': 3186,
#          'fish': 3184,
#          'saw': 3182,
#          'data': 3176,
#          'news': 3173,
#          'commonly': 3173,
#          'numbers': 3169,
#          'ran': 3168,
#          'bank': 3168,
#          'assembly': 3166,
#          'culture': 3150,
#          '1991': 3147,
#          'round': 3141,
#          'gets': 3140,
#          'wrestling': 3139,
#          'stadium': 3133,
#          'amount': 3132,
#          'features': 3132,
#          '"a': 3125,
#          'believe': 3125,
#          'lee': 3120,
#          'leading': 3115,
#          'starring': 3112,
#          'soldiers': 3111,
#          '21,': 3109,
#          'beginning': 3107,
#          'upper': 3105,
#          'starting': 3102,
#          '1990': 3101,
#          'louis': 3099,
#          'grew': 3097,
#          '19,': 3092,
#          'congress': 3091,
#          'larger': 3089,
#          'process': 3080,
#          'mountains': 3079,
#          'this,': 3078,
#          'opera': 3077,
#          'organization': 3073,
#          'design': 3061,
#          '22,': 3056,
#          'create': 3055,
#          'matches': 3054,
#          'religious': 3052,
#          '23,': 3052,
#          '25,': 3051,
#          'pictures': 3049,
#          '27,': 3048,
#          '2007,': 3047,
#          'your': 3044,
#          '26,': 3043,
#          'higher': 3039,
#          'are:': 3027,
#          'foreign': 3025,
#          'ocean': 3023,
#          '24,': 3021,
#          'available': 3020,
#          'olympic': 3017,
#          'board': 3015,
#          'bridge': 3013,
#          '2022,': 3002,
#          'size': 2998,
#          'emperor': 2995,
#          'refer': 2993,
#          'edward': 2992,
#          'nations': 2988,
#          'followed': 2985,
#          'producer': 2983,
#          '28,': 2983,
#          ...})

# %%
unigram_counts = {k: v for k,v in c.items() if v>1} # also freq filter: each word should appear at least twice

# %%
# A set of words with unigram counts
vocab = set([k for k,v in c.items() if v>1])

# %%
bigram_counts = {v: defaultdict(int) for v in vocab} #takes few seconds

# %%
# Takes some time (a minute maybe)
for i in tqdm.tqdm(range(len(corpus)-1)):
    x1, x2 = corpus[i], corpus[i+1]
    # Check if x1 and x2 are in vocab and if they are increase bigram_couts[x1][x2] by 1
    # Your Code here
    if x1 in vocab and x2 in vocab:
        bigram_counts[x1][x2] += 1
# Out:
# 100%|██████████| 31756751/31756751 [00:27<00:00, 1170539.78it/s]

# %%
bigram_counts
# Out:
# {'': defaultdict(int,
#              {'<eos>': 74687,
#               'for': 22,
#               'around': 3,
#               '': 924,
#               'earth': 2,
#               'it': 813,
#               'we': 14,
#               'the': 1524,
#               '→': 1,
#               'people': 12,
#               '"': 9,
#               'increases': 1,
#               'this': 245,
#               '-': 13,
#               'mediawiki': 1,
#               'both': 13,
#               'mercury': 1,
#               'mariner': 1,
#               'several': 6,
#               'however,': 29,
#               'summers': 1,
#               'new': 5,
#               'honolulu,': 1,
#               'platonic': 1,
#               'because': 17,
#               'its': 164,
#               'seven': 2,
#               'in': 309,
#               'scientists': 4,
#               'they': 158,
#               '3': 5,
#               '0': 4,
#               'at': 66,
#               'herodotus': 1,
#               '/': 1,
#               'that': 26,
#               'he': 383,
#               'using': 3,
#               'more': 8,
#               'german': 1,
#               'vladimir': 1,
#               "moscow's": 2,
#               'moscow': 1,
#               'los': 2,
#               'tags': 1,
#               'during': 15,
#               'everton': 1,
#               'previous': 1,
#               '•': 1,
#               'lumps': 1,
#               'with': 29,
#               'mount': 2,
#               'an': 13,
#               'here': 5,
#               'cnn': 1,
#               'alberta': 1,
#               'most': 25,
#               'a': 52,
#               'electric': 1,
#               'today': 3,
#               'and': 28,
#               'former': 2,
#               'low': 1,
#               'medium-level': 1,
#               'vertical': 1,
#               'george': 3,
#               'tom,': 1,
#               'been': 2,
#               'her': 20,
#               'ph': 1,
#               'on': 43,
#               'january': 2,
#               'these': 38,
#               'eyes,': 1,
#               'she': 131,
#               'some': 26,
#               'since': 15,
#               'august': 1,
#               'is': 38,
#               'today,': 5,
#               'large': 2,
#               'females': 15,
#               'mature': 1,
#               'oxygen': 1,
#               'there': 131,
#               'sources': 1,
#               'means': 2,
#               'liberation': 1,
#               'louisiana': 2,
#               'cartier': 1,
#               'season': 58,
#               'of': 265,
#               'other': 16,
#               'gorbachev': 1,
#               'casting': 1,
#               'trying': 1,
#               'reformation': 1,
#               "jehovah's": 1,
#               'their': 31,
#               'belarus': 1,
#               '(which': 1,
#               'his': 33,
#               'sealand': 1,
#               "alabama's": 1,
#               'temperatures': 2,
#               'bremen': 1,
#               'about': 18,
#               "it's": 10,
#               'spring': 1,
#               'nesmith': 1,
#               'as': 63,
#               'others': 7,
#               'mineralogists': 1,
#               'mandate': 1,
#               '()': 4,
#               'thousands': 1,
#               "croatia's": 1,
#               "chad's": 1,
#               'freezers': 1,
#               'arctic': 1,
#               'humidity': 1,
#               'high': 1,
#               'saying': 2,
#               '"later': 1,
#               'to': 31,
#               'was': 23,
#               'iowa': 1,
#               'congress': 1,
#               'nations"': 1,
#               'rifles': 1,
#               'another': 3,
#               'older': 1,
#               'before': 13,
#               'theophrastus': 1,
#               'libya': 1,
#               'oklahoma': 1,
#               'winters': 4,
#               'until': 4,
#               'reason': 1,
#               '[and]': 3,
#               "franklin's": 1,
#               'newcastle': 1,
#               'summer': 2,
#               'foreign': 1,
#               'stood': 1,
#               'mongolia': 1,
#               'land': 1,
#               'tropical': 3,
#               '9': 1,
#               '6': 1,
#               'much': 2,
#               'measurable': 1,
#               'wichita': 1,
#               '(chorus)': 1,
#               'de': 2,
#               'burkina': 1,
#               'five': 2,
#               'longboard': 1,
#               '15': 1,
#               'emperor': 1,
#               'every': 6,
#               'snowfall': 1,
#               'averages': 1,
#               'wolverines': 1,
#               'after': 54,
#               '=': 1,
#               'print': 1,
#               'f1': 1,
#               'guillotin': 1,
#               'svalbard': 1,
#               'suppose': 1,
#               'eleven': 2,
#               'like': 9,
#               'each': 8,
#               'if': 21,
#               '[due': 1,
#               'highlights': 1,
#               'possibly': 1,
#               '(for': 1,
#               'two': 6,
#               'khartoum': 1,
#               'karma': 1,
#               'but': 18,
#               'scotty': 1,
#               'general': 4,
#               'get': 7,
#               'selene': 1,
#               'joe': 2,
#               'four': 2,
#               'toyota': 1,
#               'together,': 1,
#               'helena': 1,
#               'constantine': 2,
#               '(': 1,
#               'sometimes,': 3,
#               'snow': 1,
#               'railways': 1,
#               'lava': 1,
#               'pajamas': 1,
#               'did': 10,
#               'formula_7,': 1,
#               'next': 3,
#               'helplessness': 1,
#               '[that': 2,
#               'somewhere': 1,
#               'sexual': 1,
#               'first': 3,
#               'rachmaninoff': 1,
#               '"(let\'s': 1,
#               'males': 7,
#               'flowing': 2,
#               'now,': 1,
#               'thor': 1,
#               'referees': 1,
#               'dr': 2,
#               'one': 13,
#               'making': 1,
#               'borzois': 1,
#               'has': 4,
#               'taken': 1,
#               'whispered': 1,
#               "loki's": 1,
#               'many': 17,
#               'by': 9,
#               'then)': 1,
#               'instead': 1,
#               "there's": 2,
#               'apres': 1,
#               'so': 9,
#               'lenses': 1,
#               'annie': 1,
#               'excluded': 1,
#               'fossils': 1,
#               '"-"': 1,
#               'host': 1,
#               'everywhere': 1,
#               '[find': 2,
#               'who': 7,
#               'feces': 1,
#               'yet': 1,
#               'mal': 1,
#               'accounts': 1,
#               'nero': 1,
#               'sevan': 1,
#               'usually': 2,
#               'also': 7,
#               'officials': 1,
#               'capital': 1,
#               'there,': 3,
#               'no': 6,
#               'when': 37,
#               'well': 1,
#               'schubert': 1,
#               'historically,': 1,
#               'not': 4,
#               'concussions': 1,
#               "n'djamena": 1,
#               'according': 20,
#               'gazi': 1,
#               'čair': 1,
#               'butel': 1,
#               'gjorče': 1,
#               'college': 1,
#               'towns': 1,
#               'female': 2,
#               'music': 1,
#               'mozart': 1,
#               'thus': 2,
#               '"9"': 1,
#               'old': 2,
#               'instead,': 1,
#               'however': 4,
#               "moon's": 1,
#               'diocletian': 1,
#               'ü': 1,
#               'nautilus': 1,
#               'neither': 1,
#               'hirohito': 1,
#               'melkonian': 1,
#               'killed': 1,
#               'approximately': 1,
#               'have': 3,
#               'even': 6,
#               'team': 4,
#               'gerry': 1,
#               'cdf': 1,
#               'together': 4,
#               'volume': 1,
#               'i': 22,
#               'caprivi': 1,
#               'multiple': 1,
#               'lack': 1,
#               'population': 1,
#               'city': 2,
#               'use': 3,
#               '"2': 1,
#               'currently,': 1,
#               'zu': 1,
#               'almost': 5,
#               '2,000,000': 1,
#               'hurling': 1,
#               'lee': 1,
#               'although': 13,
#               'checkpoint': 1,
#               'between': 5,
#               'won': 5,
#               'aalborg': 1,
#               'driver': 4,
#               'which': 1,
#               'while': 9,
#               'fiction': 1,
#               'oceans,': 1,
#               '*': 7,
#               '"yellow': 2,
#               'meldorf': 1,
#               'public': 2,
#               'seyß-inquart': 1,
#               '92%': 1,
#               'eventually,': 1,
#               'gary': 1,
#               'getting': 1,
#               'three': 2,
#               'any': 3,
#               'port-au-prince,': 1,
#               'overall': 1,
#               'non-building': 1,
#               'hundreds': 1,
#               'having': 2,
#               'clio': 1,
#               'played': 1,
#               'clara': 1,
#               'from': 46,
#               'average': 2,
#               'karakalpakstan': 1,
#               'mayhew': 1,
#               '"also': 1,
#               'mazur': 1,
#               'villiers': 1,
#               'out': 2,
#               'american': 2,
#               'now': 2,
#               'only': 4,
#               'japanese': 1,
#               'workers': 1,
#               'bede': 1,
#               'bullfrogs': 1,
#               'male': 3,
#               '[his]': 1,
#               'charles': 1,
#               'carteret': 1,
#               '(1)': 2,
#               '1985,': 1,
#               'despite': 8,
#               'woven': 1,
#               'kochi': 1,
#               'palembang': 1,
#               'hamilton': 1,
#               'manora': 1,
#               'clemens': 1,
#               'hurtova': 1,
#               'mexican': 1,
#               'doak': 1,
#               'italian': 1,
#               'muttalib': 1,
#               '"girl,': 1,
#               'siachen': 1,
#               'work': 2,
#               'pir': 1,
#               'cd': 3,
#               'very': 3,
#               'karimabad': 1,
#               'picasa': 1,
#               'bazaar': 1,
#               'over': 3,
#               'wounded': 1,
#               'shelf': 1,
#               'various': 1,
#               '2006:': 1,
#               'pakistan': 1,
#               '(right-handed)': 1,
#               'above': 2,
#               'early': 2,
#               'orthodox': 1,
#               '(4)': 1,
#               '(5)': 4,
#               '(14)': 1,
#               '(3)': 3,
#               '(17)': 1,
#               '(20)': 1,
#               '(12)': 1,
#               'already': 1,
#               '(9)': 4,
#               '(15)': 1,
#               '(7)': 2,
#               'reads': 1,
#               '(8)': 1,
#               '(11)': 1,
#               'october': 1,
#               'july': 2,
#               'all': 209,
#               'ikev2': 1,
#               'prairie': 1,
#               'phetchabun': 1,
#               'updates': 1,
#               'therefore,': 1,
#               'heaton': 1,
#               'may': 2,
#               '--': 3,
#               'rips': 1,
#               'reproduction': 1,
#               '|': 2,
#               '(or': 23,
#               'jens': 1,
#               'drivers': 2,
#               "paterson's": 1,
#               'channels': 1,
#               'twenty-seven': 1,
#               'famous': 1,
#               'weatherford': 1,
#               '422': 1,
#               "germany's": 1,
#               'nicolae': 1,
#               'producers': 1,
#               '"disney\'s': 1,
#               'probably': 1,
#               'vendetta': 1,
#               'ss-obergruppenfuhrer': 1,
#               'hans': 2,
#               'aesthetic': 1,
#               'rifled': 1,
#               'ernst': 1,
#               'eg': 1,
#               'active': 1,
#               'boldface': 1,
#               'localization': 1,
#               'lilo': 1,
#               'pico': 3,
#               '"positif"': 1,
#               'knight:': 1,
#               'mexico': 1,
#               '(2)': 3,
#               'japan': 2,
#               'undefeated': 1,
#               'besides': 1,
#               'ibn': 1,
#               'without': 1,
#               '"e': 1,
#               'hansard': 1,
#               'leaves': 1,
#               'east': 1,
#               'tpl': 1,
#               'singers': 1,
#               "constructors'": 2,
#               '–': 3,
#               'just': 2,
#               'plan': 1,
#               'juan': 1,
#               'kim': 2,
#               'lukáš': 2,
#               'serena': 1,
#               'carly': 1,
#               'bernard': 1,
#               'heather': 1,
#               'marton': 1,
#               'valeria': 1,
#               'shingo': 2,
#               'esther': 3,
#               'stephane': 1,
#               'korie': 1,
#               'peter': 1,
#               'nick': 2,
#               'preko': 1,
#               '(players': 1,
#               'bonney': 1,
#               'within': 1,
#               'fennec': 1,
#               'khufu': 1,
#               'lask': 1,
#               'spent': 1,
#               'modern': 3,
#               'internationally,': 1,
#               'shows': 1,
#               'gluck’s': 1,
#               'alaska,': 1,
#               'hawaii,': 1,
#               'measured': 1,
#               'bruce': 2,
#               'sally': 1,
#               'immediately': 1,
#               'includes': 2,
#               'built': 1,
#               'wikimedia': 2,
#               'sundew': 1,
#               'mohammad': 1,
#               'can': 2,
#               'half': 1,
#               '90%': 1,
#               'are': 5,
#               'someone': 1,
#               'consonants': 1,
#               'good;': 1,
#               'plot"': 1,
#               'melodrama,': 1,
#               "white's": 1,
#               'epicurus': 1,
#               'usually,': 1,
#               'inadequate': 1,
#               '[laughs]': 1,
#               'haber': 1,
#               'usgs': 1,
#               'tyson': 1,
#               'hope': 1,
#               'rainfall': 2,
#               '||': 1,
#               'tsunayoshi': 1,
#               '(last': 40,
#               'pluto': 1,
#               'dadyal': 1,
#               '945': 1,
#               'ssv': 1,
#               'karim': 1,
#               'soviet': 1,
#               'gagarin': 1,
#               'iihf': 1,
#               'meanwhile,': 2,
#               'israel': 2,
#               'desert': 1,
#               'cena': 1,
#               'boston': 1,
#               'extremes': 1,
#               'once': 5,
#               'powered': 1,
#               'irene': 1,
#               'vernon': 1,
#               'following': 3,
#               'haugesund,': 2,
#               'mercedes-benz,': 1,
#               'under': 3,
#               'heidfeld': 1,
#               'sonic': 1,
#               'tabitha': 1,
#               'zuko': 1,
#               'protagonists': 1,
#               'otherwise': 1,
#               'valencia': 1,
#               'shōnan-shinjuku': 1,
#               'antigua': 1,
#               'rainfalls': 1,
#               'part': 5,
#               'scored': 1,
#               'then': 20,
#               'engines': 1,
#               'cosworth': 1,
#               'winds': 1,
#               'le': 1,
#               '"the': 2,
#               'cobalt(ii)': 1,
#               'luigi': 1,
#               'also,': 2,
#               'argentine': 1,
#               'shared': 1,
#               'abstract': 2,
#               'go-karts': 1,
#               'tony': 1,
#               'supposing': 1,
#               'competed': 1,
#               'placing': 1,
#               'winner': 1,
#               'health': 1,
#               'rafael': 1,
#               'bob': 1,
#               'vania': 1,
#               'liezel': 1,
#               'jack': 1,
#               'daria': 1,
#               'duilio': 1,
#               'tímea': 1,
#               'maikel': 1,
#               'david': 2,
#               'my': 3,
#               '”': 1,
#               "california's": 1,
#               'progress': 1,
#               '"mussaurus"': 1,
#               'men': 1,
#               'larger': 1,
#               'midseason': 1,
#               'z': 1,
#               'be': 2,
#               'certain': 2,
#               'would': 1,
#               'sometimes': 3,
#               'actuated': 1,
#               'robin': 1,
#               'petra': 1,
#               'alisa': 1,
#               'montgomery': 1,
#               'recent': 1,
#               'nanmadol': 1,
#               'soon': 3,
#               'strong': 1,
#               "joannie's": 1,
#               'growing': 1,
#               'rochette': 3,
#               'ivory': 1,
#               'next,': 3,
#               'counter-strike:': 1,
#               'oxpeckers': 1,
#               'hundertwasser': 1,
#               'colour': 1,
#               'karun': 1,
#               'alexander': 1,
#               'unwilling': 1,
#               'electronic': 1,
#               'logging': 1,
#               'six': 2,
#               'twelve': 1,
#               '(2001': 1,
#               'initially': 1,
#               'common': 1,
#               'marfa': 1,
#               'walburga': 1,
#               'hudson': 1,
#               'bomis': 1,
#               'bill': 2,
#               'considerable': 1,
#               'lizard': 1,
#               ',': 12,
#               'rahm': 1,
#               'had': 1,
#               '1995': 2,
#               "contestant's": 1,
#               "aurelian's": 1,
#               'closed': 1,
#               'winslow': 1,
#               'compares': 1,
#               'later': 7,
#               'weighing': 1,
#               'pups': 1,
#               'maturity': 1,
#               'bmw': 1,
#               'sauber,': 1,
#               'russian': 1,
#               'ichinoseki': 1,
#               'tamil': 1,
#               'afterwards,': 1,
#               'alveolar': 1,
#               'confident': 1,
#               'fernanda': 1,
#               'hasekura': 1,
#               'annual': 2,
#               'record': 1,
#               'or': 3,
#               'recommends': 1,
#               "stewart's": 1,
#               '(sc': 1,
#               'ocala': 1,
#               'so,': 1,
#               'amphibians': 1,
#               'beats': 1,
#               'remodelling': 1,
#               'fusa': 1,
#               'area': 1,
#               'airport': 4,
#               'atmospheric': 1,
#               'bundi': 1,
#               'deoli': 1,
#               'burns': 1,
#               'douglas': 1,
#               'films': 1,
#               'manet': 1,
#               'oppuurs': 1,
#               'grisi': 1,
#               '[the': 1,
#               'treats': 1,
#               "go-kōgon's": 2,
#               'but,': 1,
#               'engineers': 1,
#               'curious,': 1,
#               'returns;': 1,
#               'arching': 1,
#               'glen': 1,
#               'spasmodic': 1,
#               'should': 1,
#               'shophouses': 1,
#               '""': 1,
#               "kōgon's": 3,
#               "go-komatsu's": 2,
#               'ships': 1,
#               'near': 3,
#               'pound': 1,
#               ':': 2,
#               'listed': 1,
#               'hare': 1,
#               'south': 1,
#               'changes': 1,
#               'ic': 1,
#               'close': 1,
#               "anita's": 1,
#               'norman': 1,
#               '("': 1,
#               'yoshitsune': 1,
#               'bear': 1,
#               'amar': 1,
#               'india': 27,
#               'cox': 1,
#               'päijänne': 1,
#               'kallavesi': 1,
#               'nb': 1,
#               'alternatively,': 1,
#               'depressed,': 1,
#               'cao': 1,
#               'karimganj': 1,
#               'elizabeth\xa0': 1,
#               'suddenly': 1,
#               'seems': 1,
#               'act': 1,
#               'dipstick': 1,
#               'st': 1,
#               'berlioz': 1,
#               '[and': 1,
#               'historical': 1,
#               '"and': 1,
#               'sign': 1,
#               'tjuntjuntjara': 1,
#               'lead': 1,
#               'amanda': 1,
#               'calahorra': 1,
#               'william': 1,
#               'television': 1,
#               'premios': 1,
#               'estimated': 1,
#               'skiers': 1,
#               'top': 1,
#               'well,': 1,
#               'neighbouring': 2,
#               'severe': 1,
#               'based': 2,
#               'barnum': 1,
#               'will': 2,
#               'how': 2,
#               'along': 2,
#               'hgnc': 1,
#               'halti': 1,
#               'repairing': 1,
#               'permission': 1,
#               'pollux': 1,
#               'geoffrey': 1,
#               '[stephen]': 1,
#               'hibernians': 1,
#               'birkirkara': 2,
#               'wright': 1,
#               'baldwin': 1,
#               'your': 1,
#               'clone': 1,
#               '\xa0': 3,
#               'rain': 1,
#               'mika': 1,
#               'ealdormen': 1,
#               'sixteen': 1,
#               'cage': 1,
#               'cenwalh,': 1,
#               'touring': 2,
#               'were': 2,
#               'octene': 1,
#               'cold': 1,
#               'total:': 1,
#               'members': 1,
#               'burgess': 1,
#               'nothing': 2,
#               '(short': 1,
#               'tenants': 1,
#               'marcia': 1,
#               '"lexington"': 1,
#               'j': 1,
#               'works': 1,
#               'matilda': 1,
#               'medieval': 1,
#               'alassane': 1,
#               '",': 1,
#               "we're": 1,
#               'x-ray': 1,
#               'oswald': 1,
#               'inside': 1,
#               'poi': 1,
#               'bergström': 1,
#               '(1877)': 1,
#               'unfortunately,': 2,
#               'scalise': 1,
#               "'high": 1,
#               'agent': 1,
#               't': 1,
#               'retrieved': 6,
#               'pulbah': 1,
#               'federation"': 1,
#               'orange': 1,
#               'demotic': 1,
#               "'well,": 1,
#               'extended': 1,
#               'do': 3,
#               'katy': 2,
#               'cartoons': 1,
#               'such': 3,
#               'limited': 1,
#               '"matica': 1,
#               'yamato': 1,
#               'sei': 1,
#               'depending': 1,
#               'bellvale': 1,
#               'stretching': 1,
#               'cen': 1,
#               'walter': 1,
#               "canada's": 1,
#               'jdam-equipped': 1,
#               'riders': 1,
#               'maha': 1,
#               'forgiveness': 1,
#               'broccoli': 1,
#               '2000': 1,
#               'air': 1,
#               'ironically': 1,
#               'unlike': 4,
#               'populists': 1,
#               'kratos': 1,
#               'strangely': 1,
#               'irises': 1,
#               'borussia': 1,
#               'bełżec': 1,
#               'words': 1,
#               'dangi': 1,
#               'wrangel': 1,
#               'into': 1,
#               'farnes': 1,
#               'denotes': 1,
#               'throughout': 3,
#               'announced': 1,
#               "'": 1,
#               'back': 1,
#               'drums': 1,
#               'fifteen': 1,
#               'statutes': 1,
#               'champions\xa0\xa0': 5,
#               '"new': 1,
#               'technology': 1,
#               'skyrim': 1,
#               'major': 2,
#               'immature': 1,
#               '[but': 1,
#               'desktop': 1,
#               'tied': 1,
#               'rights': 1,
#               '[we]': 1,
#               '<br>': 2,
#               'eighth': 1,
#               'literature"': 1,
#               'pre-war': 1,
#               'byun': 1,
#               'yugoslav': 2,
#               'playing': 1,
#               '1993': 2,
#               '"vigilant",': 1,
#               'williams': 1,
#               'you': 3,
#               'natalya': 1,
#               'vegetables': 1,
#               'total': 1,
#               'lake': 1,
#               'full': 1,
#               'kneževo': 1,
#               'void': 1,
#               'lodève': 1,
#               'still': 1,
#               'gasoline"': 1,
#               'analysis': 1,
#               'fish': 1,
#               'history': 1,
#               'khas': 1,
#               'rock': 1,
#               'turnout': 4,
#               'jarek': 1,
#               'hyderabad': 1,
#               'lavery': 1,
#               '[he]': 1,
#               'sanders': 1,
#               'levin,': 1,
#               'designed': 1,
#               '"my': 1,
#               'player': 4,
#               'paradiso': 1,
#               'nandini,': 1,
#               'aya': 1,
#               'majursahi': 1,
#               'phoksundo': 1,
#               'jenkins': 1,
#               '135': 1,
#               'census': 1,
#               'ksrtc': 1,
#               'irrespective': 1,
#               'put': 1,
#               '2014': 1,
#               'space': 1,
#               'classmates': 1,
#               'attracted': 1,
#               'manoj': 1,
#               'composed': 1,
#               'mull': 1,
#               '(19)': 1,
#               'nasa': 1,
#               'kids': 1,
#               'though': 1,
#               'across': 1,
#               'storm': 1,
#               'damage': 1,
#               'parks': 1,
#               'mcmillan': 1,
#               'underwood': 1,
#               'cantwell': 1,
#               'good': 1,
#               'tempted': 1,
#               '(a': 1,
#               'nikolai': 1,
#               'keetmanshoop': 1,
#               'susanna': 1,
#               'chicago': 1,
#               'ishi': 1,
#               'opening': 1,
#               'schonberg': 1,
#               'bird"': 1,
#               'economic': 1,
#               'nova': 1,
#               'sheppard': 1,
#               'indicates': 2,
#               'pagasa': 1,
#               'nominations': 1,
#               '"as': 1,
#               'back-flip': 1,
#               'formal': 1,
#               'johnson': 1,
#               'green': 1,
#               'recently': 1,
#               "acastus's": 1,
#               'norton': 1,
#               'roarke': 1,
#               'vaillant': 1,
#               'lekima': 1,
#               "lekima's": 1,
#               'institutional': 1,
#               'jiří': 1,
#               'arceo': 1,
#               'shifted': 1,
#               'jethmalani': 1,
#               'partaking': 1,
#               'armonk': 1,
#               'west': 1,
#               'tornado': 1,
#               'thanks': 1,
#               '(continue': 1,
#               'ifugao': 1,
#               'howard': 1,
#               'semjonova': 1,
#               'buru': 1,
#               'inge': 1,
#               'catherine': 1,
#               'rashford': 1,
#               'bieber': 1,
#               'marand': 1,
#               'm’baku': 1,
#               'magar,': 1,
#               '(04%)': 1,
#               'names': 10,
#               'siberia': 1,
#               'far': 1,
#               'sverdlovsk': 1,
#               'idel-ural': 1,
#               'nenetsia': 1,
#               'kuban': 1,
#               'lenard': 1,
#               'september': 2,
#               'mud': 1,
#               'richeze': 1,
#               'fernando': 1,
#               'ekland': 1,
#               'arnous': 1,
#               '870%': 1,
#               '953%': 1,
#               '951%': 1,
#               '762%': 1,
#               '915%': 1,
#               '881%': 1,
#               '988%': 1,
#               '794%': 1,
#               '902%': 1,
#               '928%': 1,
#               'puttur': 1,
#               '"she"': 1,
#               'marlenee': 1,
#               'australian': 2,
#               '(6)': 2,
#               "won't": 1,
#               'norway': 1,
#               ...}),
#  'jukes': defaultdict(int, {'<eos>': 1, 'in': 2, 'after': 1, 'wrote': 2}),
#  'wpo-3': defaultdict(int, {'was': 1, 'had': 1}),
#  '4000': defaultdict(int,
#              {'bc': 18,
#               'hertz': 1,
#               'years': 12,
#               'bce': 2,
#               'guests,': 1,
#               'americans': 1,
#               'and': 3,
#               'meters': 6,
#               'people': 9,
#               'people,': 1,
#               'years,': 1,
#               'inhabitants': 1,
#               '-': 1,
#               'to': 2,
#               'cubic': 2,
#               'haiku': 1,
#               'or': 1,
#               'c)': 1,
#               'episodes': 1,
#               'words': 2,
#               'persons': 1,
#               'in': 4,
#               'degrees': 1,
#               'cars': 1,
#               'species': 3,
#               'hp': 1,
#               'search': 1,
#               'grading': 1,
#               'techniques': 1,
#               'metres': 1,
#               'times': 1,
#               'immigrants': 1,
#               '(us$': 1,
#               'illustrations': 1,
#               'were': 2,
#               'series': 3,
#               "series'": 1,
#               'rounds': 1,
#               '<eos>': 6,
#               'is': 3,
#               'pesos': 1,
#               'oak': 1,
#               'km': 1,
#               'models,': 1,
#               'the': 1,
#               'ha': 1,
#               'international': 1,
#               'parvat': 2,
#               'works': 1,
#               'keyboard': 1,
#               'bce,': 1,
#               'types': 1,
#               '(,': 1,
#               'earth': 1,
#               'bands': 1,
#               'markhors': 1,
#               'arabs': 1,
#               'hectares': 1,
#               'hours': 1,
#               'teddy': 1,
#               'spectators': 1,
#               "'is": 1,
#               'would': 2,
#               'feet': 2,
#               'but': 1,
#               'police': 1,
#               'properties': 1}),
#  'olomouc),': defaultdict(int, {'and': 1, 'compared': 1}),
#  'lenape,': defaultdict(int, {'was': 1}),
#  'aldis': defaultdict(int,
#              {'(born': 1,
#               'hodge,': 2,
#               'hodge': 2,
#               'alexander': 1,
#               'wright': 1}),
#  '("elaeis': defaultdict(int, {'guineensis")': 2}),
#  'ciphertext,': defaultdict(int,
#              {'or': 1, 'he': 1, 'using': 1, 'so': 1, 'which': 1}),
#  'close-in': defaultdict(int, {'weapons,': 1, 'fighting': 1}),
#  'succeeds': defaultdict(int,
#              {'in': 17,
#               'all': 1,
#               'because': 1,
#               '': 1,
#               'him': 1,
#               'and': 2,
#               'to': 3,
#               'act': 1,
#               'at': 1,
#               'the': 3,
#               'windows': 1,
#               'weight': 1,
#               'on': 1,
#               'by': 1}),
#  'kathy,': defaultdict(int, {'cindy': 1, 'joni': 1, 'a': 1}),
#  'eddy,': defaultdict(int,
#              {'dinah': 1,
#               'members': 1,
#               'winning': 1,
#               'chet': 1,
#               'expecting': 1,
#               'however,': 1,
#               'george': 1,
#               'kaos': 1,
#               'who': 1,
#               'kevin': 1,
#               'flora': 1,
#               'lucille': 1,
#               'and': 1}),
#  '27th': defaultdict(int,
#              {'of': 15,
#               'largest,': 1,
#               'one': 1,
#               'president': 6,
#               'disney': 1,
#               'the': 3,
#               'december': 1,
#               'first': 1,
#               'january': 4,
#               'amendment,': 1,
#               'governor': 7,
#               'april': 1,
#               'amendment': 2,
#               'ova': 1,
#               'tropical': 1,
#               '1990,': 1,
#               '<eos>': 1,
#               'atlantic': 1,
#               'indiana': 2,
#               '1988': 1,
#               'biggest': 1,
#               '(out': 1,
#               'place': 1,
#               'july': 2,
#               'vice': 1,
#               '2024': 1,
#               'highest': 2,
#               'to': 3,
#               'premier': 6,
#               'winds': 1,
#               'largest': 3,
#               'june': 1,
#               'united': 3,
#               'ambassador': 1,
#               'king,': 1,
#               'when': 1,
#               '1996': 1,
#               'edition': 2,
#               'season': 7,
#               'prime': 7,
#               'century': 4,
#               '2021': 1,
#               'after': 1,
#               'single': 1,
#               'september,': 1,
#               'on': 2,
#               'in': 3,
#               'march': 1,
#               'ruler': 1,
#               'day': 1,
#               'till': 1,
#               'são': 1,
#               'overall': 3,
#               'marines,': 1,
#               'national': 1,
#               'maine': 1,
#               'district': 6,
#               'virginia': 1,
#               'africa': 1,
#               'guldbagge': 1,
#               'sultan': 1,
#               'congressional': 10,
#               'white': 2,
#               'golden': 1,
#               'district,': 2,
#               'us': 1,
#               'hereditary': 1,
#               'and': 4,
#               'state': 1,
#               'october': 2,
#               'that': 1,
#               'chairman': 1,
#               'lieutenant': 2,
#               'top': 1,
#               'russian': 1,
#               'secretary': 2,
#               'dance': 1,
#               'race': 1,
#               'governor-general': 1,
#               'oregon': 1,
#               'session': 1,
#               'artist': 1,
#               'speaker': 1,
#               'chess': 1,
#               'richest': 1,
#               'convoy': 1,
#               'birthday': 1,
#               'fire': 1,
#               'september': 1,
#               'movie': 1,
#               'administrator': 1,
#               'spokesperson': 1,
#               'episode': 1,
#               'berlin': 1,
#               '1960': 1,
#               'february': 1,
#               'guards': 1,
#               'separate': 1,
#               'consecutive': 1,
#               'presidential': 1,
#               'among': 1,
#               'year': 2,
#               'street,': 1,
#               'studio': 1,
#               'municipal': 1,
#               'best': 1,
#               'congress,': 1,
#               'attack': 1,
#               'may': 1}),
#  'edenhall': defaultdict(int, {'<eos>': 1, 'is': 1}),
#  'mide': defaultdict(int, {'westmeath': 1, 'the': 1, 'and': 1}),
#  'giwargis': defaultdict(int, {'<eos>': 1, '()': 1, 'died': 1}),
#  'doomhammer': defaultdict(int,
#              {'drek´thar': 1, 'told': 1, 'an': 1, 'died': 1}),
#  'maldon': defaultdict(int,
#              {'and': 1, '<eos>': 2, 'is': 1, 'district,': 25, '': 1, 'in': 1}),
#  'zayat': defaultdict(int, {'of': 1, 'stables,': 1}),
#  'latium': defaultdict(int,
#              {'and': 2,
#               'in': 1,
#               'remained': 1,
#               'it': 1,
#               'on': 1,
#               'with': 1,
#               '(or': 1,
#               '<eos>': 2,
#               'he': 1}),
#  'malden,': defaultdict(int,
#              {'flint,': 1,
#               'massachusetts': 4,
#               'missouri': 2,
#               'and': 1,
#               'ma,': 1,
#               'illinois': 1,
#               'helen': 1,
#               'robert': 1,
#               'rip': 1,
#               'brian': 1,
#               'adam': 1,
#               'raymond': 1}),
#  'graciete': defaultdict(int, {'santana': 1, 'moreira': 1}),
#  'ethno': defaultdict(int, {'band': 1, 'band,': 1}),
#  'lestek': defaultdict(int, {'<eos>': 1, '(': 1}),
#  'alta': defaultdict(int,
#              {'vista': 3,
#               'season,': 1,
#               'bandera': 1,
#               'california,': 2,
#               'taylor': 2,
#               'flights': 1,
#               'wind': 1,
#               'gracia,': 1,
#               'verapaz,': 1,
#               'vista,': 4,
#               'is': 5,
#               'variante': 1,
#               'was': 1,
#               'california': 6,
#               'verapaz': 8,
#               'valle': 5,
#               'provence,': 1,
#               'california"': 1,
#               's': 1,
#               'northern': 1,
#               'tierra': 1,
#               ',': 1,
#               'and': 2,
#               'from': 2,
#               '<eos>': 3,
#               'tree': 1,
#               'liva': 1,
#               'if': 1,
#               'the': 1,
#               '(town)': 1,
#               '(;': 1,
#               'municipality': 1,
#               'are': 1,
#               '(municipality)': 1,
#               'or': 1,
#               'can': 1}),
#  '"bottle': defaultdict(int, {'it': 1, 'bill"': 1, 'racers"': 1, 'of': 1}),
#  'poles': defaultdict(int,
#              {'in': 21,
#               'and': 39,
#               'being': 1,
#               'mars': 1,
#               'are': 31,
#               'as': 4,
#               'consist': 1,
#               'the': 12,
#               'stay': 2,
#               'by': 3,
#               'were': 12,
#               'outside': 3,
#               'to': 7,
#               'get': 1,
#               'he': 3,
#               'of': 19,
#               'it': 3,
#               '(north': 1,
#               'nearby': 1,
#               'on': 4,
#               'many': 1,
#               'that': 6,
#               'at': 3,
#               'attract': 2,
#               'every': 1,
#               '(sides)': 1,
#               'players': 1,
#               'a': 4,
#               'population,': 1,
#               'made': 1,
#               'repelling': 1,
#               'cannot': 1,
#               'do': 1,
#               'become': 1,
#               'who': 5,
#               'tried': 1,
#               'driven': 1,
#               'repel': 1,
#               'with': 6,
#               'for': 4,
#               'first': 1,
#               'have': 4,
#               'or': 2,
#               'how': 1,
#               'repulsed': 1,
#               'had': 4,
#               'during': 1,
#               '<eos>': 17,
#               'realized': 1,
#               'towards': 1,
#               'so': 1,
#               'is': 4,
#               '(for': 1,
#               'used': 1,
#               "dead's": 1,
#               'insolation': 1,
#               'this': 3,
#               'likely': 1,
#               'downed': 1,
#               'will': 1,
#               'sometimes': 2,
#               'would': 2,
#               'compared': 1,
#               '(and': 1,
#               'also': 1,
#               '(23%),': 1,
#               'there': 2,
#               'into': 1,
#               '(,': 1,
#               'toward': 1,
#               'late': 1,
#               'move': 2,
#               'thought': 1,
#               'feared': 1,
#               'began': 1,
#               'warm': 1,
#               'evolved': 1,
#               'increased': 1,
#               '(03': 1,
#               'showed': 1,
#               'incandescent': 1,
#               'helped': 2,
#               '(a': 1,
#               '(which': 1,
#               'just': 1,
#               'most': 1,
#               'while': 2,
#               'managed': 1,
#               'she': 2,
#               'which': 1,
#               '(since': 1,
#               'changes': 1,
#               'where': 1,
#               'intersect': 1,
#               'other': 1,
#               'could': 1,
#               'more': 1,
#               'after': 1,
#               'from': 2,
#               'because': 1,
#               'did': 1,
#               'saw': 1,
#               '': 3,
#               'appear': 1,
#               'mounted': 1,
#               'unhappy,': 1,
#               'due': 2,
#               'thus': 1,
#               'note': 1,
#               'they': 1,
#               'suggested': 1,
#               'coming': 1,
#               'howard': 1,
#               'wood': 1,
#               'fixed': 1,
#               'without': 1,
#               'take': 1,
#               'prefer': 1}),
#  'polyglot,': defaultdict(int, {'she': 1, 'possessing': 1}),
#  'gm-title': defaultdict(int, {'in': 1, 'by': 1}),
#  'gimbap': defaultdict(int,
#              {'<eos>': 1, '(': 1, 'it': 1, 'the': 1, 'was': 2, 'is': 2}),
#  'al-fawwaz': defaultdict(int,
#              {'<eos>': 1,
#               '(15': 1,
#               'was': 1,
#               'served': 1,
#               'also': 1,
#               'died': 1}),
#  'goddard,': defaultdict(int,
#              {'was': 1,
#               'explained': 1,
#               'susan': 1,
#               'shirley': 1,
#               'who': 1,
#               'at': 1,
#               'marta': 1,
#               'and': 1,
#               'gareth': 1,
#               'kansas': 1,
#               'former': 1,
#               'victor': 1,
#               'k': 1,
#               'macdonald': 1,
#               'burgess': 1}),
#  'orchestrion': defaultdict(int, {'(a': 1, '<eos>': 1, 'is': 1}),
#  'nishinomiya,': defaultdict(int, {'hyōgo': 1, 'and': 1, 'sanda,': 1}),
#  'wem,': defaultdict(int, {'wendover,': 1, 'shropshire,': 2, 'from': 1}),
#  'sobieraj': defaultdict(int, {'<eos>': 1, '(born': 1, 'competed': 1}),
#  '(44': defaultdict(int,
#              {'ounces)': 1,
#               'miles)': 1,
#               'times)': 1,
#               'inches)': 1,
#               'goals)': 1,
#               'days)': 1,
#               'm)': 1,
#               'metres)': 2,
#               'wins': 1,
#               'years': 1,
#               'members)': 1,
#               'pounds)': 1,
#               'yrs': 1}),
#  'emma,': defaultdict(int,
#              {'bought': 1,
#               'sister': 1,
#               'the': 1,
#               'simon,': 1,
#               'daughter': 1,
#               'forever': 1,
#               'jeremy,': 1,
#               'his': 1,
#               'nicknamed': 1,
#               'luke,': 1,
#               'was': 1,
#               'a': 1,
#               'is': 1,
#               'ginger,': 1,
#               'missouri': 1}),
#  'eddison': defaultdict(int,
#              {'<eos>': 1, 'obe': 1, 'was': 1, 'died': 1, 'first': 1}),
#  'ambarvale,': defaultdict(int, {'appin,': 1, 'new': 1}),
#  'mbeki,': defaultdict(int,
#              {'the': 1, 'raymond': 1, 'steve': 1, 'kgalema': 1, 'who': 1}),
#  'espaillat': defaultdict(int,
#              {'and': 3,
#               'province': 19,
#               'province;': 2,
#               'is': 1,
#               'province,': 1,
#               'high': 1,
#               'provinces': 1,
#               'the': 1}),
#  'mar,': defaultdict(int,
#              {'daughter': 1,
#               'on': 2,
#               'who': 1,
#               'short': 1,
#               'take': 1,
#               'chile)': 2,
#               'chile': 8,
#               'california,': 1,
#               'newport': 1,
#               'and': 2,
#               'an': 1,
#               'damian': 1,
#               'barcelona)': 1,
#               'santiago,': 1,
#               'quillota,': 1,
#               'with': 1,
#               'deportes': 1,
#               'catalonia': 1,
#               'is': 1,
#               'for': 1,
#               'california': 2,
#               'where': 1,
#               'was': 1,
#               'los': 1}),
#  "shostakovich's": defaultdict(int,
#              {'parents': 1,
#               'opera': 1,
#               '"symphony': 1,
#               'string': 1,
#               'seventh': 1,
#               'violin': 2,
#               '"lady': 1}),
#  'corybas,': defaultdict(int, {'and': 1}),
#  '14-year-olds': defaultdict(int, {'the': 1, 'by': 1}),
#  'zone)': defaultdict(int,
#              {'to': 1,
#               '<eos>': 3,
#               'on': 1,
#               'otherwise': 1,
#               'games,': 1,
#               'and': 1,
#               'is': 2,
#               'he': 1,
#               'this': 1}),
#  'plan:': defaultdict(int,
#              {'<eos>': 2,
#               'he': 1,
#               'at': 1,
#               'it': 1,
#               'lois': 1,
#               'to': 2,
#               'falsely': 1,
#               'she': 1}),
#  'qinghai': defaultdict(int,
#              {'and': 3,
#               'province,': 2,
#               'it': 1,
#               'province': 3,
#               'mountains': 1,
#               '<eos>': 1,
#               'district,': 1,
#               'provinces': 1,
#               'lake': 1,
#               'lake,': 1}),
#  'öxeryd': defaultdict(int, {'<eos>': 1, 'is': 1}),
#  '(pastor)': defaultdict(int, {'who,': 1, '<eos>': 2}),
#  "micheaux's": defaultdict(int, {'last': 1, 'second': 1}),
#  'astrophysical': defaultdict(int,
#              {'observatory': 9,
#               'objects': 1,
#               'and': 2,
#               'journal': 1,
#               'journal,': 1,
#               'journal"': 1,
#               'instrumentation': 1,
#               'object': 1,
#               'star': 4}),
#  'pravah': defaultdict(int,
#              {'<eos>': 7, 'is': 1, 'hd': 1, 'the': 1, 'it': 3, 'produced': 1}),
#  'sicknesses': defaultdict(int,
#              {'like': 1,
#               'people': 1,
#               'such': 1,
#               'some': 2,
#               'it': 1,
#               'or': 1,
#               'that': 1,
#               'are': 1,
#               '': 1}),
#  'sanghar': defaultdict(int,
#              {'district': 4,
#               'district,': 3,
#               'city': 1,
#               'is': 2,
#               'taluka': 3,
#               'than': 1,
#               '<eos>': 1,
#               '()': 1}),
#  'imprisoned,': defaultdict(int,
#              {'tortured,': 2,
#               'and': 9,
#               'exiled': 1,
#               'or': 1,
#               'but': 3,
#               'beaten': 1,
#               'he': 2,
#               'enslaved,': 1,
#               'fritzl': 1,
#               'the': 2,
#               'tortured': 1,
#               'one': 1,
#               'harassed': 1,
#               'although': 1,
#               'amlaíb': 1}),
#  'reignited': defaultdict(int,
#              {'trilogy"': 3, 'trilogy': 3, 'by': 1, 'an': 1, 'debates': 1}),
#  '(rocks': defaultdict(int, {'to': 1, 'and': 1, 'etc)': 1}),
#  '"unitary': defaultdict(int, {'authorities"': 3, 'authority"': 2}),
#  'changi': defaultdict(int,
#              {'airport': 35,
#               'it': 1,
#               'airport,': 10,
#               'the': 2,
#               'airline': 1,
#               '<eos>': 1,
#               'is': 2,
#               'air': 2,
#               'naval': 2,
#               'in': 1,
#               'prison,': 1,
#               'point': 3,
#               'ferry': 3,
#               'prison': 2,
#               'when': 1,
#               'skytrain,': 1,
#               "airport's": 3,
#               'experience': 1,
#               'beach': 2}),
#  'd\'assise"': defaultdict(int, {'it': 1, 'by': 2}),
#  'valangin': defaultdict(int,
#              {'merged': 4,
#               'in': 1,
#               'lands,': 1,
#               '<eos>': 1,
#               'was': 1,
#               'on': 1}),
#  'activity': defaultdict(int,
#              {'it': 25,
#               'of': 126,
#               'happened': 1,
#               'is': 75,
#               'on': 20,
#               'when': 4,
#               'sickness': 1,
#               'available': 1,
#               'that': 34,
#               'in': 182,
#               'where': 7,
#               'venus': 1,
#               '': 10,
#               'at': 12,
#               'depends': 1,
#               'which': 15,
#               'takes': 2,
#               'involving': 2,
#               'weekly': 1,
#               'since': 4,
#               'threatens': 1,
#               'or': 17,
#               'and': 59,
#               'as': 13,
#               'south': 1,
#               'during': 14,
#               '<eos>': 98,
#               'new': 1,
#               'you': 2,
#               'the': 40,
#               'involves': 6,
#               'may': 6,
#               'other': 3,
#               'such': 8,
#               'more': 2,
#               'into': 2,
#               'from': 9,
#               'occurred': 2,
#               'within': 3,
#               'for': 21,
#               'with': 19,
#               'find': 1,
#               'to': 19,
#               'this': 6,
#               'affects': 2,
#               'another': 1,
#               'changes': 1,
#               'against': 5,
#               '80%': 1,
#               'having': 2,
#               'due': 1,
#               'but': 8,
#               '(a': 1,
#               'continued': 4,
#               'there': 8,
#               'he': 8,
#               'done': 2,
#               'spread': 2,
#               'waste': 1,
#               'diverted': 2,
#               'was': 26,
#               'status': 2,
#               'would': 4,
#               'begins': 1,
#               'introduces': 1,
#               'sweat': 1,
#               'people': 2,
#               'fourth': 1,
#               'while': 3,
#               'consists': 1,
#               'among': 1,
#               'slowly': 1,
#               'make': 1,
#               'many': 1,
#               'developed': 4,
#               'can': 5,
#               'then': 1,
#               'are': 8,
#               '(eg,': 1,
#               'range': 1,
#               'generally': 1,
#               'relates': 1,
#               'a': 5,
#               '(eva)': 2,
#               'they': 10,
#               'using': 1,
#               'again': 2,
#               'groups': 1,
#               'fandoms': 1,
#               'until': 2,
#               'researchers': 1,
# ...
#               'fierro': 6,
#               'alberto': 1,
#               'cultural': 1,
#               'chirino': 2,
#               'gaite': 1,
#               'arzola': 2,
#               '(11': 1,
#               'erasto': 1,
#               "vizcarra's": 3,
#               '': 1,
#               'rossi': 1,
#               'vizcarra,': 2,
#               '(9': 1,
#               'was': 3,
#               'villa': 2,
#               '(14': 1,
#               'pando': 1,
#               'esteban': 1,
#               'c': 1,
#               'carrillo': 1,
#               'díez': 2,
#               'aramburú': 3,
#               '(de': 1,
#               'galli,': 1,
#               'maximiliano': 1,
#               'páez': 1,
#               'hernández': 1,
#               'competed': 1,
#               'francisco': 2,
#               'calvo': 2,
#               'alcoff': 2,
#               'after': 1}),
#  'redesignated': defaultdict(int, {'"homo': 1, 'from': 1, 'a': 1}),
#  'pivoting': defaultdict(int,
#              {'coil': 1, 'arm': 1, 'bascules': 1, '(2022': 1, 'is': 1}),
#  'chess-player': defaultdict(int, {'mälzel': 1, '<eos>': 1, 'of': 1}),
#  'govinda,': defaultdict(int, {'srinivasa,': 1, 'shakti': 1}),
#  'albanian-american': defaultdict(int,
#              {'and': 1, 'actress,': 1, 'actor,': 1, 'singer,': 1}),
#  'tapes,': defaultdict(int,
#              {'so': 1,
#               'and': 8,
#               'bookmark': 1,
#               'but': 1,
#               'compact': 2,
#               'graham': 1,
#               'read': 1,
#               'he': 1,
#               'video': 2,
#               'bostaph': 1,
#               'hosted': 1,
#               'that': 1,
#               'computer': 1,
#               'printing': 1}),
#  '"basketball': defaultdict(int, {'and': 1, 'wives"': 1, 'wives': 2}),
#  '"knew': defaultdict(int, {'that': 2}),
#  'unitarianism': defaultdict(int,
#              {'today': 1,
#               '': 1,
#               '<eos>': 1,
#               'is': 2,
#               'can': 1,
#               'they': 1,
#               'remain': 1,
#               'important': 1,
#               'the': 1,
#               'đurić': 1}),
#  'birthed': defaultdict(int,
#              {'<eos>': 1, 'two': 1, 'jackson': 1, 'around': 1}),
#  'broad"': defaultdict(int, {'and': 1, 'in': 1}),
#  'anarchy",': defaultdict(int, {'a': 1, '"the': 2, 'secretary': 1, 'and': 2}),
#  'newspapers:': defaultdict(int,
#              {'"instead': 1, '"the': 1, 'the': 2, '<eos>': 1, 'la': 1}),
#  'charlotte"': defaultdict(int, {'was': 1, 'the': 4, '<eos>': 1}),
#  'commandment"': defaultdict(int, {'is': 1, 'mcclure': 1, 'won': 1}),
#  'aspall': defaultdict(int, {'<eos>': 1, 'is': 1, 'aspall': 1, 'has': 1}),
#  'birkin,': defaultdict(int, {'richard': 1, 'féodor': 1}),
#  'frozen)': defaultdict(int, {'uncooked': 1, 'to': 1, '<eos>': 2}),
#  'brittany"': defaultdict(int, {'<eos>': 1, '(c': 1}),
#  'avesnes-les-aubert': defaultdict(int, {'<eos>': 1, '()': 1}),
#  'delaware:': defaultdict(int, {'<eos>': 1}),
#  'gjakova': defaultdict(int, {'<eos>': 1, '(albanian': 1, 'or': 1}),
#  'creativity)': defaultdict(int, {'he': 1, 'include': 1}),
#  'maniago': defaultdict(int, {'<eos>': 1, '(born': 1, 'played': 1}),
#  '(hyperuricemia)': defaultdict(int, {'may': 1, 'is': 1}),
#  'boniperti,': defaultdict(int, {'at': 1, 'like': 1}),
#  'winnington': defaultdict(int, {'it': 1, '<eos>': 1, 'is': 1}),
#  'su-34': defaultdict(int, {'fighter': 1, '<eos>': 1, 'is': 1}),
#  'vbc': defaultdict(int, {'(vietnam)': 4, 'galina': 1}),
#  'talence,': defaultdict(int, {'france': 1, 'a': 1, 'gironde,': 1}),
#  '2002–03,': defaultdict(int, {'2004–05,': 1, 'when': 1}),
#  'diyu': defaultdict(int, {'<eos>': 1, '(traditional': 1, 'looks': 1}),
#  'sestri': defaultdict(int, {'levante': 4, 'levante,': 2}),
#  'faculty"': defaultdict(int, {'<eos>': 2, 'and': 1}),
#  'mirabel': defaultdict(int,
#              {'is': 3,
#               'international': 1,
#               'explains': 1,
#               'mirabel': 1,
#               'then': 1,
#               'suddenly': 1,
#               'decides': 1,
#               'finds': 1,
#               'gets': 1,
#               'rebuilds': 1,
#               'standing': 1,
#               'takes': 1,
#               'talking': 1,
#               'follows': 1,
#               'would': 2,
#               'still': 1,
#               'hugging': 1,
#               'apologizes': 1,
#               'of': 1,
#               'blames': 1,
#               'feels': 1,
#               'back': 1,
#               'tells': 1,
#               'a': 1,
#               'and': 1}),
#  'modeling;': defaultdict(int, {'analysis': 1, 'in': 1}),
#  'handgrip': defaultdict(int,
#              {'or': 1, '': 1, 'molded': 1, 'with': 1, 'in': 1, 'controls': 1}),
#  'break-away': defaultdict(int, {'this': 1, 'to': 1, 'often': 1, 'state': 1}),
#  'rhino': defaultdict(int,
#              {'records': 2,
#               'and': 1,
#               'named': 1,
#               'without': 1,
#               '"diprotodon"': 1,
#               'species': 1,
#               'sanctuary': 1,
#               'native': 1,
#               '<eos>': 2,
#               '"elasmotherium"': 1,
#               'rhinos': 2,
#               'fossil': 1,
#               'have': 1,
#               'that': 2,
#               'reserve': 1,
#               'in': 2,
#               'live': 1,
#               'is': 2,
#               'to': 1,
#               'also': 1,
#               'season': 2,
#               'junior': 2,
#               'records,': 1,
#               '(marvel': 1,
#               'has': 1,
#               'under': 1}),
#  'staris': defaultdict(int, {'was': 1, '20,': 1, 'v20,': 1}),
#  'ether': defaultdict(int,
#              {'was': 2,
#               'which': 3,
#               'theory': 1,
#               'wind': 1,
#               'this': 2,
#               'or': 3,
#               'and': 6,
#               '<eos>': 4,
#               'is': 5,
#               'ether': 1,
#               'burns': 1,
#               'has': 1,
#               'as': 2,
#               'in': 3,
#               'if': 1,
#               'instead,': 1,
#               'by': 1,
#               'to': 1,
#               'solutions': 1,
#               'second,': 1,
#               'the': 2,
#               'group': 1,
#               'part': 1,
#               'due': 1,
#               'coin': 2,
#               'transactions': 1,
#               'solution': 1,
#               'it': 1}),
#  '(certified': defaultdict(int, {'medical': 1, 'clones)': 1}),
#  'nettleton': defaultdict(int,
#              {'<eos>': 1, '(august': 1, 'was': 1, 'died': 1, 'is': 1}),
#  'ineffective,': defaultdict(int, {'and': 3, 'unless': 1, 'so': 1}),
#  'sox': defaultdict(int,
#              {'and': 25,
#               'play': 4,
#               'won': 5,
#               '<eos>': 20,
#               'got': 1,
#               'are': 3,
#               'finished': 1,
#               'began': 1,
#               'first': 1,
#               'is': 1,
#               'ruth': 1,
#               'played,': 1,
#               'owner': 2,
#               'sold': 1,
#               'had': 2,
#               'finally': 1,
#               'fan': 1,
#               'have': 2,
#               'near': 1,
#               'swept': 2,
#               'he': 24,
#               'schilling': 1,
#               'from': 13,
#               '(1993–1997)': 1,
#               'they': 1,
#               'held': 1,
#               'became': 1,
#               'in': 18,
#               'ever': 1,
#               'traded': 1,
#               'win': 1,
#               'ortiz': 1,
#               'single-season': 1,
#               'lost': 2,
#               'went': 1,
#               'were': 1,
#               'organization,': 1,
#               'the': 2,
#               'up': 1,
#               'beat': 3,
#               'then': 1,
#               'would': 1,
#               'to': 3,
#               'for': 3,
#               'shared': 1,
#               'on': 2,
#               'before': 3,
#               'barber': 1,
#               'while': 1,
#               'active': 1,
#               'it': 2,
#               'made': 1,
#               'radio': 1,
#               'broadcasts': 2,
#               'after': 2,
#               'hall': 2,
#               'of': 5,
#               '(1954)': 1,
#               '(2001–2003),': 1,
#               'as': 1,
#               '': 3,
#               'team': 1,
#               '(1961),': 1,
#               '(–),': 2,
#               'franchise': 1,
#               'all-century': 1,
#               '(1967)': 1,
#               'among': 1,
#               'during': 1,
#               '(1969)': 1,
#               'scandal': 1,
#               'players': 1,
#               '(1960–61),': 1,
#               '(1948–1951),': 1,
#               '(1952–1953)': 1,
#               '(1950,': 1,
#               '(1965)': 1,
#               '(1958),': 1,
#               '(1973),': 1,
#               'nelson': 1,
#               'organization': 2,
#               'defeated': 1,
#               'world': 1,
#               'that': 1,
#               'along': 1,
#               '(1964)': 1,
#               '(1977),': 1,
#               '(1960–1962),': 1,
#               '(2006–2007),': 1,
#               '(1968–69)': 1,
#               'allen': 1,
#               '(1969–1971),': 1,
#               'teammates': 1,
#               'between': 2,
#               '(twice),': 1,
#               '(1970)': 1,
#               'so': 1,
#               'with': 1,
#               'organizations': 1,
#               '(1963–1969)': 1,
#               '(1969–1978)': 1,
#               'signed': 1}),
#  'lithuania': defaultdict(int,
#              {'the': 27,
#               'and': 60,
#               'became': 1,
#               'called': 1,
#               '<eos>': 61,
#               '(these': 1,
#               '(the': 1,
#               'seized': 1,
#               'came': 1,
#               'announced': 1,
#               'in': 20,
#               'is': 17,
#               'began': 2,
#               '(at': 1,
#               're-declared': 1,
#               'has': 4,
#               'abroad': 1,
#               'borders': 1,
#               'are': 3,
#               'include': 1,
#               'they': 2,
#               'some': 1,
#               'lithuania': 1,
#               'made': 1,
#               'declared': 2,
#               'have': 2,
#               'there': 2,
#               'she': 5,
#               'on': 13,
#               'out': 1,
#               'and,': 1,
#               'that': 1,
#               'since': 3,
#               'give': 1,
#               'twelve': 1,
#               '': 6,
#               'john': 1,
#               'to': 7,
#               'which': 1,
#               'bigos': 1,
#               'from': 18,
#               'accepted': 1,
#               'into': 1,
#               'litas': 1,
#               'these': 1,
#               'within': 1,
#               'it': 22,
#               'executed': 1,
#               'he': 13,
#               'his': 8,
#               'first': 1,
#               'gained': 1,
#               'each': 1,
#               '–': 2,
#               'by': 4,
#               'national': 4,
#               'grand': 1,
#               'while': 1,
#               'after': 3,
#               '(1576–1586)': 1,
#               'at': 5,
#               'was': 4,
#               'also': 1,
#               'had': 1,
#               'during': 1,
#               'before': 2,
#               '()': 2,
#               'working': 1,
#               '(as': 1,
#               'one': 1,
#               'or': 1,
#               'once,': 1,
#               'almenas': 1,
#               'of': 1,
#               'consists': 1,
#               'initial': 1,
#               'for': 1,
#               'its': 2,
#               'due': 1,
#               '(,': 1,
#               '(),': 1,
#               'foundation': 1,
#               'jonava': 1,
#               'should': 1,
#               'as': 1,
#               '(10%),': 1,
#               '(4%),': 1,
#               'following': 1,
#               'asked': 1,
#               'sank': 1,
#               'when': 1,
#               'fully': 1,
#               'left': 1,
#               'via': 1,
#               'certificate': 1,
#               '()",': 1,
#               '(european': 1,
#               '(2022)': 1,
#               'held': 1,
#               'were': 1,
#               'together': 1,
#               'rail': 1}),
#  'peace-keeping': defaultdict(int, {'missions': 1, 'on': 1, 'forces': 4}),
#  'magnetospheres': defaultdict(int, {'is': 1, 'the': 1}),
#  'allusions': defaultdict(int,
#              {'in': 1,
#               'to': 7,
#               'the': 1,
#               'however': 1,
#               'set': 1,
#               'reveal': 1,
#               'were': 1,
#               'on': 1}),
#  'jordan),': defaultdict(int, {'and': 1, 'bwv': 1}),
#  'frabotta': defaultdict(int, {'<eos>': 1, '(11': 1, 'died': 1}),
#  'pq,': defaultdict(int, {'on': 1, 'meaning': 1, 'especially': 1}),
#  'blooregard': defaultdict(int, {'q': 2}),
#  'morien': defaultdict(int, {'<eos>': 1, 'is': 1}),
#  'hegde': defaultdict(int,
#              {'<eos>': 2,
#               '(1': 1,
#               'was': 1,
#               'died': 1,
#               '(born': 1,
#               'it': 1,
#               'and': 1,
#               'in': 1,
#               'became': 1,
#               'as': 3}),
#  'gaga’s': defaultdict(int,
#              {'initial': 1, 'sixth': 1, 'fifth': 1, 'music': 1}),
#  'fail': defaultdict(int,
#              {'a': 4,
#               'at': 9,
#               'to': 65,
#               'movie': 1,
#               'this': 6,
#               '(22%),': 1,
#               'because': 7,
#               'are': 2,
#               'out': 2,
#               '<eos>': 14,
#               '75': 1,
#               'one': 2,
#               'microsoft': 1,
#               'without': 3,
#               'while': 1,
#               'overall,': 1,
#               'and': 7,
#               'than': 1,
#               'before': 1,
#               'certain': 1,
#               'or': 6,
#               'in': 9,
#               'completely': 1,
#               'because,': 1,
#               'kidney': 1,
#               'due': 2,
#               'far': 1,
#               'for': 1,
#               'if': 2,
#               'them': 1,
#               'miserably': 2,
#               'cafe"': 1,
#               'you': 2,
#               'on': 2,
#               'soon"': 1,
#               'much': 1,
#               'the': 7,
#               'as': 1,
#               'after': 2,
#               'her': 2,
#               'suffer': 1,
#               'when': 2,
#               'he': 2,
#               '(the': 1,
#               '': 1,
#               'examples': 1,
#               'under': 1,
#               'cultural': 1,
#               'most': 1,
#               'they': 2,
#               'criteria': 1,
#               'proof': 1,
#               'adults': 1,
#               'every': 1,
#               'with': 1,
#               'sparta': 1,
#               'but': 1,
#               'gust': 1,
#               'currently': 1,
#               'discography': 1,
#               'many': 1,
#               'mutual': 2,
#               'is': 1,
#               'makes': 2,
#               'grades,': 1,
#               'doctrine': 1,
#               'more': 1,
#               'sometimes': 1,
#               'referendum': 1}),
#  'bolhrad': defaultdict(int, {'<eos>': 1, '(;': 1, 'raion': 1}),
#  'intellect:': defaultdict(int, {'an': 2}),
#  'richfield,': defaultdict(int,
#              {'idaho': 1, 'minnesota': 2, 'utah': 1, 'neil': 1}),
#  'franchise;': defaultdict(int, {'the': 1, 'of': 2, 'it’s': 1}),
#  'spectre,': defaultdict(int, {'the': 2, 'sandman,': 1}),
#  'straightening': defaultdict(int,
#              {'of': 2,
#               'occurring': 1,
#               'the': 4,
#               '<eos>': 1,
#               'is': 2,
#               'keeps': 2,
#               'teeth': 2,
#               'hair': 1,
#               'just': 1}),
#  '(crescent-shaped)': defaultdict(int, {'caudal': 1, 'in': 1}),
#  'jos': defaultdict(int,
#              {'van': 3,
#               'oehlen': 3,
#               'de': 1,
#               '<eos>': 10,
#               'is': 6,
#               'luhukay': 2,
#               'chabert': 1,
#               'wienen': 2,
#               'vandeloo': 1,
#               'bax': 2,
#               'compaan': 2,
#               'waals': 2,
#               'verstappen,': 1,
#               'he': 2,
#               'and': 2,
#               'verstappen': 1,
#               'buttler,': 1,
#               'in': 1,
#               'huypens': 1,
#               'maria': 1,
#               'verhaegen': 1,
#               'daman': 2}),
#  ...}

# %%
bigram_probabilities = {v: defaultdict(int) for v in vocab}
# Find out the bi-gram probabilities. For this divide the Bi-gram counts of x1,x2 by Uni-gram counts of x1
for x1 in bigram_counts:
    for x2 in bigram_counts[x1]:
      # Your Code here
        bigram_probabilities[x1][x2] = bigram_counts[x1][x2] / unigram_counts[x1]

# %%
# Print Bi-gram probability of black cat
bigram_probabilities["black"]["cat"]
# Out:
# 0.0022091310751104565

# %%
# Print Bi-gram probability of green cat
# From the probability you can understand that green cats do not exist (at least are not common)
bigram_probabilities["green"]["cat"]
# Out:
# 0

# %%
# Complete the function to find probability of a sequence.
# if you have sequence s = {w1,w2,w3,w4}
# P(s) = p(w1,w2)*p(w2,w3)*p(w3,w4)
def sequence_probability(s):
    # words contain list of words in sequence s
    words = preprocess(s)
    # List to contain all transition Bi-gram probabilities, i.e., [p(w1,w2),p(w2,w3),p(w3,w4)]
    transition_probs = []
    for i in range(len(words)-1):
        # Gets consecutive words. x1,x2 will get w1,w2 then w2,w3 and so on
        x1, x2 = words[i], words[i+1]
        # Get the bi-gram probabilities of the transitions, i.e., p(w1,w2)
        # Your code here
        transition_prob = bigram_probabilities[x1][x2]
        # Insert the transition prob in list transition_probs
        # Your code here
        transition_probs.append(transition_prob)

    # Calculate the sequence probability using transition_probs list.
    # Hint: transition_prob contains [p(w1,w2),p(w2,w3),p(w3,w4)] and your sequence prob P(s) = p(w1,w2)*p(w2,w3)*p(w3,w4)
    # Your Code here
    prob = 1
    for transition_prob in transition_probs:
        prob += transition_prob
    
    return prob

# %%
sequences = ["i like fish", "i likes fish", "me likes fish"]
probs = [(s, sequence_probability(s)) for s in sequences]
sorted(probs, key = lambda x: x[1], reverse=True)
# it can catch ungrammatical constructions
# Out:
# [('i like fish', 1.0598181288715858),
#  ('i likes fish', 1.0567765490663619),
#  ('me likes fish', 1.0562380237452258)]

# %%
sequences = ["i like burgers", "i like fish", "i like snakes"]
probs = [(s, sequence_probability(s)) for s in sequences]
sorted(probs, key = lambda x: x[1], reverse=True)
# burgers are in the unigrams, but there is no fitting bigram --> unknown / low-frequency word problem
# Out:
# [('i like burgers', 1.0864018451806203),
#  ('i like snakes', 1.064612363072076),
#  ('i like fish', 1.0598181288715858)]

# %%
sequences = ["i like fish", "i like fried fish", "i like fried fish with potatoes"]
probs = [(s, sequence_probability(s)) for s in sequences]
sorted(probs, key = lambda x: x[1], reverse=True)
# longer sequences will have lower probability
# Out:
# [('i like fried fish with potatoes', 1.126865258765832),
#  ('i like fried fish', 1.0733548148072751),
#  ('i like fish', 1.0598181288715858)]

# %%
# Comlete the function on generating sequences. For this you will follow a greedy approach where you select the next word on the basis of highest bi-gram probability.
# Basically if the last word is w, you find the word x which has the highest bi-gram probability P(w,x)
# The function takes the starting word and the length of the sequence you want to generate
def generate(start_word, length = 2):
    output = [start_word]
    # You need to generate length-1 number of words so loop over that many times
    for i in range(0, length-1):
        # If last word in output(till now) is not in bigram_probabilities we will stop the generation
        if output[i] not in bigram_probabilities:
            break
        else:
          # Find the Bi-gram probabilities of all words with the last word in output(till now). The last word in output(till now) is basically output[i]
          # Then find the word which has the highest probability and add it to the output string
          # Your code here
          output.append(max(bigram_probabilities[output[i]], key=bigram_probabilities[output[i]].get))

    return output

# %%
# Use the generate function to generate a sequence of length 10 starting with the word "cats"
# Your Code here
generate('cats', 10)
# Out:
# ['cats', 'are', 'the', 'first', 'time', 'in', 'the', 'first', 'time', 'in']

# %%
# Use the generate function to generate a sequence of length 10 starting with the word "we"
# Your Code here
generate('we', 10)
# Out:
# ['we', 'can', 'be', 'a', 'commune', 'it', 'is', 'a', 'commune', 'it']

# %% [markdown]
# ## Watermarking

# %%
# Two sentences
s1 = "pigeons known for their remarkable homing ability and adaptability to urban environments have been companions and messengers to humans for thousands of years ."
s2 = "with their iridescent feathers and distinctive cooing pigeons add a unique charm to cityscapes around the world ."

# %%
w = s1.split(" ") + s2.split(" ")
vocab = set(w)

# %%
import pickle

with open('data/red_list.data', 'rb') as f:
        red_list = pickle.load(f)

# red_list contains which are words are red/green as next words. If the value of red_list[w1][w2] is True that means w2 cannot follow w1 and it is a violation.
# If the value of red_list[w1][w2] is False that means w2 can follow w1 and it is not a violation.

# %%
red_list['with']['their']
# Out:
# True

# %%
red_list['and']['distinctive']
# Out:
# False

# %%
# Now you have the red list in red_list
# Write a function to check the number of violations
# The function takes the sentence s and the redlist as inputs
def check(s, redlist):
    # Get the list of words
    w = s.split(" ")
    # Count number of violations
    # Remember the red list contains true and flase
    # You need to check if the value corresponding to consecutive words in w are True in redlist. If so violations count will go up by 1.
    violations = 0
    for i in range(0, len(w)-1):
        violations += 1 if  redlist[w[i]][w[i+1]] is True else 0
    return violations

check(s1, red_list), check(s2, red_list)
# Out:
# (0, 10)

# %%
# Calculate the probability of a human writing a sentence of the same length as s1 without ever violating the red list
print(1 / (2 ** len(s1)))
# Out:
# 1.3684555315672042e-48

# %%
# Calculate the probability of a human writing a sentence of the same length as s2 without ever violating the red list
print(1 / (2 ** len(s2)))
# Out:
# 9.62964972193618e-35
